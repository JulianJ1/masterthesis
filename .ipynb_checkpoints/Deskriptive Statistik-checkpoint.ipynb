# %% [markdown]
# # Masterthesis
# ## Deskriptive Statistik
# #### Julian Jetz

# %% [markdown]
# ## Inhalt:
#
# * [Boxenplots und Histogramme der Schäden (mit Ausreißern)](#ausreißer)
#
# * [Entfernung der Ausreißer](#ausreißer-delete)
#
# * [Häufigkeitsverteilungen](#frequencies)
#     * [Zugart](#freq-zugart)
#     * [Unfallart](#freq-unfallart)
#     * [Streckenart](#freq-streckenart)
#     * [Unfallursache Lvl 2](#freq-cause)
#         * [Unfallursache Lvl 1 (nach Unfallart aufgeteilt)](#freq-cause_lvl1_lvl2_unfallart)
#     * [Unfallsignifikanz](#freq-acctype)
#         * [Unfallsignifikanz (nach Unfallursache Lvl 2)](#freq-acctype_cause)
#     * [Wetter](#freq-wetter)
#     * [Jahreszeit](#freq-jahreszeit)
#     * [Jahr](#freq-jahr)
#         * [Jahr nach Unfallart](#freq-jahr_unfallart)
#     * [Temperatur](#freq-temp)
#         * [Unfallursachen nach Temperatur](#freq-temp_cause)
#     * [Sichtbarkeit](#freq-vis)
#     * [Geschwindigkeitsüberschreitung](#freq-speed)
#
# * [Verteilungstabellen](#tables)
#     * [](#)
#
# * [Boxenplots und Histogramme](#boxenplots)
#     * [Infrastrukturschaden](#infrastrukturdmg)
#     * [Materialschaden](#EQPDMG)
#     * [Streckenschaden](#TRKDMG)
#     * [Zuggeschwindigkeit](#zuggeschwindigkeit)
#     * [Zuggewicht](#tons)
#     * [Zugart](#zugart)
#     * [Unfallart](#unfallart)
#     * [Unfallursache Lvl 2](#cause)
#     * [Unfallsignifikanz](#unfallsignifikanz)
#     * [Wetter](#wetter)
#     * [Jahreszeit](#Jahreszeit)
#     * [Jahr](#jahr)
#     * [Temperatur](#temp)
#     * [Geschwindigkeitsüberschreitung](#speed)
#
# * [Statistik](#common_statistics)
#
# * [Korrelationen](#correlations)
#
# * [Anova Varianz](#ANOVA)
#     * [Anova Heatmap](#ANOVA_HEATMAP)

# %%
import glob
import pandas as pd
import numpy as np
from scipy import stats
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from pandas.plotting import scatter_matrix
from currency_converter import CurrencyConverter
from datetime import date
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
na_values = ['nan', 'N/A', 'NaN', 'NaT']

# %%
df = pd.read_csv('resources/accident_data.csv', sep=";", na_values=na_values, index_col=False, dtype = {"STATE" : "str", "TYPE" : "str", "TYPEQ" : "str", "TYPTRK" : "str", "WEATHER" : "str", "VISIBLTY" : "str", "TONS" : "float64"})
df.shape[0]
# Out:
# 66363

# %%
pd.set_option('display.max_colwidth', 500)

# %%
a4_dims = (16, 10)
sns.set(style="whitegrid")

# %% [markdown]
# ### Boxenplots und Histogramme der Schäden (mit Ausreißern) <a class="anchor" id="ausreißer"></a>

# %% [markdown]
# #### Boxenplot Infrastrukturschaden

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
#plt.yscale("log")
ax.set_ylabels("Infrastrukturschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Boxplot_Infrastrukturschaden.png')

# %% [markdown]
# #### Histogramm Infrastrukturschaden (ohne Ausreißer)¶

# %%
df['INFRASTRUCTURE_DMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Infrastrukturschaden.png')

# %% [markdown]
# #### Boxenplot Materialschaden

# %%
ax = sns.catplot(y='EQPDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Boxplot_Materialschaden.png')

# %% [markdown]
# #### Histogramm Materialschaden

# %%
df['EQPDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Materialschaden.png')

# %% [markdown]
# #### Boxenplot Streckenschaden

# %%
ax = sns.catplot(y='TRKDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Streckenschaden in Dollar")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Boxplot_Streckenschaden.png')

# %% [markdown]
# #### Histogramm Materialschaden

# %%
df['TRKDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Streckenschaden.png')

# %% [markdown]
# #### Entfernung der Ausreißer <a class="anchor" id="ausreißer-delete"></a>

# %%
df.shape[0]
# Out:
# 66363

# %%
std_dev = 3.5
df = df[(np.abs(stats.zscore(df[['LOCOMOTIVES1','LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2','LOADF2', 'EMPTYF2', 'INFRASTRUCTURE_DMG']])) < float(std_dev)).all(axis=1)]

# %%
df.shape[0]
# Out:
# 59882

# %% [markdown]
# ### Häufigkeiten <a class="anchor" id="frequencies"></a>

# %%
def bar_values(ax):
    for p in ax.patches:
        ax.annotate(format(p.get_height(), ',d').replace(",","."), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
    sns.despine()
    return ax

# %% [markdown]
# #### Häufigkeiten Zugart <a class="anchor" id="freq-zugart"></a>

# %%
#fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.countplot(x="EQUIPMENT_TYPE", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Zugart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90, horizontalalignment='right')
plt.savefig('Images/Count_Zugart.png')

# %% [markdown]
# #### Häufigkeiten Unfallart <a class="anchor" id="freq-unfallart"></a>

# %%
ax = sns.countplot(x="ACCIDENT_TYPE", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=25, horizontalalignment='right')
plt.savefig('Images/Count_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Streckenart <a class="anchor" id="freq-streckenart"></a>

# %%
ax = sns.countplot(x="TYPTRK", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Streckenart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=25, horizontalalignment='right')
plt.savefig('Images/Count_Streckenart.png')

# %% [markdown]
# #### Häufigkeiten Unfallursache <a class="anchor" id="freq-cause"></a>

# %%
#fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.countplot(x="ACCCAUSE_LVL2", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallursache")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')
plt.savefig('Images/Count_Unfallursache.png')

# %% [markdown]
# #### Häufigkeiten Unfallursache Lvl 1 (eingefärbt nach Unfallursache Lvl2 und gruppiert nach Unfallart) <a class="anchor" id="freq-cause_lvl1_lvl2_unfallart"></a>

# %%
bp = sns.catplot(y="ACCCAUSE_LVL1", hue="ACCCAUSE_LVL2", data=df, kind="count", col="ACCIDENT_TYPE", col_wrap=2, height=14, aspect=0.7, legend=False, legend_out=False)
bp.set_xlabels('Anzahl', fontsize=12)
bp.set_ylabels('Unfallursache', fontsize=12)
for ax in bp.axes:
    ax.legend(bbox_to_anchor=(0, 1.08), loc='upper left', ncol=3, frameon=False, fontsize=10)
    ax.grid(axis='y')
    #plt.setp(ax.get_xticklabels(), visible=True)
    #ax.set_xticks([0,1,2,3,4,5], ax.get_xticklabels())
plt.subplots_adjust(wspace=0.1, hspace=0.15)
plt.savefig('Images/Count_Unfallursache_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Unfallschwere <a class="anchor" id="freq-acctype"></a>

# %%
ax = sns.countplot(x="ACCTYPE", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallschwere")
plt.savefig('Images/Count_Unfallschwere.png')

# %% [markdown]
# #### Häufigkeiten Unfallschwere (nach Zugart)  <a class="anchor" id="freq-acctype_cause"></a>

# %%
cp = sns.catplot(x="ACCTYPE", data=df, col="EQUIPMENT_TYPE", palette="colorblind", kind="count", col_wrap=4, height=3, aspect=1)
cp.set_xlabels('Unfallschwere', fontsize=12)
cp.set_ylabels('Anzahl', fontsize=12)

# %% [markdown]
# #### Häufigkeiten Wetter <a class="anchor" id="freq-wetter"></a>

# %%
ax = sns.countplot(x="WEATHER", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Wetter")
plt.savefig('Images/Count_Wetter.png')

# %% [markdown]
# #### Häufigkeiten Jahreszeit <a class="anchor" id="freq-jahreszeit"></a>

# %%
ax = sns.countplot(x="Jahreszeit", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Jahreszeit")
plt.savefig('Images/Count_Jahreszeit.png')

# %% [markdown]
# #### Häufigkeiten Jahr <a class="anchor" id="freq-jahr"></a>

# %%
bp = sns.catplot(x="YEAR4", data=df, kind="count", height=10, aspect=1.5, palette="colorblind")
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Anzahl', fontsize=12)
plt.savefig('Images/Count_Jahr.png')

# %% [markdown]
# #### Häufigkeiten Jahr (nach Unfallart) <a class="anchor" id="freq-jahr_unfallart"></a>

# %%
bp = sns.catplot(x="YEAR4", data=df, kind="count", col="ACCIDENT_TYPE", col_wrap=2, height=5, aspect=1.5, palette="colorblind")
bp.set_ylabels('Jahr', fontsize=12)
bp.set_xlabels('Anzahl', fontsize=12)
for x in bp.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
plt.savefig('Images/Count_Jahr_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Temperatur <a class="anchor" id="freq-temp"></a>

# %%
temp_order = ["Sehr Kalt (-45° - 30,01° C)", "Kalt (-30° - 0,01° C)", "Moderat (0° bis 19,99° C)", "Warm (20° bis 31,99° C)", "Heiß (>= 32° C)"]
ax = sns.countplot(x="TEMP_CLUSTER", data=df, palette="colorblind", order=temp_order)
ax = bar_values(ax)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')
ax.set_xlabel("Temperatur")
plt.savefig('Images/Count_Temperatur.png')

# %% [markdown]
# #### Häufigkeiten Temperatur (nach Unfallursache) <a class="anchor" id="freq-temp_cause"></a>

# %%
ax = sns.catplot(x="TEMP_CLUSTER", hue="ACCCAUSE_LVL2", kind="count", data=df, palette='colorblind', order=temp_order, legend=False, height=15, aspect=1.5)
for x in ax.axes.flat:
    x.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=3, frameon=False, fontsize=20)
    for label in x.get_xticklabels():
        label.set_rotation(-90)   
ax.set_xlabels("Temperatur")
plt.savefig('Images/Count_Temperatur_Unfallursache.png')

# %% [markdown]
# #### Häufigkeiten Sichtbarkeit <a class="anchor" id="freq-vis"></a>

# %%
vis_order = ["Dawn", "Day", "Dusk", "Dark"]
ax = sns.countplot(x="VISIBLTY", data=df, palette="colorblind", order=vis_order)
ax = bar_values(ax)
ax.set_xlabel("Sichtbarkeit")
plt.savefig('Images/Count_Sichtbarkeit.png')

# %% [markdown]
# #### Häufigkeiten zu hohe Zuggeschwindigkeit <a class="anchor" id="freq-speed"></a>

# %%
ax = sns.countplot(x="SPD_TOO_HIGH", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Zuggeschwindigkeit zu hoch")
plt.savefig('Images/Count_Zug_zu_schnell.png')

# %% [markdown]
# ### Verteilungstabellen <a class="anchor" id="tables"></a>

# %% [markdown]
# #### Verteilungstabelle Zugart nach Unfallart <a class="anchor" id="tables_eqtype_type"></a>

# %%
freq_tab = pd.crosstab(index=df["ACCIDENT_TYPE"],  columns=df["EQUIPMENT_TYPE"], margins=True)
freq_tab/freq_tab.loc["All"]
# Out:
# EQUIPMENT_TYPE                             Commuter Train  Cut of Cars  \
# ACCIDENT_TYPE
# Collision                                        0.187861     0.094460
# Crossing                                         0.572254     0.008174
# Derailment                                       0.170520     0.858311
# Fire/violent rupture/Explosive Detonation        0.069364     0.039055
# All                                              1.000000     1.000000
#
# EQUIPMENT_TYPE                             Freight Train  Locomotive  \
# ACCIDENT_TYPE
# Collision                                       0.035492    0.080994
# Crossing                                        0.107591    0.077214
# Derailment                                      0.843200    0.817495
# Fire/violent rupture/Explosive Detonation       0.013718    0.024298
# All                                             1.000000    1.000000
#
# EQUIPMENT_TYPE                             Passenger Train  Single Car  \
# ACCIDENT_TYPE
# Collision                                         0.277101    0.155136
# Crossing                                          0.458587    0.098532
# Derailment                                        0.182095    0.536688
# Fire/violent rupture/Explosive Detonation         0.082217    0.209644
# All                                               1.000000    1.000000
#
# EQUIPMENT_TYPE                             Work Train  Yard/Switching  \
# ACCIDENT_TYPE
# Collision                                    0.150685        0.040784
# Crossing                                     0.126712        0.006243
# Derailment                                   0.686644        0.951747
# Fire/violent rupture/Explosive Detonation    0.035959        0.001225
# All                                          1.000000        1.000000
#
# EQUIPMENT_TYPE                                  All
# ACCIDENT_TYPE
# Collision                                  0.049080
# Crossing                                   0.088240
# Derailment                                 0.847767
# Fire/violent rupture/Explosive Detonation  0.014913
# All                                        1.000000

# %%
format_dict = {'Environmental Conditions':'{:.2f}%', 'Human Factors': '{:.2f}%', 'Loading': '{:.2f}%', 
               'Mechanical and Electrical Failures': '{:.2f}%', 'Miscellaneous Causes': '{:.2f}%', 
               'Signal and Communication': '{:.2f}%', 'Track, Roadbed and Structures': '{:.2f}%',
               'All': '{:.2f}%'}

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Zugart  <a class="anchor" id="tables_zugart_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["ACCIDENT_TYPE"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_2748b17a_d115_11ea_928f_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2748b17a_d115_11ea_928f_acde48001122level0_row0" class="row_heading level0 row0" >Collision</th>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row0_col0" class="data row0 col0" >8.01%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row0_col1" class="data row0 col1" >9.55%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row0_col2" class="data row0 col2" >1.53%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row0_col3" class="data row0 col3" >2.56%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row0_col4" class="data row0 col4" >17.30%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row0_col5" class="data row0 col5" >6.48%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row0_col6" class="data row0 col6" >0.40%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row0_col7" class="data row0 col7" >$4.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_2748b17a_d115_11ea_928f_acde48001122level0_row1" class="row_heading level0 row1" >Crossing</th>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row1_col0" class="data row1 col0" >0.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row1_col1" class="data row1 col1" >0.23%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row1_col2" class="data row1 col2" >85.07%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row1_col3" class="data row1 col3" >0.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row1_col4" class="data row1 col4" >0.49%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row1_col5" class="data row1 col5" >0.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row1_col6" class="data row1 col6" >0.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row1_col7" class="data row1 col7" >$8.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_2748b17a_d115_11ea_928f_acde48001122level0_row2" class="row_heading level0 row2" >Derailment</th>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row2_col0" class="data row2 col0" >91.65%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row2_col1" class="data row2 col1" >90.13%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row2_col2" class="data row2 col2" >13.33%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row2_col3" class="data row2 col3" >91.12%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row2_col4" class="data row2 col4" >76.13%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row2_col5" class="data row2 col5" >93.52%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row2_col6" class="data row2 col6" >99.56%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row2_col7" class="data row2 col7" >$84.78%</td>
#             </tr>
#             <tr>
#                         <th id="T_2748b17a_d115_11ea_928f_acde48001122level0_row3" class="row_heading level0 row3" >Fire/violent rupture/Explosive Detonation</th>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row3_col0" class="data row3 col0" >0.34%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row3_col1" class="data row3 col1" >0.09%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row3_col2" class="data row3 col2" >0.07%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row3_col3" class="data row3 col3" >6.32%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row3_col4" class="data row3 col4" >6.08%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row3_col5" class="data row3 col5" >0.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row3_col6" class="data row3 col6" >0.04%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row3_col7" class="data row3 col7" >$1.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_2748b17a_d115_11ea_928f_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_2748b17a_d115_11ea_928f_acde48001122row4_col7" class="data row4 col7" >$100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Wetter <a class="anchor" id="tables_weather_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["WEATHER"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_effe9c70_d114_11ea_928f_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >WEATHER</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_effe9c70_d114_11ea_928f_acde48001122level0_row0" class="row_heading level0 row0" >Clear</th>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row0_col0" class="data row0 col0" >39.24%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row0_col1" class="data row0 col1" >67.45%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row0_col2" class="data row0 col2" >71.00%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row0_col3" class="data row0 col3" >65.80%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row0_col4" class="data row0 col4" >$67.01%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row0_col5" class="data row0 col5" >62.62%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row0_col6" class="data row0 col6" >64.50%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row0_col7" class="data row0 col7" >$65.94%</td>
#             </tr>
#             <tr>
#                         <th id="T_effe9c70_d114_11ea_928f_acde48001122level0_row1" class="row_heading level0 row1" >Cloudy</th>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row1_col0" class="data row1 col0" >22.31%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row1_col1" class="data row1 col1" >22.71%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row1_col2" class="data row1 col2" >20.24%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row1_col3" class="data row1 col3" >24.58%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row1_col4" class="data row1 col4" >$23.22%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row1_col5" class="data row1 col5" >26.08%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row1_col6" class="data row1 col6" >25.39%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row1_col7" class="data row1 col7" >$23.83%</td>
#             </tr>
#             <tr>
#                         <th id="T_effe9c70_d114_11ea_928f_acde48001122level0_row2" class="row_heading level0 row2" >Fog</th>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row2_col0" class="data row2 col0" >1.26%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row2_col1" class="data row2 col1" >1.24%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row2_col2" class="data row2 col2" >1.78%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row2_col3" class="data row2 col3" >1.39%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row2_col4" class="data row2 col4" >$1.39%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row2_col5" class="data row2 col5" >0.66%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row2_col6" class="data row2 col6" >0.93%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row2_col7" class="data row2 col7" >$1.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_effe9c70_d114_11ea_928f_acde48001122level0_row3" class="row_heading level0 row3" >Rain</th>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row3_col0" class="data row3 col0" >23.34%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row3_col1" class="data row3 col1" >6.43%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row3_col2" class="data row3 col2" >5.13%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row3_col3" class="data row3 col3" >5.20%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row3_col4" class="data row3 col4" >$6.56%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row3_col5" class="data row3 col5" >7.64%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row3_col6" class="data row3 col6" >6.98%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row3_col7" class="data row3 col7" >$6.61%</td>
#             </tr>
#             <tr>
#                         <th id="T_effe9c70_d114_11ea_928f_acde48001122level0_row4" class="row_heading level0 row4" >Sleet</th>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row4_col0" class="data row4 col0" >0.57%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row4_col1" class="data row4 col1" >0.18%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row4_col2" class="data row4 col2" >0.23%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row4_col3" class="data row4 col3" >0.16%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row4_col4" class="data row4 col4" >$0.12%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row4_col5" class="data row4 col5" >0.17%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row4_col6" class="data row4 col6" >0.23%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row4_col7" class="data row4 col7" >$0.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_effe9c70_d114_11ea_928f_acde48001122level0_row5" class="row_heading level0 row5" >Snow</th>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row5_col0" class="data row5 col0" >13.27%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row5_col1" class="data row5 col1" >1.99%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row5_col2" class="data row5 col2" >1.63%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row5_col3" class="data row5 col3" >2.87%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row5_col4" class="data row5 col4" >$1.69%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row5_col5" class="data row5 col5" >2.82%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row5_col6" class="data row5 col6" >1.97%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row5_col7" class="data row5 col7" >$2.21%</td>
#             </tr>
#             <tr>
#                         <th id="T_effe9c70_d114_11ea_928f_acde48001122level0_row6" class="row_heading level0 row6" >All</th>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row6_col0" class="data row6 col0" >100.00%</td>
#                         <td id="T_effe9c70_d114_11ea_928f_acde48001122row6_col1" class="data row6 col1" >100

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Jahreszeit <a class="anchor" id="tables_jahreszeit_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["Jahreszeit"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f16665f2_d114_11ea_928f_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >Jahreszeit</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f16665f2_d114_11ea_928f_acde48001122level0_row0" class="row_heading level0 row0" >Frühling</th>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row0_col0" class="data row0 col0" >19.45%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row0_col1" class="data row0 col1" >25.46%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row0_col2" class="data row0 col2" >23.84%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row0_col3" class="data row0 col3" >25.88%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row0_col4" class="data row0 col4" >$26.23%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row0_col5" class="data row0 col5" >24.42%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row0_col6" class="data row0 col6" >24.65%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row0_col7" class="data row0 col7" >$25.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_f16665f2_d114_11ea_928f_acde48001122level0_row1" class="row_heading level0 row1" >Herbst</th>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row1_col0" class="data row1 col0" >15.90%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row1_col1" class="data row1 col1" >23.69%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row1_col2" class="data row1 col2" >25.19%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row1_col3" class="data row1 col3" >21.82%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row1_col4" class="data row1 col4" >$21.71%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row1_col5" class="data row1 col5" >22.59%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row1_col6" class="data row1 col6" >23.57%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row1_col7" class="data row1 col7" >$23.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_f16665f2_d114_11ea_928f_acde48001122level0_row2" class="row_heading level0 row2" >Sommer</th>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row2_col0" class="data row2 col0" >19.34%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row2_col1" class="data row2 col1" >27.04%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row2_col2" class="data row2 col2" >27.52%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row2_col3" class="data row2 col3" >25.68%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row2_col4" class="data row2 col4" >$27.78%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row2_col5" class="data row2 col5" >25.58%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row2_col6" class="data row2 col6" >26.47%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row2_col7" class="data row2 col7" >$26.63%</td>
#             </tr>
#             <tr>
#                         <th id="T_f16665f2_d114_11ea_928f_acde48001122level0_row3" class="row_heading level0 row3" >Winter</th>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row3_col0" class="data row3 col0" >45.31%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row3_col1" class="data row3 col1" >23.81%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row3_col2" class="data row3 col2" >23.45%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row3_col3" class="data row3 col3" >26.62%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row3_col4" class="data row3 col4" >$24.28%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row3_col5" class="data row3 col5" >27.41%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row3_col6" class="data row3 col6" >25.31%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row3_col7" class="data row3 col7" >$25.14%</td>
#             </tr>
#             <tr>
#                         <th id="T_f16665f2_d114_11ea_928f_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row4_col4" class="data row4 col4" >$100.00%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_f16665f2_d114_11ea_928f_acde48001122row4_col7" class="data row4 col7" >$100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Temperatur <a class="anchor" id="tables_jahreszpeit_temp"></a>

# %%
freq_tab = pd.crosstab(index=df["TEMP_CLUSTER"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f25686ae_d114_11ea_928f_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >TEMP_CLUSTER</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f25686ae_d114_11ea_928f_acde48001122level0_row0" class="row_heading level0 row0" >Heiß (>= 32° C)</th>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row0_col0" class="data row0 col0" >3.55%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row0_col1" class="data row0 col1" >5.33%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row0_col2" class="data row0 col2" >9.16%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row0_col3" class="data row0 col3" >5.70%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row0_col4" class="data row0 col4" >$6.12%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row0_col5" class="data row0 col5" >4.49%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row0_col6" class="data row0 col6" >8.43%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row0_col7" class="data row0 col7" >$7.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_f25686ae_d114_11ea_928f_acde48001122level0_row1" class="row_heading level0 row1" >Kalt (-30° - 0,01° C)</th>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row1_col0" class="data row1 col0" >36.38%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row1_col1" class="data row1 col1" >11.78%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row1_col2" class="data row1 col2" >9.08%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row1_col3" class="data row1 col3" >16.44%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row1_col4" class="data row1 col4" >$10.51%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row1_col5" class="data row1 col5" >12.29%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row1_col6" class="data row1 col6" >13.28%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row1_col7" class="data row1 col7" >$12.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_f25686ae_d114_11ea_928f_acde48001122level0_row2" class="row_heading level0 row2" >Moderat (0° bis 19,99° C)</th>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row2_col0" class="data row2 col0" >36.38%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row2_col1" class="data row2 col1" >49.13%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row2_col2" class="data row2 col2" >42.14%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row2_col3" class="data row2 col3" >47.34%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row2_col4" class="data row2 col4" >$49.02%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row2_col5" class="data row2 col5" >49.34%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row2_col6" class="data row2 col6" >46.91%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row2_col7" class="data row2 col7" >$47.11%</td>
#             </tr>
#             <tr>
#                         <th id="T_f25686ae_d114_11ea_928f_acde48001122level0_row3" class="row_heading level0 row3" >Sehr Kalt (-45° - 30,01° C)</th>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row3_col0" class="data row3 col0" >0.57%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row3_col1" class="data row3 col1" >0.05%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row3_col2" class="data row3 col2" >0.00%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row3_col3" class="data row3 col3" >0.09%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row3_col4" class="data row3 col4" >$0.02%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row3_col5" class="data row3 col5" >0.00%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row3_col6" class="data row3 col6" >0.03%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row3_col7" class="data row3 col7" >$0.05%</td>
#             </tr>
#             <tr>
#                         <th id="T_f25686ae_d114_11ea_928f_acde48001122level0_row4" class="row_heading level0 row4" >Warm (20° bis 31,99° C)</th>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row4_col0" class="data row4 col0" >23.11%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row4_col1" class="data row4 col1" >33.71%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row4_col2" class="data row4 col2" >39.63%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row4_col3" class="data row4 col3" >30.44%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row4_col4" class="data row4 col4" >$34.34%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row4_col5" class="data row4 col5" >33.89%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row4_col6" class="data row4 col6" >31.35%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row4_col7" class="data row4 col7" >$32.86%</td>
#             </tr>
#             <tr>
#                         <th id="T_f25686ae_d114_11ea_928f_acde48001122level0_row5" class="row_heading level0 row5" >All</th>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row5_col0" class="data row5 col0" >100.00%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row5_col1" class="data row5 col1" >100.00%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row5_col2" class="data row5 col2" >100.00%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row5_col3" class="data row5 col3" >100.00%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row5_col4" class="data row5 col4" >$100.00%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row5_col5" class="data row5 col5" >100.00%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row5_col6" class="data row5 col6" >100.00%</td>
#                         <td id="T_f25686ae_d114_11ea_928f_acde48001122row5_col7" class="data row5 col7" >$100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Boxenplots und Histogramme <a class="anchor" id="boxenplots"></a>

# %% [markdown]
# #### Boxenplot Infrastrukturschaden (ohne Ausreißer) <a class="anchor" id="infrastrukturdmg"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
plt.yscale("log")
ax.set_ylabels("Infrastrukturschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Infrastrukturschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Infrastrukturschaden (ohne Ausreißer)¶

# %%
df['INFRASTRUCTURE_DMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Infrastrukturschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Materialschaden (ohne Ausreißer) <a class="anchor" id="EQPDMG"></a>

# %%
ax = sns.catplot(y='EQPDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
plt.yscale("log")
ax.set_ylabels("Materialschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Materialschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Materialschaden (ohne Ausreißer)¶

# %%
df['EQPDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Materialschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Streckenchaden (ohne Ausreißer) <a class="anchor" id="TRKDMG"></a>

# %%
ax = sns.catplot(y='TRKDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Streckenschaden in Dollar")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Streckenschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Materialschaden (ohne Ausreißer)¶

# %%
df['TRKDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Streckenschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Zuggeschwindigkeit <a class="anchor" id="zuggeschwindigkeit"></a>

# %%
ax = sns.catplot(y='SPEED', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Geschwindigkeit des Zuges")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Zuggeschwindigkeit.png')

# %% [markdown]
# #### Histogramm Zuggeschwindigkeit

# %%
df['SPEED'].hist(bins=50)
plt.savefig('Images/Histogramm_Zuggeschwindigkeit.png')

# %% [markdown]
# #### Boxenplot Zuggewicht <a class="anchor" id="tons"></a>

# %%
ax = sns.catplot(y='TONS', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Gewicht des Zuges")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Zuggewicht.png')

# %% [markdown]
# #### Histogramm Zuggewicht

# %%
df['TONS'].hist(bins=50)
plt.savefig('Images/Histogramm_Zuggewicht.png')

# %% [markdown]
# #### Boxenplot Zugart und Geschwindigkeit <a class="anchor" id="zugart"></a>

# %%
ax = sns.catplot(y='SPEED', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Geschwindigkeit des Zuges")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Geschwindigkeit_Zugart.png')

# %% [markdown]
# #### Boxenplot Zugart und Gewicht

# %%
ax = sns.catplot(y='TONS', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Gewicht in t(ohne Lokomotiven)")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Gewicht_Zugart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Zugart

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Infrastruktur_Zugart.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Zugart

# %%
ax = sns.catplot(y='EQPDMG', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Material_Zugart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallart <a class="anchor" id="unfallart"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCIDENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallart")
plt.savefig('Images/Boxplot_Infrastruktur_Unfallart.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallart

# %%
ax = sns.catplot(y='EQPDMG', x='ACCIDENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallart")
plt.savefig('Images/Boxplot_Material_Unfallart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallursache <a class="anchor" id="cause"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCCAUSE_LVL2', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallursache")
plt.savefig('Images/Boxplot_Infrastruktur_Unfallursache.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallursache

# %%
ax = sns.catplot(y='EQPDMG', x='ACCCAUSE_LVL2', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallursache")
plt.savefig('Images/Boxplot_Material_Unfallursache.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallschwere <a class="anchor" id="unfallsignifikanz"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCTYPE', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallschwere")
plt.savefig('Images/Boxplot_Infrastruktur_Unfallschwere.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallschwere

# %%
ax = sns.catplot(y='EQPDMG', x='ACCTYPE', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallschwere")
plt.savefig('Images/Boxplot_Material_Unfallschwere.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Wetter <a class="anchor" id="wetter"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='WEATHER', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Wetter")
plt.savefig('Images/Boxplot_Infrastruktur_Wetter.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Wetter

# %%
ax = sns.catplot(y='EQPDMG', x='WEATHER', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Wetter")
plt.savefig('Images/Boxplot_Material_Wetter.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahreszeit <a class="anchor" id="jahreszeit"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='Jahreszeit', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Infrastruktur_Jahreszeit.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahreszeit (nach Unfallursache)

# %%
bp = sns.catplot(y='INFRASTRUCTURE_DMG', x='Jahreszeit', data=df, palette="colorblind", hue='ACCCAUSE_LVL2', kind="boxen", legend=False, height=10, aspect=1.5)
plt.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=3, frameon=False)
bp.set_ylabels("Infrastrukturschaden in Dollar")
bp.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Infrastruktur_Ursache_Sommer.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahreszeit

# %%
ax = sns.catplot(y='EQPDMG', x='Jahreszeit', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Material_Jahreszeit.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahreszeit (nach Unfallursache)

# %%
bp = sns.catplot(y='EQPDMG', x='Jahreszeit', data=df, palette="colorblind", hue='ACCCAUSE_LVL2', kind="boxen", legend=False, height=10, aspect=1.5)
plt.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=3, frameon=False)
bp.set_ylabels("Materialschaden in Dollar")
bp.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Material_Ursache_Sommer.png')
plt.show()

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahr <a class="anchor" id="jahr"></a>

# %%
bp = sns.catplot(x="YEAR4", y="INFRASTRUCTURE_DMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Infrastrukturschaden in Dollar', fontsize=12)
plt.savefig('Images/Boxplot_Infrastruktur_Jahr.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahr

# %%
bp = sns.catplot(x="YEAR4", y="EQPDMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Materialschaden in Dollar', fontsize=12)
plt.savefig('Images/Boxplot_Material_Jahr.png')

# %% [markdown]
# #### Boxenplot Streckenschaden und Jahr

# %%
bp = sns.catplot(x="YEAR4", y="TRKDMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Streckenschaden in Dollar', fontsize=12)
plt.savefig('Images/Boxplot_Strecke_Jahr.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Temperatur <a class="anchor" id="temp"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='TEMP_CLUSTER', data=df, palette="colorblind", order=temp_order, kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Temperatur")
plt.savefig('Images/Boxplot_Infrastruktur_Temperatur.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Temperatur

# %%
ax = sns.catplot(y='EQPDMG', x='TEMP_CLUSTER', data=df, palette="colorblind", order=temp_order, kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Temperatur")
plt.savefig('Images/Boxplot_Material_Temperatur.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Zug zu schnell? <a class="anchor" id="speed"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='SPD_TOO_HIGH', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Zug zu schnell?")
plt.savefig('Images/Boxplot_Infrastruktur_Zug_zu_schnell.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Zug zu schnell?

# %%
ax = sns.catplot(y='EQPDMG', x='SPD_TOO_HIGH', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Zug zu schnell?")
plt.savefig('Images/Boxplot_Material_Zug_zu_schnell.png')

# %% [markdown]
# ### Common Statistics <a class="anchor" id="common_statistics"></a>

# %%
x_data = df[['YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'TEMP_CLUSTER', 'SPEED', 'ACCCAUSE_LVL1', 'ACCIDENT_TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']]
y = df['INFRASTRUCTURE_DMG']

# %%
x_data.describe(include=np.number, percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
#               YEAR4         MONTH  LOCOMOTIVES1        LOADF1        LOADP1  \
# count  59882.000000  59882.000000  59882.000000  59882.000000  59882.000000
# mean    2001.473398      6.442170      2.412311     36.506980      0.131292
# std        9.796880      3.433553      1.262734     34.678279      0.811276
# min     1985.000000      1.000000      0.000000      0.000000      0.000000
# 10%     1988.000000      2.000000      1.000000      0.000000      0.000000
# 20%     1991.000000      3.000000      1.000000      4.000000      0.000000
# 30%     1995.000000      4.000000      2.000000     11.000000      0.000000
# 40%     1999.000000      5.000000      2.000000     18.000000      0.000000
# 50%     2002.000000      6.000000      2.000000     27.000000      0.000000
# 60%     2004.000000      8.000000      2.000000     37.000000      0.000000
# 70%     2007.000000      9.000000      3.000000     50.000000      0.000000
# 80%     2011.000000     10.000000      3.000000     65.000000      0.000000
# 90%     2015.000000     11.000000      4.000000     90.000000      0.000000
# max     2020.000000     12.000000      7.000000    161.000000      7.000000
#
#             EMPTYF1       EMPTYP1  LOCOMOTIVES2        LOADF2       EMPTYF2  \
# count  59882.000000  59882.000000  59882.000000  59882.000000  59882.000000
# mean      16.929344      0.013477      0.133362      2.771150      1.052954
# std       24.677152      0.176817      0.424311      3.487399      2.064600
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 10%        0.000000      0.000000      0.000000      0.000000      0.000000
# 20%        0.000000      0.000000      0.000000      0.000000      0.000000
# 30%        0.000000      0.000000      0.000000      0.000000      0.000000
# 40%        1.000000      0.000000      0.000000      1.000000      0.000000
# 50%        4.000000      0.000000      0.000000      2.000000      0.000000
# 60%       11.000000      0.000000      0.000000      3.000000      0.000000
# 70%       20.000000      0.000000      0.000000      4.000000      1.000000
# 80%       32.000000      0.000000      0.000000      5.000000      2.000000
# 90%       53.000000      0.000000      1.000000      7.000000      4.000000
# max      116.000000      3.000000      2.000000     20.000000     12.000000
#
#                TONS         SPEED
# count  59882.000000  59882.000000
# mean    4770.290827     13.964400
# std     4588.919690     15.703166
# min        0.000000      0.000000
# 10%      217.676946      3.000000
# 20%      955.000000      4.000000
# 30%     1800.000000      5.000000
# 40%     2666.857954      6.000000
# 50%     3566.000000      7.000000
# 60%     4711.000000      9.000000
# 70%     6049.000000     10.000000
# 80%     7861.000000     23.000000
# 90%    10980.700000     40.000000
# max    96140.000000    135.000000

# %%
x_data.describe(include=np.object, percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
#                      TEMP_CLUSTER   ACCCAUSE_LVL1 ACCIDENT_TYPE  \
# count                       59882           59882         59882
# unique                          5              31             4
# top     Moderat (0° bis 19,99° C)  Track Geometry    Derailment
# freq                        28213            9594         50766
#
#        EQUIPMENT_TYPE TYPTRK VISIBLTY WEATHER  STATE          ACCTYPE  \
# count           59882  59882    59882   59855  59882            59882
# unique              8      4        4       6     56                2
# top     Freight Train   Yard      Day   Clear     48  Not Significant
# freq            36741  27378    30569   39470   7113            51012
#
#        Jahreszeit
# count       59882
# unique          4
# top        Sommer
# freq        15944

# %%
y.describe(include='all', percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
# count    5.988200e+04
# mean     7.122166e+04
# std      1.423726e+05
# min      3.300000e+01
# 10%      8.609000e+03
# 20%      1.110000e+04
# 30%      1.414730e+04
# 40%      1.815580e+04
# 50%      2.389400e+04
# 60%      3.250000e+04
# 70%      4.800000e+04
# 80%      7.880880e+04
# 90%      1.642422e+05
# max      1.476346e+06
# Name: INFRASTRUCTURE_DMG, dtype: float64

# %%
ax = sns.jointplot(x='SPEED', y='INFRASTRUCTURE_DMG', data=df, kind='hex', gridsize=20)

# %%
ax = sns.jointplot(x='TONS', y='INFRASTRUCTURE_DMG', data=df, kind='hex', gridsize=20)

# %% [markdown]
# ### Scattermatrix und Korrelationen der Daten <a class="anchor" id="correlations"></a>
# Jahr, Monat, Anzahl der beladenen Frachtwagons und Personenwagons, Gewicht, Temperatur, Geschwindigkeit und Unfallkosten

# %%
#sm = scatter_matrix(df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'SPEED']], diagonal='kde', figsize=(18, 18))
#n = len(df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'SPEED']].columns)
#for x in range(n):
#    for y in range(n):
#        # to get the axis of subplots
#        ax = sm[x, y]
#        # to make x axis name vertical  
#        ax.xaxis.label.set_rotation(-90)
#        # to make y axis name horizontal 
#        ax.yaxis.label.set_rotation(0)
#        # to make sure y axis names are outside the plot area
#        ax.yaxis.labelpad = 50
#plt.savefig(r"Images/scatterALL.png")

# %%
colormap = plt.cm.RdBu
corr = df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'TEMP_CLUSTER', 'SPEED', 'ACCCAUSE_LVL1', 'TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']].corr()
corr
# Out:
#                     INFRASTRUCTURE_DMG    EQPDMG    TRKDMG     YEAR4  \
# INFRASTRUCTURE_DMG            1.000000  0.851378  0.702930  0.123177
# EQPDMG                        0.851378  1.000000  0.287665  0.083709
# TRKDMG                        0.702930  0.287665  1.000000  0.113659
# YEAR4                         0.123177  0.083709  0.113659  1.000000
# MONTH                        -0.006337 -0.002274 -0.010059 -0.015141
# LOCOMOTIVES1                  0.140241  0.107027  0.120975 -0.072825
# LOADF1                        0.253544  0.201690  0.208687 -0.024037
# LOADP1                       -0.002518  0.024653 -0.047167  0.041851
# EMPTYF1                      -0.009291 -0.013223 -0.000154 -0.008849
# EMPTYP1                      -0.000718  0.007403 -0.013300  0.011376
# LOCOMOTIVES2                  0.021267  0.031056 -0.003783  0.079794
# LOADF2                        0.431440  0.446263  0.232457 -0.120370
# EMPTYF2                       0.082626  0.099667  0.028198 -0.031005
# TONS                          0.247846  0.195067  0.205716  0.009649
# SPEED                         0.229706  0.219549  0.143021 -0.018956
# SPD_TOO_HIGH                  0.030831  0.035324  0.003727 -0.088132
#
#                        MONTH  LOCOMOTIVES1    LOADF1    LOADP1   EMPTYF1  \
# INFRASTRUCTURE_DMG -0.006337      0.140241  0.253544 -0.002518 -0.009291
# EQPDMG             -0.002274      0.107027  0.201690  0.024653 -0.013223
# TRKDMG             -0.010059      0.120975  0.208687 -0.047167 -0.000154
# YEAR4              -0.015141     -0.072825 -0.024037  0.041851 -0.008849
# MONTH               1.000000      0.005554  0.006389 -0.000614  0.007705
# LOCOMOTIVES1        0.005554      1.000000  0.405165 -0.146398  0.171008
# LOADF1              0.006389      0.405165  1.000000 -0.170051 -0.109276
# LOADP1             -0.000614     -0.146398 -0.170051  1.000000 -0.110936
# EMPTYF1             0.007705      0.171008 -0.109276 -0.110936  1.000000
# EMPTYP1             0.007294     -0.074551 -0.076224  0.058098 -0.050677
# LOCOMOTIVES2       -0.005263      0.033671 -0.118474 -0.009581 -0.073350
# LOADF2             -0.013561      0.192803  0.432062 -0.128279 -0.172901
# EMPTYF2             0.003545      0.060652 -0.134532 -0.082368  0.441472
# TONS                0.002726      0.384525  0.855556 -0.160871  0.067727
# SPEED              -0.002420      0.110099  0.092147  0.380418  0.042368
# SPD_TOO_HIGH        0.006080      0.019871  0.007699 -0.013143 -0.008765
#
#                      EMPTYP1  LOCOMOTIVES2    LOADF2   EMPTYF2      TONS  \
# INFRASTRUCTURE_DMG -0.000718      0.021267  0.431440  0.082626  0.247846
# EQPDMG              0.007403      0.031056  0.446263  0.099667  0.195067
# TRKDMG             -0.013300     -0.003783  0.232457  0.028198  0.205716
# YEAR4               0.011376      0.079794 -0.120370 -0.031005  0.009649
# MONTH               0.007294     -0.005263 -0.013561  0.003545  0.002726
# LOCOMOTIVES1       -0.074551      0.033671  0.192803  0.060652  0.384525
# LOADF1             -0.076224     -0.118474  0.432062 -0.134532  0.855556
# LOADP1              0.058098     -0.009581 -0.128279 -0.082368 -0.160871
# EMPTYF1            -0.050677     -0.073350 -0.172901  0.441472  0.067727
# EMPTYP1             1.000000      0.035253 -0.057396 -0.035990 -0.074693
# LOCOMOTIVES2        0.035253      1.000000 -0.122803 -0.076364 -0.111799
# LOADF2             -0.057396     -0.122803  1.000000 -0.111897  0.364108
# EMPTYF2            -0.035990     -0.076364 -0.111897  1.000000 -0.045546
# TONS               -0.074693     -0.111799  0.364108 -0.045546  1.000000
# SPEED               0.007775     -0.056122 -0.024929 -0.048009  0.066354
# SPD_TOO_HIGH        0.002793      0.001909  0.044637  0.007191 -0.001492
#
#                        SPEED  SPD_TOO_HIGH
# INFRASTRUCTURE_DMG  0.229706      0.030831
# EQPDMG              0.219549      0.035324
# TRKDMG              0.143021      0.003727
# YEAR4              -0.018956     -0.088132
# MONTH              -0.002420      0.006080
# LOCOMOTIVES1        0.110099      0.019871
# LOADF1              0.092147      0.007699
# LOADP1              0.380418     -0.013143
# EMPTYF1             0.042368     -0.008765
# EMPTYP1             0.007775      0.002793
# LOCOMOTIVES2       -0.056122      0.001909
# LOADF2             -0.024929      0.044637
# EMPTYF2            -0.048009      0.007191
# TONS                0.066354     -0.001492
# SPEED               1.000000      0.104537
# SPD_TOO_HIGH        0.104537      1.000000

# %%
ax=plt.figure(figsize=(20,15)).gca()
ax=sns.heatmap(corr,ax=ax,linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True);
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.savefig(r"Images/corrALL.png")

# %%
corr = df[df['TONS']!=0][['TONS', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1', 'LOADF2', 'EMPTYF2']].corr()
corr
# Out:
#              TONS    LOADF1    LOADP1   EMPTYF1   EMPTYP1    LOADF2   EMPTYF2
# TONS     1.000000  0.849484 -0.170591  0.042719 -0.079135  0.344532 -0.066758
# LOADF1   0.849484  1.000000 -0.180139 -0.139938 -0.080777  0.414525 -0.158349
# LOADP1  -0.170591 -0.180139  1.000000 -0.116096  0.057708 -0.134664 -0.085866
# EMPTYF1  0.042719 -0.139938 -0.116096  1.000000 -0.053019 -0.196973  0.434489
# EMPTYP1 -0.079135 -0.080777  0.057708 -0.053019  1.000000 -0.060280 -0.037568
# LOADF2   0.344532  0.414525 -0.134664 -0.196973 -0.060280  1.000000 -0.128968
# EMPTYF2 -0.066758 -0.158349 -0.085866  0.434489 -0.037568 -0.128968  1.000000

# %% [markdown]
# ### ANOVA <a class="anchor" id="ANOVA"></a>

# %%
anova_df =df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'TEMP_CLUSTER', 'ACCCAUSE_LVL1', 'ACCCAUSE_LVL2', 'ACCIDENT_TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']]

# %%
anova = anova_df.copy()
anova = anova.dropna

# %%
def anova(dmg, cat):
    #print ("ANOVA für INFRASTRUCUTURE_DMG ~ %s :" % (cat))
    mod= ols(dmg + ' ~ ' + cat , data=anova_df).fit()
    anova_table = sm.stats.anova_lm(mod, typ=2)
    esq_sm = anova_table['sum_sq'][0]/(anova_table['sum_sq'][0]+anova_table['sum_sq'][1])
    anova_table['EtaSq'] = [esq_sm, 'NaN']
    anova_table
    pair_t = mod.t_test_pairwise(cat)
    anova_table
    pair_t.result_frame
    return [anova_table, pair_t.result_frame]

# %% [markdown]
# #### ANOVA Korrelation Temperatur Cluster und Damage

# %%
temp_cluster = anova("INFRASTRUCTURE_DMG","TEMP_CLUSTER")

# %%
temp_cluster[0]
# Out:
#                     sum_sq       df          F        PR(>F)       EtaSq
# TEMP_CLUSTER  3.152244e+12      4.0  38.976909  1.217152e-32  0.00259704
# Residual      1.210633e+15  59877.0        NaN           NaN         NaN

# %%
temp_cluster[1]
# Out:
#                                                                coef  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                  -3921.153504
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)             -19804.482267
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)            -7172.112381
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)               -21431.424371
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)       -15883.328763
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      -3250.958877
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)         -17510.270867
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  12632.369886
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)      -1626.942103
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)   -14259.311990
#
#                                                             std err         t  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                   2723.561411 -1.439715
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               2351.724973 -8.421258
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)            26961.250061 -0.266016
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 2416.929202 -8.867212
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)         1822.213837 -8.716501
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      26920.231384 -0.120763
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           1905.623176 -9.188737
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  26885.157268  0.469864
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)       1320.690454 -1.231888
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)    26890.939325 -0.530265
#
#                                                               P>|t|  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                  1.499531e-01
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)              3.805850e-17
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)            7.902281e-01
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                7.700944e-19
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)        2.941103e-18
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      9.038794e-01
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)          4.097637e-20
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  6.384538e-01
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)      2.179959e-01
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)    5.959305e-01
#
#                                                        Conf. Int. Low  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                    -9259.343687
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               -24413.871691
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)             -60016.259679
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 -26168.614318
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)         -19454.874453
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)       -56014.709420
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           -21245.299159
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)   -40062.635264
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)        -4215.500154
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)     -66965.649992
#
#                                                        Conf. Int. Upp.  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                      1417.036678
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)                -15195.092844
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)               45672.034917
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                  -16694.234424
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)          -12311.783074
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)         49512.791666
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)            -13775.242574
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)     65327.375037
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)           961.615947
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)       38447.026012
#
#                                                        pvalue-hs  reject-hs
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                   0.622726      False
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               0.000000       True
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)             0.973342      False
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 0.000000       True
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)         0.000000       True
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)       0.973342      False
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           0.000000       True
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)   0.973342      False
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)       0.707554      False
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)     0.973342      False

# %% [markdown]
# #### ANOVA Korrelation Unfallursachen Cluster und Damage

# %%
cause = anova("INFRASTRUCTURE_DMG","ACCCAUSE_LVL2")

# %%
cause[0]
# Out:
#                      sum_sq       df           F         PR(>F)      EtaSq
# ACCCAUSE_LVL2  2.496806e+13      6.0  209.586853  1.096686e-265  0.0205704
# Residual       1.188817e+15  59875.0         NaN            NaN        NaN

# %%
cause[1]
# Out:
#                                                                           coef  \
# Human Factors-Environmental Conditions                           -91032.853458
# Loading-Environmental Conditions                                 -86647.700636
# Mechanical and Electrical Failures-Environmental Conditions      -34555.793740
# Miscellaneous Causes-Environmental Conditions                    -76688.019794
# Signal and Communication-Environmental Conditions                -96572.812923
# Track, Roadbed and Structures-Environmental Conditions           -62390.025713
# Loading-Human Factors                                              4385.152821
# Mechanical and Electrical Failures-Human Factors                  56477.059718
# Miscellaneous Causes-Human Factors                                14344.833664
# Signal and Communication-Human Factors                            -5539.959466
# Track, Roadbed and Structures-Human Factors                       28642.827744
# Mechanical and Electrical Failures-Loading                        52091.906896
# Miscellaneous Causes-Loading                                       9959.680843
# Signal and Communication-Loading                                  -9925.112287
# Track, Roadbed and Structures-Loading                             24257.674923
# Miscellaneous Causes-Mechanical and Electrical Failures          -42132.226054
# Signal and Communication-Mechanical and Electrical Failures      -62017.019184
# Track, Roadbed and Structures-Mechanical and Electrical Failures -27834.231974
# Signal and Communication-Miscellaneous Causes                    -19884.793130
# Track, Roadbed and Structures-Miscellaneous Causes                14297.994080
# Track, Roadbed and Structures-Signal and Communication            34182.787210
#
#                                                                       std err  \
# Human Factors-Environmental Conditions                            4901.740938
# Loading-Environmental Conditions                                  5094.375318
# Mechanical and Electrical Failures-Environmental Conditions       5013.851616
# Miscellaneous Causes-Environmental Conditions                     5119.379615
# Signal and Communication-Environmental Conditions                 7463.180559
# Track, Roadbed and Structures-Environmental Conditions            4855.142954
# Loading-Human Factors                                             2131.897327
# Mechanical and Electrical Failures-Human Factors                  1931.588559
# Miscellaneous Causes-Human Factors                                2190.975578
# Signal and Communication-Human Factors                            5855.885107
# Track, Roadbed and Structures-Human Factors                       1471.305353
# Mechanical and Electrical Failures-Loading                        2378.367090
# Miscellaneous Causes-Loading                                      2593.447442
# Signal and Communication-Loading                                  6018.055005
# Track, Roadbed and Structures-Loading                             2022.457687
# Miscellaneous Causes-Mechanical and Electrical Failures           2431.464123
# Signal and Communication-Mechanical and Electrical Failures       5950.044890
# Track, Roadbed and Structures-Mechanical and Electrical Failures  1810.078242
# Signal and Communication-Miscellaneous Causes                     6039.236194
# Track, Roadbed and Structures-Miscellaneous Causes                2084.639744
# Track, Roadbed and Structures-Signal and Communication            5816.935557
#
#                                                                           t  \
# Human Factors-Environmental Conditions                           -18.571535
# Loading-Environmental Conditions                                 -17.008504
# Mechanical and Electrical Failures-Environmental Conditions       -6.892065
# Miscellaneous Causes-Environmental Conditions                    -14.979944
# Signal and Communication-Environmental Conditions                -12.939900
# Track, Roadbed and Structures-Environmental Conditions           -12.850296
# Loading-Human Factors                                              2.056925
# Mechanical and Electrical Failures-Human Factors                  29.238659
# Miscellaneous Causes-Human Factors                                 6.547236
# Signal and Communication-Human Factors                            -0.946050
# Track, Roadbed and Structures-Human Factors                       19.467630
# Mechanical and Electrical Failures-Loading                        21.902383
# Miscellaneous Causes-Loading                                       3.840325
# Signal and Communication-Loading                                  -1.649223
# Track, Roadbed and Structures-Loading                             11.994157
# Miscellaneous Causes-Mechanical and Electrical Failures          -17.327924
# Signal and Communication-Mechanical and Electrical Failures      -10.422950
# Track, Roadbed and Structures-Mechanical and Electrical Failures -15.377364
# Signal and Communication-Miscellaneous Causes                     -3.292601
# Track, Roadbed and Structures-Miscellaneous Causes                 6.858736
# Track, Roadbed and Structures-Signal and Communication             5.876425
#
#                                                                           P>|t|  \
# Human Factors-Environmental Conditions                             8.984085e-77
# Loading-Environmental Conditions                                   1.008668e-64
# Mechanical and Electrical Failures-Environmental Conditions        5.553007e-12
# Miscellaneous Causes-Environmental Conditions                      1.227003e-50
# Signal and Communication-Environmental Conditions                  3.016108e-38
# Track, Roadbed and Structures-Environmental Conditions             9.612539e-38
# Loading-Human Factors                                              3.969777e-02
# Mechanical and Electrical Failures-Human Factors                  1.295247e-186
# Miscellaneous Causes-Human Factors                                 5.908393e-11
# Signal and Communication-Human Factors                             3.441270e-01
# Track, Roadbed and Structures-Human Factors                        3.766059e-84
# Mechanical and Electrical Failures-Loading                        6.437323e-106
# Miscellaneous Causes-Loading                                       1.229980e-04
# Signal and Communication-Loading                                   9.910729e-02
# Track, Roadbed and Structures-Loading                              4.161318e-33
# Miscellaneous Causes-Mechanical and Electrical Failures            4.224829e-67
# Signal and Communication-Mechanical and Electrical Failures        2.048287e-25
# Track, Roadbed and Structures-Mechanical and Electrical Failures   2.936723e-53
# Signal and Communication-Miscellaneous Causes                      9.932283e-04
# Track, Roadbed and Structures-Miscellaneous Causes                 7.014424e-12
# Track, Roadbed and Structures-Signal and Communication             4.214322e-09
#
#                                                                   Conf. Int. Low  \
# Human Factors-Environmental Conditions                            -100640.283370
# Loading-Environmental Conditions                                   -96632.694628
# Mechanical and Electrical Failures-Environmental Conditions        -44382.960985
# Miscellaneous Causes-Environmental Conditions                      -86722.022299
# Signal and Communication-Environmental Conditions                 -111200.673729
# Track, Roadbed and Structures-Environmental Conditions             -71906.123410
# Loading-Human Factors                                                 206.626373
# Mechanical and Electrical Failures-Human Factors                    52691.139178
# Miscellaneous Causes-Human Factors                                  10050.513631
# Signal and Communication-Human Factors                             -17017.515391
# Track, Roadbed and Structures-Human Factors                         25759.063947
# Mechanical and Electrical Failures-Loading                          47430.298825
# Miscellaneous Causes-Loading                                         4876.514505
# Signal and Communication-Loading                                   -21720.521796
# Track, Roadbed and Structures-Loading                               20293.650565
# Miscellaneous Causes-Mechanical and Electrical Failures            -46897.904502
# Signal and Communication-Mechanical and Electrical Failures        -73679.128622
# Track, Roadbed and Structures-Mechanical and Electrical Failures   -31381.991854
# Signal and Communication-Miscellaneous Causes                      -31721.717847
# Track, Roadbed and Structures-Miscellaneous Causes                  10212.092665
# Track, Roadbed and Structures-Signal and Communication              22781.572544
#
#                                                                   Conf. Int. Upp.  \
# Human Factors-Environmental Conditions                              -81425.423545
# Loading-Environmental Conditions                                    -76662.706645
# Mechanical and Electrical Failures-Environmental Conditions         -24728.626495
# Miscellaneous Causes-Environmental Conditions                       -66654.017289
# Signal and Communication-Environmental Conditions                   -81944.952118
# Track, Roadbed and Structures-Environmental Conditions              -52873.928017
# Loading-Human Factors                                                 8563.679270
# Mechanical and Electrical Failures-Human Factors                     60262.980258
# Miscellaneous Causes-Human Factors                                   18639.153697
# Signal and Communication-Human Factors                                5937.596459
# Track, Roadbed and Structures-Human Factors                          31526.591541
# Mechanical and Electrical Failures-Loading                           56753.514968
# Miscellaneous Causes-Loading                                         15042.847180
# Signal and Communication-Loading                                      1870.297222
# Track, Roadbed and Structures-Loading                                28221.699281
# Miscellaneous Causes-Mechanical and Electrical Failures             -37366.547605
# Signal and Communication-Mechanical and Electrical Failures         -50354.909745
# Track, Roadbed and Structures-Mechanical and Electrical Failures    -24286.472094
# Signal and Communication-Miscellaneous Causes                        -8047.868413
# Track, Roadbed and Structures-Miscellaneous Causes                   18383.895495
# Track, Roadbed and Structures-Signal and Communication               45584.001875
#
#                                                                      pvalue-hs  \
# Human Factors-Environmental Conditions                            0.000000e+00
# Loading-Environmental Conditions                                  0.000000e+00
# Mechanical and Electrical Failures-Environmental Conditions       4.997702e-11
# Miscellaneous Causes-Environmental Conditions                     0.000000e+00
# Signal and Communication-Environmental Conditions                 0.000000e+00
# Track, Roadbed and Structures-Environmental Conditions            0.000000e+00
# Loading-Human Factors                                             1.144281e-01
# Mechanical and Electrical Failures-Human Factors                  0.000000e+00
# Miscellaneous Causes-Human Factors                                4.135877e-10
# Signal and Communication-Human Factors                            3.441270e-01
# Track, Roadbed and Structures-Human Factors                       0.000000e+00
# Mechanical and Electrical Failures-Loading                        0.000000e+00
# Miscellaneous Causes-Loading                                      6.148388e-04
# Signal and Communication-Loading                                  1.883923e-01
# Track, Roadbed and Structures-Loading                             0.000000e+00
# Miscellaneous Causes-Mechanical and Electrical Failures           0.000000e+00
# Signal and Communication-Mechanical and Electrical Failures       0.000000e+00
# Track, Roadbed and Structures-Mechanical and Electrical Failures  0.000000e+00
# Signal and Communication-Miscellaneous Causes                     3.966998e-03
# Track, Roadbed and Structures-Miscellaneous Causes                5.611511e-11
# Track, Roadbed and Structures-Signal and Communication            2.528593e-08
#
#                                                                   reject-hs
# Human Factors-Environmental Conditions                                 True
# Loading-Environmental Conditions                                       True
# Mechanical and Electrical Failures-Environmental Conditions            True
# Miscellaneous Causes-Environmental Conditions                          True
# Signal and Communication-Environmental Conditions                      True
# Track, Roadbed and Structures-Environmental Conditions                 True
# Loading-Human Factors                                                 False
# Mechanical and Electrical Failures-Human Factors                       True
# Miscellaneous Causes-Human Factors                                     True
# Signal and Communication-Human Factors                                False
# Track, Roadbed and Structures-Human Factors                            True
# Mechanical and Electrical Failures-Loading                             True
# Miscellaneous Causes-Loading                                           True
# Signal and Communication-Loading                                      False
# Track, Roadbed and Structures-Loading                                  True
# Miscellaneous Causes-Mechanical and Electrical Failures                True
# Signal and Communication-Mechanical and Electrical Failures            True
# Track, Roadbed and Structures-Mechanical and Electrical Failures       True
# Signal and Communication-Miscellaneous Causes                          True
# Track, Roadbed and Structures-Miscellaneous Causes                     True
# Track, Roadbed and Structures-Signal and Communication                 True

# %% [markdown]
# #### ANOVA Korrelation Unfallart und Damage

# %%
accidenttype = anova("INFRASTRUCTURE_DMG","ACCIDENT_TYPE")

# %%
accidenttype[0]
# Out:
#                      sum_sq       df         F        PR(>F)       EtaSq
# ACCIDENT_TYPE  3.676389e+12      3.0  60.63775  3.904000e-39  0.00302886
# Residual       1.210109e+15  59878.0       NaN           NaN         NaN

# %%
accidenttype[1]
# Out:
#                                                               coef  \
# Crossing-Collision                                    -9977.868407
# Derailment-Collision                                  15631.247903
# Fire/violent rupture/Explosive Detonation-Collision   20087.101580
# Derailment-Crossing                                   25609.116311
# Fire/violent rupture/Explosive Detonation-Crossing    30064.969988
# Fire/violent rupture/Explosive Detonation-Derailment   4455.853677
#
#                                                           std err          t  \
# Crossing-Collision                                    3271.240561  -3.050179
# Derailment-Collision                                  2697.116026   5.795542
# Fire/violent rupture/Explosive Detonation-Collision   5432.075064   3.697869
# Derailment-Crossing                                   2054.936784  12.462240
# Fire/violent rupture/Explosive Detonation-Crossing    5143.517262   5.845216
# Fire/violent rupture/Explosive Detonation-Derailment  4798.873813   0.928521
#
#                                                              P>|t|  \
# Crossing-Collision                                    2.288052e-03
# Derailment-Collision                                  6.844145e-09
# Fire/violent rupture/Explosive Detonation-Collision   2.176112e-04
# Derailment-Crossing                                   1.328102e-35
# Fire/violent rupture/Explosive Detonation-Crossing    5.085252e-09
# Fire/violent rupture/Explosive Detonation-Derailment  3.531413e-01
#
#                                                       Conf. Int. Low  \
# Crossing-Collision                                     -16389.511696
# Derailment-Collision                                    10344.890772
# Fire/violent rupture/Explosive Detonation-Collision      9440.214880
# Derailment-Crossing                                     21581.432809
# Fire/violent rupture/Explosive Detonation-Crossing      19983.657618
# Fire/violent rupture/Explosive Detonation-Derailment    -4949.956291
#
#                                                       Conf. Int. Upp.  \
# Crossing-Collision                                       -3566.225118
# Derailment-Collision                                     20917.605035
# Fire/violent rupture/Explosive Detonation-Collision      30733.988281
# Derailment-Crossing                                      29636.799813
# Fire/violent rupture/Explosive Detonation-Crossing       40146.282357
# Fire/violent rupture/Explosive Detonation-Derailment     13861.663644
#
#                                                          pvalue-hs  reject-hs
# Crossing-Collision                                    4.570868e-03       True
# Derailment-Collision                                  2.737658e-08       True
# Fire/violent rupture/Explosive Detonation-Collision   6.526914e-04       True
# Derailment-Crossing                                   0.000000e+00       True
# Fire/violent rupture/Explosive Detonation-Crossing    2.542626e-08       True
# Fire/violent rupture/Explosive Detonation-Derailment  3.531413e-01      False

# %% [markdown]
# #### ANOVA Korrelation Zugart und Damage

# %%
eqtype = anova("INFRASTRUCTURE_DMG","EQUIPMENT_TYPE")

# %%
eqtype[0]
# Out:
#                       sum_sq       df           F  PR(>F)      EtaSq
# EQUIPMENT_TYPE  3.916072e+13      7.0  285.162173     0.0  0.0322633
# Residual        1.174624e+15  59874.0         NaN     NaN        NaN

# %%
eqtype[1]
# Out:
#                                         coef      std err          t  \
# Cut of Cars-Commuter Train     -32985.540121  8632.426899  -3.821120
# Freight Train-Commuter Train    22458.879195  7565.326384   2.968660
# Locomotive-Commuter Train      -35097.416694  8203.244502  -4.278480
# Passenger Train-Commuter Train  -1761.864274  8285.408335  -0.212647
# Single Car-Commuter Train      -40116.359296  9890.836694  -4.055912
# Work Train-Commuter Train       -1946.861282  9502.269728  -0.204884
# Yard/Switching-Commuter Train  -31328.925281  7605.580759  -4.119202
# Freight Train-Cut of Cars       55444.419316  4283.988019  12.942244
# Locomotive-Cut of Cars          -2111.876573  5330.254255  -0.396206
# Passenger Train-Cut of Cars     31223.675847  5455.857525   5.722964
# Single Car-Cut of Cars          -7130.819175  7677.697608  -0.928771
# Work Train-Cut of Cars          31038.678840  7170.182706   4.328855
# Yard/Switching-Cut of Cars       1656.614840  4354.681244   0.380422
# Locomotive-Freight Train       -57556.295889  3335.712750 -17.254572
# Passenger Train-Freight Train  -24220.743470  3532.952089  -6.855667
# Single Car-Freight Train       -62575.238492  6454.642491  -9.694610
# Work Train-Freight Train       -24405.740477  5841.822418  -4.177761
# Yard/Switching-Freight Train   -53787.804476  1295.614860 -41.515273
# Passenger Train-Locomotive      33335.552419  4747.716034   7.021387
# Single Car-Locomotive           -5018.942603  7191.763814  -0.697874
# Work Train-Locomotive           33150.555412  6647.251029   4.987107
# Yard/Switching-Locomotive        3768.491413  3426.029033   1.099959
# Single Car-Passenger Train     -38354.495022  7285.344033  -5.264610
# Work Train-Passenger Train       -184.997007  6748.386263  -0.027414
# Yard/Switching-Passenger Train -29567.061006  3618.348498  -8.171424
# Work Train-Single Car           38169.498015  8644.152728   4.415644
# Yard/Switching-Single Car        8787.434015  6501.777071   1.351543
# Yard/Switching-Work Train      -29382.063999  5893.859903  -4.985199
#
#                                        P>|t|  Conf. Int. Low  Conf. Int. Upp.  \
# Cut of Cars-Commuter Train      1.329811e-04   -49905.127974    -16065.952268
# Freight Train-Commuter Train    2.992201e-03     7630.812200     37286.946191
# Locomotive-Commuter Train       1.884657e-05   -51175.805502    -19019.027885
# Passenger Train-Commuter Train  8.316033e-01   -18001.294492     14477.565943
# Single Car-Commuter Train       5.000232e-05   -59502.434886    -20730.283706
# Work Train-Commuter Train       8.376636e-01   -20571.344217     16677.621654
# Yard/Switching-Commuter Train   3.806965e-05   -46235.890997    -16421.959565
# Freight Train-Cut of Cars       2.925727e-38    47047.787349     63841.051283
# Locomotive-Cut of Cars          6.919548e-01   -12559.194134      8335.440989
# Passenger Train-Cut of Cars     1.051797e-08    20530.175422     41917.176272
# Single Car-Cut of Cars          3.530118e-01   -22179.134175      7917.495825
# Work Train-Cut of Cars          1.501297e-05    16985.094878     45092.262802
# Yard/Switching-Cut of Cars      7.036338e-01    -6878.576102     10191.805782
# Locomotive-Freight Train        1.498766e-66   -64094.304909    -51018.286869
# Passenger Train-Freight Train   7.166572e-12   -31145.342306    -17296.144633
# Single Car-Freight Train        3.300380e-22   -75226.361052    -49924.115931
# Work Train-Freight Train        2.948089e-05   -35855.733485    -12955.747469
# Yard/Switching-Freight Train    0.000000e+00   -56327.214274    -51248.394678
# Passenger Train-Locomotive      2.220062e-12    24030.011871     42641.092967
# Single Car-Locomotive           4.852589e-01   -19114.825615      9076.940409
# Work Train-Locomotive           6.146100e-07    20121.919423     46179.191401
# Yard/Switching-Locomotive       2.713544e-01    -2946.537848     10483.520673
# Single Car-Passenger Train      1.409706e-07   -52633.795600    -24075.194444
# Work Train-Passenger Train      9.781300e-01   -13411.858420     13041.864406
# Yard/Switching-Passenger Train  3.106640e-16   -36659.037112    -22475.084901
# Work Train-Single Car           1.008860e-05    21226.927495     55112.068535
# Yard/Switching-Single Car       1.765265e-01    -3956.072491     21530.940522
# Yard/Switching-Work Train       6.207057e-07   -40934.050665    -17830.077334
#
#                                    pvalue-hs  reject-hs
# Cut of Cars-Commuter Train      1.461820e-03       True
# Freight Train-Commuter Train    2.952231e-02       True
# Locomotive-Commuter Train       2.826612e-04       True
# Passenger Train-Commuter Train  9.972262e-01      False
# Single Car-Commuter Train       5.998629e-04       True
# Work Train-Commuter Train       9.972262e-01      False
# Yard/Switching-Commuter Train   4.947924e-04       True
# Freight Train-Cut of Cars       0.000000e+00       True
# Locomotive-Cut of Cars          9.972262e-01      False
# Passenger Train-Cut of Cars     2.208772e-07       True
# Single Car-Cut of Cars          9.525458e-01      False
# Work Train-Cut of Cars          2.401805e-04       True
# Yard/Switching-Cut of Cars      9.972262e-01      False
# Locomotive-Freight Train        0.000000e+00       True
# Passenger Train-Freight Train   1.576652e-10       True
# Single Car-Freight Train        0.000000e+00       True
# Work Train-Freight Train        4.126534e-04       True
# Yard/Switching-Freight Train    0.000000e+00       True
# Passenger Train-Locomotive      5.106260e-11       True
# Single Car-Locomotive           9.813991e-01      False
# Work Train-Locomotive           1.167753e-05       True
# Yard/Switching-Locomotive       9.205433e-01      False
# Single Car-Passenger Train      2.819409e-06       True
# Work Train-Passenger Train      9.972262e-01      False
# Yard/Switching-Passenger Train  7.993606e-15       True
# Work Train-Single Car           1.714923e-04       True
# Yard/Switching-Single Car       8.258809e-01      False
# Yard/Switching-Work Train       1.167753e-05       True

# %% [markdown]
# #### ANOVA Korrelation Sichtbarkeit und Damage

# %%
vis = anova("INFRASTRUCTURE_DMG","VISIBLTY")

# %%
vis[0]
# Out:
#                 sum_sq       df          F        PR(>F)       EtaSq
# VISIBLTY  1.315148e+12      3.0  21.649598  5.232702e-14  0.00108351
# Residual  1.212470e+15  59878.0        NaN           NaN         NaN

# %%
vis[1]
# Out:
#                    coef      std err         t         P>|t|  Conf. Int. Low  \
# Dawn-Dark  15955.289371  2847.248519  5.603757  2.106741e-08    10374.672013
# Day-Dark   -4591.024683  1234.707734 -3.718309  2.007437e-04    -7011.056290
# Dusk-Dark  -8157.869206  2746.805341 -2.969948  2.979682e-03   -13541.617574
# Day-Dawn  -20546.314054  2811.961483 -7.306755  2.770674e-13   -26057.768694
# Dusk-Dawn -24113.158577  3731.965136 -6.461250  1.046359e-10   -31427.823693
# Dusk-Day   -3566.844523  2710.210847 -1.316076  1.881534e-01    -8878.867551
#
#            Conf. Int. Upp.     pvalue-hs  reject-hs
# Dawn-Dark     21535.906729  8.426962e-08       True
# Day-Dark      -2170.993075  6.021103e-04       True
# Dusk-Dark     -2774.120838  5.950485e-03       True
# Day-Dawn     -15034.859413  1.662670e-12       True
# Dusk-Dawn    -16798.493461  5.231798e-10       True
# Dusk-Day       1745.178504  1.881534e-01      False

# %% [markdown]
# #### ANOVA Korrelation Wetter und Damage

# %%
weather = anova("INFRASTRUCTURE_DMG","WEATHER")

# %%
weather[0]
# Out:
#                 sum_sq       df         F    PR(>F)        EtaSq
# WEATHER   2.921503e+11      5.0  2.881965  0.013213  0.000240712
# Residual  1.213402e+15  59849.0       NaN       NaN          NaN

# %%
weather[1]
# Out:
#                       coef       std err         t     P>|t|  Conf. Int. Low  \
# Cloudy-Clear   -574.352745   1391.090441 -0.412880  0.679696    -3300.895050
# Fog-Clear      8785.296033   5351.025701  1.641797  0.100637    -1702.733727
# Rain-Clear      459.286899   2374.035904  0.193462  0.846597    -4193.832074
# Sleet-Clear    3428.145576  12964.202729  0.264432  0.791448   -21981.738742
# Snow-Clear    13331.366048   3981.182030  3.348595  0.000813     5528.234845
# Fog-Cloudy     9359.648778   5435.188806  1.722047  0.085066    -1293.340974
# Rain-Cloudy    1033.639644   2558.094562  0.404066  0.686165    -3980.234964
# Sleet-Cloudy   4002.498322  12999.167424  0.307904  0.758156   -21475.916925
# Snow-Cloudy   13905.718793   4093.606193  3.396936  0.000682     5882.235823
# Rain-Fog      -8326.009134   5765.604151 -1.444083  0.148721   -19626.614158
# Sleet-Fog     -5357.150457  13988.448704 -0.382970  0.701744   -32774.560596
# Snow-Fog       4546.070014   6592.113098  0.689623  0.490434    -8374.495541
# Sleet-Rain     2968.858677  13140.748364  0.225928  0.821258   -22787.055725
# Snow-Rain     12872.079148   4523.110161  2.845847  0.004431     4006.766846
# Snow-Sleet     9903.220471  13523.795009  0.732281  0.464000   -16603.466743
#
#               Conf. Int. Upp.  pvalue-hs  reject-hs
# Cloudy-Clear      2152.189559   0.999654      False
# Fog-Clear        19273.325793   0.688626      False
# Rain-Clear        5112.405873   0.999654      False
# Sleet-Clear      28838.029894   0.999654      False
# Snow-Clear       21134.497250   0.011318       True
# Fog-Cloudy       20012.638530   0.655907      False
# Rain-Cloudy       6047.514253   0.999654      False
# Sleet-Cloudy     29480.913568   0.999654      False
# Snow-Cloudy      21929.201763   0.010180       True
# Rain-Fog          2974.595890   0.800143      False
# Sleet-Fog        22060.259683   0.999654      False
# Snow-Fog         17466.635570   0.996348      False
# Sleet-Rain       28724.773080   0.999654      False
# Snow-Rain        21737.391450   0.056094      False
# Snow-Sleet       36409.907685   0.996348      False

# %% [markdown]
# #### ANOVA Korrelation zu hoher Geschwindigkeit und Damage

# %%
spd = anova("INFRASTRUCTURE_DMG","SPD_TOO_HIGH")

# %%
spd[0]
# Out:
#                     sum_sq       df         F        PR(>F)        EtaSq
# SPD_TOO_HIGH  1.153734e+12      1.0  56.97166  4.483777e-14  0.000950526
# Residual      1.212631e+15  59880.0       NaN           NaN          NaN

# %%
spd[1]
# Out:
#                    coef      std err         t         P>|t|  Conf. Int. Low  \
# True-False  24536.35037  3250.727226  7.547957  4.483777e-14    18164.913297
#
#             Conf. Int. Upp.     pvalue-hs  reject-hs
# True-False     30907.787443  4.485301e-14       True

# %% [markdown]
# #### ANOVA Korrelation Streckenart und Damage

# %%
typtrk = anova("INFRASTRUCTURE_DMG","TYPTRK")

# %%
typtrk[0]
# Out:
#                 sum_sq       df            F  PR(>F)      EtaSq
# TYPTRK    8.092342e+13      3.0  1425.750132     0.0  0.0666703
# Residual  1.132862e+15  59878.0          NaN     NaN        NaN

# %%
typtrk[1]
# Out:
#                          coef      std err          t         P>|t|  \
# Main-Industry    77568.016392  2003.222955  38.721609  0.000000e+00
# Siding-Industry  33263.570342  3379.191373   9.843648  7.599127e-23
# Yard-Industry     2045.363841  1981.617694   1.032169  3.019972e-01
# Siding-Main     -44304.446050  2993.378360 -14.800817  1.770537e-49
# Yard-Main       -75522.652550  1211.688224 -62.328453  0.000000e+00
# Yard-Siding     -31218.206501  2978.962988 -10.479555  1.128819e-25
#
#                  Conf. Int. Low  Conf. Int. Upp.  pvalue-hs  reject-hs
# Main-Industry      73641.692181     81494.340602   0.000000       True
# Siding-Industry    26640.343072     39886.797611   0.000000       True
# Yard-Industry      -1838.613979      5929.341662   0.301997      False
# Siding-Main       -50171.478423    -38437.413676   0.000000       True
# Yard-Main         -77897.565837    -73147.739264   0.000000       True
# Yard-Siding       -37056.984693    -25379.428308   0.000000       True

# %% [markdown]
# #### ANOVA Korrelation Signifikanzlevel und Damage

# %%
acctype = anova("INFRASTRUCTURE_DMG","ACCTYPE")

# %%
acctype[0]
# Out:
#                 sum_sq       df             F  PR(>F)     EtaSq
# ACCTYPE   4.439262e+14      1.0  34528.804644     0.0  0.365737
# Residual  7.698588e+14  59880.0           NaN     NaN       NaN

# %%
acctype[1]
# Out:
#                                      coef     std err          t  P>|t|  \
# Significant-Not Significant  242384.90551  1304.41204  185.81928    0.0
#
#                              Conf. Int. Low  Conf. Int. Upp.  pvalue-hs  \
# Significant-Not Significant   239828.253213    244941.557808        0.0
#
#                              reject-hs
# Significant-Not Significant       True

# %% [markdown]
# #### ANOVA Korrelation Jahreszeit und Damage

# %%
jahreszeit = anova("INFRASTRUCTURE_DMG","Jahreszeit")

# %%
jahreszeit[0]
# Out:
#                   sum_sq       df         F   PR(>F)        EtaSq
# Jahreszeit  2.237357e+11      3.0  3.679761  0.01152  0.000184329
# Residual    1.213561e+15  59878.0       NaN      NaN          NaN

# %%
jahreszeit[1]
# Out:
#                         coef      std err         t     P>|t|  Conf. Int. Low  \
# Herbst-Frühling -3570.841853  1676.411174 -2.130051  0.033171    -6856.613797
# Sommer-Frühling  1800.773818  1619.992186  1.111594  0.266317    -1374.416704
# Winter-Frühling -1097.662449  1643.077798 -0.668053  0.504103    -4318.100854
# Sommer-Herbst    5371.615671  1651.751105  3.252073  0.001146     2134.177552
# Winter-Herbst    2473.179405  1674.398902  1.477055  0.139666     -808.648477
# Winter-Sommer   -2898.436267  1617.909744 -1.791470  0.073223    -6069.545195
#
#                  Conf. Int. Upp.  pvalue-hs  reject-hs
# Herbst-Frühling      -285.069910   0.155213      False
# Sommer-Frühling      4975.964340   0.461709      False
# Winter-Frühling      2122.775956   0.504103      False
# Sommer-Herbst        8609.053790   0.006858       True
# Winter-Herbst        5755.007286   0.363203      False
# Winter-Sommer         272.672661   0.262264      False

# %%
temp_cluster_eqpdmg = anova("EQPDMG","TEMP_CLUSTER")
cause_eqpdmg = anova("EQPDMG","ACCCAUSE_LVL2")
accidenttype_eqpdmg = anova("EQPDMG","ACCIDENT_TYPE")
eqtype_eqpdmg = anova("EQPDMG","EQUIPMENT_TYPE")
vis_eqpdmg = anova("EQPDMG","VISIBLTY")
weather_eqpdmg = anova("EQPDMG","WEATHER")
spd_eqpdmg = anova("EQPDMG","SPD_TOO_HIGH")
typtrk_eqpdmg = anova("EQPDMG","TYPTRK")
acctype_eqpdmg = anova("EQPDMG","ACCTYPE")
jahreszeit_eqpdmg = anova("EQPDMG","Jahreszeit")

# %%
temp_cluster_trkdmg = anova("TRKDMG","TEMP_CLUSTER")
cause_trkdmg = anova("TRKDMG","ACCCAUSE_LVL2")
accidenttype_trkdmg = anova("TRKDMG","ACCIDENT_TYPE")
eqtype_trkdmg = anova("TRKDMG","EQUIPMENT_TYPE")
vis_trkdmg = anova("TRKDMG","VISIBLTY")
weather_trkdmg = anova("TRKDMG","WEATHER")
spd_trkdmg = anova("TRKDMG","SPD_TOO_HIGH")
typtrk_trkdmg = anova("TRKDMG","TYPTRK")
acctype_trkdmg = anova("TRKDMG","ACCTYPE")
jahreszeit_trkdmg = anova("TRKDMG","Jahreszeit")

# %%
compare_anova = [
                                [
                                    temp_cluster[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis[0]["EtaSq"]["VISIBLTY"],
                                    weather[0]["EtaSq"]["WEATHER"],
                                    spd[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk[0]["EtaSq"]["TYPTRK"],
                                    acctype[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit[0]["EtaSq"]["Jahreszeit"]
                                ],
                                [
                                    temp_cluster_eqpdmg[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause_eqpdmg[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype_eqpdmg[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype_eqpdmg[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis_eqpdmg[0]["EtaSq"]["VISIBLTY"],
                                    weather_eqpdmg[0]["EtaSq"]["WEATHER"],
                                    spd_eqpdmg[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk_eqpdmg[0]["EtaSq"]["TYPTRK"],
                                    acctype_eqpdmg[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit_eqpdmg[0]["EtaSq"]["Jahreszeit"]
                                ],
                                [
                                    temp_cluster_trkdmg[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause_trkdmg[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype_trkdmg[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype_trkdmg[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis_trkdmg[0]["EtaSq"]["VISIBLTY"],
                                    weather_trkdmg[0]["EtaSq"]["WEATHER"],
                                    spd_trkdmg[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk_trkdmg[0]["EtaSq"]["TYPTRK"],
                                    acctype_trkdmg[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit_trkdmg[0]["EtaSq"]["Jahreszeit"]
                                ]
                            ]
pd.DataFrame(compare_anova,columns=["Temperatur", "Ursache","Unfallart", "Zugart", "Sichtbarkeit", "Wetter", "Zug zu schnell?", "Streckenart", "Siginifikanz des Unfalls", "Jahreszeit"], index=["Infrastrukturschaden", "Materialschaden", "Streckenschaden"]).style.format("{:.1g}")
# Out:
# <style  type="text/css" >
# </style><table id="T_c5540c2a_d110_11ea_928f_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Temperatur</th>        <th class="col_heading level0 col1" >Ursache</th>        <th class="col_heading level0 col2" >Unfallart</th>        <th class="col_heading level0 col3" >Zugart</th>        <th class="col_heading level0 col4" >Sichtbarkeit</th>        <th class="col_heading level0 col5" >Wetter</th>        <th class="col_heading level0 col6" >Zug zu schnell?</th>        <th class="col_heading level0 col7" >Streckenart</th>        <th class="col_heading level0 col8" >Siginifikanz des Unfalls</th>        <th class="col_heading level0 col9" >Jahreszeit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c5540c2a_d110_11ea_928f_acde48001122level0_row0" class="row_heading level0 row0" >Infrastrukturschaden</th>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row0_col0" class="data row0 col0" >0.003</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row0_col1" class="data row0 col1" >0.02</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row0_col2" class="data row0 col2" >0.003</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row0_col3" class="data row0 col3" >0.03</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row0_col4" class="data row0 col4" >0.001</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row0_col5" class="data row0 col5" >0.0002</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row0_col6" class="data row0 col6" >0.001</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row0_col7" class="data row0 col7" >0.07</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row0_col8" class="data row0 col8" >0.4</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row0_col9" class="data row0 col9" >0.0002</td>
#             </tr>
#             <tr>
#                         <th id="T_c5540c2a_d110_11ea_928f_acde48001122level0_row1" class="row_heading level0 row1" >Materialschaden</th>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row1_col0" class="data row1 col0" >0.002</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row1_col1" class="data row1 col1" >0.01</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row1_col2" class="data row1 col2" >0.003</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row1_col3" class="data row1 col3" >0.02</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row1_col4" class="data row1 col4" >0.0005</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row1_col5" class="data row1 col5" >0.0003</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row1_col6" class="data row1 col6" >0.001</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row1_col7" class="data row1 col7" >0.05</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row1_col8" class="data row1 col8" >0.3</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row1_col9" class="data row1 col9" >1e-05</td>
#             </tr>
#             <tr>
#                         <th id="T_c5540c2a_d110_11ea_928f_acde48001122level0_row2" class="row_heading level0 row2" >Streckenschaden</th>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row2_col0" class="data row2 col0" >0.001</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row2_col1" class="data row2 col1" >0.02</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row2_col2" class="data row2 col2" >0.008</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row2_col3" class="data row2 col3" >0.02</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row2_col4" class="data row2 col4" >0.001</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row2_col5" class="data row2 col5" >0.0004</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row2_col6" class="data row2 col6" >1e-05</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row2_col7" class="data row2 col7" >0.03</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row2_col8" class="data row2 col8" >0.2</td>
#                         <td id="T_c5540c2a_d110_11ea_928f_acde48001122row2_col9" class="data row2 col9" >0.0006</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### ANOVA Heatmap <a class="anchor" id="ANOVA_HEATMAP"></a>

# %%
colormap = plt.cm.Blues
ax=plt.figure(figsize=(20,15)).gca()
x_axis_labels = ["Temperatur", "Ursache","Unfallart", "Zugart", "Sichtbarkeit", "Wetter", "Zug zu schnell?", "Streckenart", "Siginifikanz des Unfalls", "Jahreszeit"] # labels for x-axis
y_axis_labels = ["Infrastrukturschaden", "Materialschaden", "Streckenschaden"] # labels for y-axis
ax=sns.heatmap(compare_anova,ax=ax,linewidths=0.1, 
            square=True, cmap=colormap, linecolor='white', annot=True, xticklabels=x_axis_labels, yticklabels=y_axis_labels, vmin=0, vmax=0.5);
bottom, top = ax.get_ylim()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, horizontalalignment='right', verticalalignment='top')
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.savefig("Images/ANOVA_Heatmap.png")
