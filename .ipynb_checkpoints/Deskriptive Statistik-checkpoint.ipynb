# %% [markdown]
# # Masterthesis
# ## Deskriptive Statistik
# #### Julian Jetz

# %% [markdown]
# ## Inhalt:
#
# * [Boxenplots und Histogramme der Schäden (mit Ausreißern)](#ausreißer)
#
#
# * [Entfernung der Ausreißer](#ausreißer-delete)
#
#
# * [Häufigkeitsverteilungen](#frequencies)
#     * [Zugart](#freq-zugart)
#     * [Unfallart](#freq-unfallart)
#     * [Streckenart](#freq-streckenart)
#     * [Unfallursache Lvl 2](#freq-cause)
#         * [Unfallursache Lvl 1 (nach Unfallart aufgeteilt)](#freq-cause_lvl1_lvl2_unfallart)
#     * [Unfallsignifikanz](#freq-acctype)
#         * [Unfallsignifikanz (nach Unfallursache Lvl 2)](#freq-acctype_cause)
#     * [Wetter](#freq-wetter)
#     * [Jahreszeit](#freq-jahreszeit)
#     * [Jahr](#freq-jahr)
#         * [Jahr nach Unfallart](#freq-jahr_unfallart)
#     * [Temperatur](#freq-temp)
#         * [Unfallursachen nach Temperatur](#freq-temp_cause)
#     * [Sichtbarkeit](#freq-vis)
#     * [Geschwindigkeitsüberschreitung](#freq-speed)
#
#
# * [Verteilungstabellen](#tables)
#     * [Zugart nach Unfallart](#tables_eqtype_type)
#     * [Unfallart nach Zugart](#tables_type_eqtype)
#     * [Unfallursache nach Zugart](#tables_zugart_cause)
#     * [Unfallursache nach Wetter](#tables_weather_cause)
#     * [Unfallursache nach Jahreszeit](#tables_jahreszeit_cause)
#     * [Unfallursache nach Temperatur](#tables_cause_temp)
#     * [Unfallursache nach Sichtbarkeit](#tables_vis_cause)
#     * [Sichtbarkeit nach Unfallursache](#tables_cause_vis)
#     * [Geschwindigkeitsüberschreitung nach Unfallart](#tables_speed_acctype)
#     * [Geschwindigkeitsüberschreitung nach Streckenart](#tables_speed_typtrk)
#     * [Geschwindigkeitsüberschreitung nach Zugart](#tables_speed_eqtype)
#
#
# * [Boxenplots und Histogramme](#boxenplots)
#     * [Infrastrukturschaden](#infrastrukturdmg)
#     * [Materialschaden](#EQPDMG)
#     * [Streckenschaden](#TRKDMG)
#     * [Zuggeschwindigkeit](#zuggeschwindigkeit)
#     * [Zuggewicht](#tons)
#     * [Zugart](#zugart)
#     * [Unfallart](#unfallart)
#     * [Streckenart](#typtrk)
#     * [Unfallursache Lvl 2](#cause)
#     * [Unfallsignifikanz](#unfallsignifikanz)
#     * [Wetter](#wetter)
#     * [Jahreszeit](#Jahreszeit)
#     * [Jahr](#jahr)
#     * [Temperatur](#temp)
#     * [Sichrbarkeit](#vis)
#     * [Geschwindigkeitsüberschreitung](#speed)
#
#
# * [Statistik](#common_statistics)
#
#
# * [Korrelationen](#correlations)
#
#
# * [Anova Varianz](#ANOVA)
#     * [Anova Heatmap](#ANOVA_HEATMAP)

# %%
import glob
import pandas as pd
import numpy as np
from scipy import stats
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from pandas.plotting import scatter_matrix
from datetime import date
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
na_values = ['nan', 'N/A', 'NaN', 'NaT']

# %%
df = pd.read_csv('resources/accident_data.csv', sep=";", na_values=na_values, index_col=False, dtype = {"STATE" : "str", "TYPE" : "str", "TYPEQ" : "str", "TYPTRK" : "str", "WEATHER" : "str", "VISIBLTY" : "str", "TONS" : "float64"})
df.shape[0]
# Out:
# 70555

# %%
pd.set_option('display.max_colwidth', 500)

# %%
a4_dims = (16, 10)
sns.set(style="whitegrid")

# %% [markdown]
# ### Boxenplots und Histogramme der Schäden (mit Ausreißern) <a class="anchor" id="ausreißer"></a>

# %% [markdown]
# #### Boxenplot Infrastrukturschaden

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
#plt.yscale("log")
ax.set_ylabels("Infrastrukturschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Boxplot_Infrastrukturschaden.png')

# %% [markdown]
# #### Histogramm Infrastrukturschaden (ohne Ausreißer)¶

# %%
df['INFRASTRUCTURE_DMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Infrastrukturschaden.png')

# %% [markdown]
# #### Boxenplot Materialschaden

# %%
ax = sns.catplot(y='EQPDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Boxplot_Materialschaden.png')

# %% [markdown]
# #### Histogramm Materialschaden

# %%
df['EQPDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Materialschaden.png')

# %% [markdown]
# #### Boxenplot Streckenschaden

# %%
ax = sns.catplot(y='TRKDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Streckenschaden in Dollar")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Boxplot_Streckenschaden.png')

# %% [markdown]
# #### Histogramm Materialschaden

# %%
df['TRKDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Streckenschaden.png')

# %% [markdown]
# #### Entfernung der Ausreißer <a class="anchor" id="ausreißer-delete"></a>

# %%
df.shape[0]
# Out:
# 70555

# %%
std_dev = 3.5
df = df[(np.abs(stats.zscore(df[['LOCOMOTIVES1','LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2','LOADF2', 'EMPTYF2', 'INFRASTRUCTURE_DMG']])) < float(std_dev)).all(axis=1)]

# %%
df.shape[0]
# Out:
# 63695

# %% [markdown]
# ### Häufigkeiten <a class="anchor" id="frequencies"></a>

# %%
def bar_values(ax):
    for p in ax.patches:
        ax.annotate(format(p.get_height(), ',d').replace(",","."), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
    sns.despine()
    return ax

# %% [markdown]
# #### Häufigkeiten Zugart <a class="anchor" id="freq-zugart"></a>

# %%
#fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.countplot(x="EQUIPMENT_TYPE", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Zugart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90, horizontalalignment='right')
plt.savefig('Images/Count_Zugart.png')

# %% [markdown]
# #### Häufigkeiten Unfallart <a class="anchor" id="freq-unfallart"></a>

# %%
ax = sns.countplot(x="ACCIDENT_TYPE", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=25, horizontalalignment='right')
plt.savefig('Images/Count_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Streckenart <a class="anchor" id="freq-streckenart"></a>

# %%
ax = sns.countplot(x="TYPTRK", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Streckenart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=25, horizontalalignment='right')
plt.savefig('Images/Count_Streckenart.png')

# %% [markdown]
# #### Häufigkeiten Unfallursache <a class="anchor" id="freq-cause"></a>

# %%
#fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.countplot(x="ACCCAUSE_LVL2", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallursache")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')
plt.savefig('Images/Count_Unfallursache.png')

# %% [markdown]
# #### Häufigkeiten Unfallursache Lvl 1 (eingefärbt nach Unfallursache Lvl2 und gruppiert nach Unfallart) <a class="anchor" id="freq-cause_lvl1_lvl2_unfallart"></a>

# %%
bp = sns.catplot(y="ACCCAUSE_LVL1", hue="ACCCAUSE_LVL2", data=df, kind="count", col="ACCIDENT_TYPE", col_wrap=2, height=14, aspect=0.7, legend=False, legend_out=False)
bp.set_xlabels('Anzahl', fontsize=12)
bp.set_ylabels('Unfallursache', fontsize=12)
for ax in bp.axes:
    ax.legend(bbox_to_anchor=(0, 1.08), loc='upper left', ncol=3, frameon=False, fontsize=10)
    ax.grid(axis='y')
    #plt.setp(ax.get_xticklabels(), visible=True)
    #ax.set_xticks([0,1,2,3,4,5], ax.get_xticklabels())
plt.subplots_adjust(wspace=0.1, hspace=0.15)
plt.savefig('Images/Count_Unfallursache_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Unfallschwere <a class="anchor" id="freq-acctype"></a>

# %%
ax = sns.countplot(x="ACCTYPE", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallschwere")
plt.savefig('Images/Count_Unfallschwere.png')

# %% [markdown]
# #### Häufigkeiten Unfallschwere (nach Zugart)  <a class="anchor" id="freq-acctype_cause"></a>

# %%
cp = sns.catplot(x="ACCTYPE", data=df, col="EQUIPMENT_TYPE", palette="colorblind", kind="count", col_wrap=4, height=3, aspect=1)
cp.set_xlabels('Unfallschwere', fontsize=12)
cp.set_ylabels('Anzahl', fontsize=12)
plt.savefig('Images/Count_Unfallschwere_Zugart.png')

# %% [markdown]
# #### Häufigkeiten Wetter <a class="anchor" id="freq-wetter"></a>

# %%
ax = sns.countplot(x="WEATHER", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Wetter")
plt.savefig('Images/Count_Wetter.png')

# %% [markdown]
# #### Häufigkeiten Jahreszeit <a class="anchor" id="freq-jahreszeit"></a>

# %%
ax = sns.countplot(x="Jahreszeit", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Jahreszeit")
plt.savefig('Images/Count_Jahreszeit.png')

# %% [markdown]
# #### Häufigkeiten Jahr <a class="anchor" id="freq-jahr"></a>

# %%
bp = sns.catplot(x="YEAR4", data=df, kind="count", height=10, aspect=1.5, palette="colorblind")
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Anzahl', fontsize=12)
plt.savefig('Images/Count_Jahr.png')

# %% [markdown]
# #### Häufigkeiten Jahr (nach Unfallart) <a class="anchor" id="freq-jahr_unfallart"></a>

# %%
bp = sns.catplot(x="YEAR4", data=df, kind="count", col="ACCIDENT_TYPE", col_wrap=2, height=5, aspect=1.5, palette="colorblind")
bp.set_ylabels('Jahr', fontsize=12)
bp.set_xlabels('Anzahl', fontsize=12)
for x in bp.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
plt.savefig('Images/Count_Jahr_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Temperatur <a class="anchor" id="freq-temp"></a>

# %%
temp_order = ["Sehr Kalt (-45° - 30,01° C)", "Kalt (-30° - 0,01° C)", "Moderat (0° bis 19,99° C)", "Warm (20° bis 31,99° C)", "Heiß (>= 32° C)"]
ax = sns.countplot(x="TEMP_CLUSTER", data=df, palette="colorblind", order=temp_order)
ax = bar_values(ax)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')
ax.set_xlabel("Temperatur")
plt.savefig('Images/Count_Temperatur.png')

# %% [markdown]
# #### Häufigkeiten Temperatur (nach Unfallursache) <a class="anchor" id="freq-temp_cause"></a>

# %%
ax = sns.catplot(x="TEMP_CLUSTER", hue="ACCCAUSE_LVL2", kind="count", data=df, palette='colorblind', order=temp_order, legend=False, height=15, aspect=1.5)
for x in ax.axes.flat:
    x.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=3, frameon=False, fontsize=20)
    for label in x.get_xticklabels():
        label.set_rotation(-90)   
ax.set_xlabels("Temperatur")
plt.savefig('Images/Count_Temperatur_Unfallursache.png')

# %% [markdown]
# #### Häufigkeiten Sichtbarkeit <a class="anchor" id="freq-vis"></a>

# %%
vis_order = ["Dawn", "Day", "Dusk", "Dark"]
ax = sns.countplot(x="VISIBLTY", data=df, palette="colorblind", order=vis_order)
ax = bar_values(ax)
ax.set_xlabel("Sichtbarkeit")
plt.savefig('Images/Count_Sichtbarkeit.png')

# %% [markdown]
# #### Häufigkeiten zu hohe Zuggeschwindigkeit <a class="anchor" id="freq-speed"></a>

# %%
ax = sns.countplot(x="SPD_TOO_HIGH", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Zuggeschwindigkeit zu hoch")
plt.savefig('Images/Count_Zug_zu_schnell.png')

# %% [markdown]
# ### Verteilungstabellen <a class="anchor" id="tables"></a>

# %% [markdown]
# #### Verteilungstabelle Zugart nach Unfallart <a class="anchor" id="tables_eqtype_type"></a>

# %%
format_dict = {'Commuter Train':'{:.2f}%', 'Cut of Cars': '{:.2f}%', 'Freight Train': '{:.2f}%', 
               'Locomotive': '{:.2f}%', 'Passenger Train': '{:.2f}%', 'Single Car': '{:.2f}%', 'Work Train': '{:.2f}%',
               'Yard/Switching': '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["ACCIDENT_TYPE"],  columns=df["EQUIPMENT_TYPE"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_70d2da8a_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >EQUIPMENT_TYPE</th>        <th class="col_heading level0 col0" >Commuter Train</th>        <th class="col_heading level0 col1" >Cut of Cars</th>        <th class="col_heading level0 col2" >Freight Train</th>        <th class="col_heading level0 col3" >Locomotive</th>        <th class="col_heading level0 col4" >Passenger Train</th>        <th class="col_heading level0 col5" >Single Car</th>        <th class="col_heading level0 col6" >Work Train</th>        <th class="col_heading level0 col7" >Yard/Switching</th>        <th class="col_heading level0 col8" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70d2da8a_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Collision</th>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >18.53%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >9.53%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >3.41%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row0_col3" class="data row0 col3" >8.26%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row0_col4" class="data row0 col4" >28.00%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row0_col5" class="data row0 col5" >16.15%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row0_col6" class="data row0 col6" >14.45%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row0_col7" class="data row0 col7" >4.20%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row0_col8" class="data row0 col8" >4.86%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d2da8a_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Crossing</th>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >58.58%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >0.85%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >10.45%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row1_col3" class="data row1 col3" >7.58%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row1_col4" class="data row1 col4" >45.13%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row1_col5" class="data row1 col5" >9.53%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row1_col6" class="data row1 col6" >12.96%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row1_col7" class="data row1 col7" >0.63%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row1_col8" class="data row1 col8" >8.65%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d2da8a_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Derailment</th>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >16.35%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >85.62%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >84.83%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row2_col3" class="data row2 col3" >81.77%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row2_col4" class="data row2 col4" >18.50%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row2_col5" class="data row2 col5" >52.33%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row2_col6" class="data row2 col6" >68.94%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row2_col7" class="data row2 col7" >95.02%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row2_col8" class="data row2 col8" >85.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d2da8a_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Fire / Violent Rupture / Explosive Detonation</th>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >6.54%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >4.00%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >1.31%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row3_col3" class="data row3 col3" >2.39%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row3_col4" class="data row3 col4" >8.37%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row3_col5" class="data row3 col5" >21.98%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row3_col6" class="data row3 col6" >3.65%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row3_col7" class="data row3 col7" >0.15%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row3_col8" class="data row3 col8" >1.48%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d2da8a_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#                         <td id="T_70d2da8a_d199_11ea_9cd1_acde48001122row4_col8" class="data row4 col8" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallart nach Zugart <a class="anchor" id="tables_type_eqtype"></a>

# %%
format_dict = {'Collision':'{:.2f}%', 'Crossing': '{:.2f}%', 'Derailment': '{:.2f}%', 
               'Fire / Violent RuptureViolent rupture / Explosive Detonation': '{:.2f}%', 'All': '{:.2f}%'}
freq_tab_eqtype_type = pd.crosstab(index=df["EQUIPMENT_TYPE"],  columns=df["ACCIDENT_TYPE"], margins=True)
(freq_tab_eqtype_type/freq_tab_eqtype_type.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_70e1e41c_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="col_heading level0 col0" >Collision</th>        <th class="col_heading level0 col1" >Crossing</th>        <th class="col_heading level0 col2" >Derailment</th>        <th class="col_heading level0 col3" >Fire / Violent Rupture / Explosive Detonation</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="index_name level0" >EQUIPMENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70e1e41c_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Commuter Train</th>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >2.19%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >3.90%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >0.11%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row0_col3" class="data row0 col3" >2.54777</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row0_col4" class="data row0 col4" >0.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_70e1e41c_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Cut of Cars</th>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >3.62%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >0.18%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >1.86%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row1_col3" class="data row1 col3" >4.98938</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row1_col4" class="data row1 col4" >1.84%</td>
#             </tr>
#             <tr>
#                         <th id="T_70e1e41c_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Freight Train</th>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >43.22%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >74.50%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >61.57%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row2_col3" class="data row2 col3" >54.7771</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row2_col4" class="data row2 col4" >61.70%</td>
#             </tr>
#             <tr>
#                         <th id="T_70e1e41c_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Locomotive</th>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >5.13%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >2.65%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >2.91%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row3_col3" class="data row3 col3" >4.88323</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row3_col4" class="data row3 col4" >3.02%</td>
#             </tr>
#             <tr>
#                         <th id="T_70e1e41c_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >Passenger Train</th>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >15.88%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >14.39%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >0.60%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row4_col3" class="data row4 col3" >15.6051</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row4_col4" class="data row4 col4" >2.76%</td>
#             </tr>
#             <tr>
#                         <th id="T_70e1e41c_d199_11ea_9cd1_acde48001122level0_row5" class="row_heading level0 row5" >Single Car</th>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row5_col0" class="data row5 col0" >2.68%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row5_col1" class="data row5 col1" >0.89%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row5_col2" class="data row5 col2" >0.50%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row5_col3" class="data row5 col3" >11.9958</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row5_col4" class="data row5 col4" >0.81%</td>
#             </tr>
#             <tr>
#                         <th id="T_70e1e41c_d199_11ea_9cd1_acde48001122level0_row6" class="row_heading level0 row6" >Work Train</th>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row6_col0" class="data row6 col0" >2.81%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row6_col1" class="data row6 col1" >1.42%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row6_col2" class="data row6 col2" >0.77%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row6_col3" class="data row6 col3" >2.33546</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row6_col4" class="data row6 col4" >0.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_70e1e41c_d199_11ea_9cd1_acde48001122level0_row7" class="row_heading level0 row7" >Yard/Switching</th>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row7_col0" class="data row7 col0" >24.47%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row7_col1" class="data row7 col1" >2.07%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row7_col2" class="data row7 col2" >31.69%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row7_col3" class="data row7 col3" >2.86624</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row7_col4" class="data row7 col4" >28.35%</td>
#             </tr>
#             <tr>
#                         <th id="T_70e1e41c_d199_11ea_9cd1_acde48001122level0_row8" class="row_heading level0 row8" >All</th>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row8_col0" class="data row8 col0" >100.00%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row8_col1" class="data row8 col1" >100.00%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row8_col2" class="data row8 col2" >100.00%</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row8_col3" class="data row8 col3" >100</td>
#                         <td id="T_70e1e41c_d199_11ea_9cd1_acde48001122row8_col4" class="data row8 col4" >100.00%</td>
#             </tr>
#     </tbody></table>

# %%
format_dict = {'Environmental Conditions':'{:.2f}%', 'Human Factors': '{:.2f}%', 'Loading': '{:.2f}%', 
               'Mechanical and Electrical Failures': '{:.2f}%', 'Miscellaneous Causes': '{:.2f}%', 
               'Signal and Communication': '{:.2f}%', 'Track, Roadbed and Structures': '{:.2f}%',
               'All': '{:.2f}%'}

# %% [markdown]
# #### Verteilungstabelle Unfallart  nach Unfallursache <a class="anchor" id="tables_zugart_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["ACCIDENT_TYPE"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_70f2363c_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70f2363c_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Collision</th>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >8.45%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >9.52%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >1.55%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row0_col3" class="data row0 col3" >2.42%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row0_col4" class="data row0 col4" >17.06%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row0_col5" class="data row0 col5" >6.48%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row0_col6" class="data row0 col6" >0.43%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row0_col7" class="data row0 col7" >4.86%</td>
#             </tr>
#             <tr>
#                         <th id="T_70f2363c_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Crossing</th>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >0.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >0.22%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >84.61%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row1_col3" class="data row1 col3" >0.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row1_col4" class="data row1 col4" >0.51%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row1_col5" class="data row1 col5" >0.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row1_col6" class="data row1 col6" >0.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row1_col7" class="data row1 col7" >8.65%</td>
#             </tr>
#             <tr>
#                         <th id="T_70f2363c_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Derailment</th>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >91.22%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >90.16%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >13.77%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row2_col3" class="data row2 col3" >91.49%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row2_col4" class="data row2 col4" >76.20%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row2_col5" class="data row2 col5" >93.52%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row2_col6" class="data row2 col6" >99.53%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row2_col7" class="data row2 col7" >85.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_70f2363c_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Fire / Violent Rupture / Explosive Detonation</th>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >0.33%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >0.09%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >0.06%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row3_col3" class="data row3 col3" >6.09%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row3_col4" class="data row3 col4" >6.24%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row3_col5" class="data row3 col5" >0.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row3_col6" class="data row3 col6" >0.04%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row3_col7" class="data row3 col7" >1.48%</td>
#             </tr>
#             <tr>
#                         <th id="T_70f2363c_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_70f2363c_d199_11ea_9cd1_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Zugart  <a class="anchor" id="tables_zugart_typtrk"></a>

# %%
freq_tab = pd.crosstab(index=df["TYPTRK"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_7100b2f2_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >TYPTRK</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7100b2f2_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Industry</th>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >20.20%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >9.27%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >2.50%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row0_col3" class="data row0 col3" >2.90%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row0_col4" class="data row0 col4" >8.93%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row0_col5" class="data row0 col5" >2.43%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row0_col6" class="data row0 col6" >13.72%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row0_col7" class="data row0 col7" >9.50%</td>
#             </tr>
#             <tr>
#                         <th id="T_7100b2f2_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Main</th>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >44.68%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >21.16%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >90.83%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row1_col3" class="data row1 col3" >67.91%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row1_col4" class="data row1 col4" >41.08%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row1_col5" class="data row1 col5" >11.35%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row1_col6" class="data row1 col6" >32.29%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row1_col7" class="data row1 col7" >41.10%</td>
#             </tr>
#             <tr>
#                         <th id="T_7100b2f2_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Siding</th>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >5.27%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >4.02%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >0.90%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row2_col3" class="data row2 col3" >3.10%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row2_col4" class="data row2 col4" >3.44%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row2_col5" class="data row2 col5" >1.78%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row2_col6" class="data row2 col6" >5.02%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row2_col7" class="data row2 col7" >3.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_7100b2f2_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Yard</th>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >29.86%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >65.55%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >5.77%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row3_col3" class="data row3 col3" >26.08%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row3_col4" class="data row3 col4" >46.55%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row3_col5" class="data row3 col5" >84.44%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row3_col6" class="data row3 col6" >48.97%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row3_col7" class="data row3 col7" >45.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_7100b2f2_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_7100b2f2_d199_11ea_9cd1_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach State <a class="anchor" id="tables_state_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["STATE"],  columns=df["ACCCAUSE_LVL2"], margins=True)
((freq_tab/freq_tab.loc["All"]*100).sort_values(by=['All'], ascending=False)).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_7110c17e_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >STATE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7110c17e_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >All</th>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >100.00%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >100.00%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >100.00%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row0_col3" class="data row0 col3" >100.00%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row0_col4" class="data row0 col4" >100.00%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row0_col5" class="data row0 col5" >100.00%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row0_col6" class="data row0 col6" >100.00%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row0_col7" class="data row0 col7" >100.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_7110c17e_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Texas</th>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >6.04%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >10.85%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >14.86%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row1_col3" class="data row1 col3" >9.85%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row1_col4" class="data row1 col4" >9.88%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row1_col5" class="data row1 col5" >11.02%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row1_col6" class="data row1 col6" >11.94%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row1_col7" class="data row1 col7" >11.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_7110c17e_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Illinois</th>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >6.70%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >11.21%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >5.32%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row2_col3" class="data row2 col3" >7.13%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row2_col4" class="data row2 col4" >8.67%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row2_col5" class="data row2 col5" >10.05%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row2_col6" class="data row2 col6" >8.08%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row2_col7" class="data row2 col7" >8.52%</td>
#             </tr>
#             <tr>
#                         <th id="T_7110c17e_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Kalifornien</th>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >4.06%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >6.33%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >8.41%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row3_col3" class="data row3 col3" >4.50%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row3_col4" class="data row3 col4" >8.97%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row3_col5" class="data row3 col5" >7.29%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row3_col6" class="data row3 col6" >4.84%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row3_col7" class="data row3 col7" >5.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_7110c17e_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >Ohio</th>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >3.62%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >3.79%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >2.88%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row4_col3" class="data row4 col3" >3.51%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row4_col4" class="data row4 col4" >3.16%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row4_col5" class="data row4 col5" >5.83%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row4_col6" class="data row4 col6" >3.72%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row4_col7" class="data row4 col7" >3.59%</td>
#             </tr>
#             <tr>
#                         <th id="T_7110c17e_d199_11ea_9cd1_acde48001122level0_row5" class="row_heading level0 row5" >Pennsylvania</th>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row5_col0" class="data row5 col0" >3.40%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row5_col1" class="data row5 col1" >3.39%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row5_col2" class="data row5 col2" >2.63%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row5_col3" class="data row5 col3" >3.61%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row5_col4" class="data row5 col4" >3.87%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row5_col5" class="data row5 col5" >4.38%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row5_col6" class="data row5 col6" >3.64%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row5_col7" class="data row5 col7" >3.50%</td>
#             </tr>
#             <tr>
#                         <th id="T_7110c17e_d199_11ea_9cd1_acde48001122level0_row6" class="row_heading level0 row6" >Iowa</th>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row6_col0" class="data row6 col0" >4.28%</td>
#                         <td id="T_7110c17e_d199_11ea_9cd1_acde48001122row6_col1" class="data row6 col1

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Wetter <a class="anchor" id="tables_weather_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["WEATHER"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_71210890_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >WEATHER</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_71210890_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Clear</th>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >39.52%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >67.50%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >71.03%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row0_col3" class="data row0 col3" >65.79%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row0_col4" class="data row0 col4" >67.10%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row0_col5" class="data row0 col5" >62.72%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row0_col6" class="data row0 col6" >64.35%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row0_col7" class="data row0 col7" >65.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_71210890_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Cloudy</th>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >22.06%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >22.76%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >20.23%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row1_col3" class="data row1 col3" >24.60%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row1_col4" class="data row1 col4" >23.11%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row1_col5" class="data row1 col5" >25.77%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row1_col6" class="data row1 col6" >25.59%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row1_col7" class="data row1 col7" >23.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_71210890_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Fog</th>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >1.43%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >1.22%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >1.79%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row2_col3" class="data row2 col3" >1.37%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row2_col4" class="data row2 col4" >1.39%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row2_col5" class="data row2 col5" >0.65%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row2_col6" class="data row2 col6" >0.92%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row2_col7" class="data row2 col7" >1.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_71210890_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Rain</th>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >23.05%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >6.34%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >5.10%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row3_col3" class="data row3 col3" >5.17%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row3_col4" class="data row3 col4" >6.59%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row3_col5" class="data row3 col5" >7.62%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row3_col6" class="data row3 col6" >6.91%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row3_col7" class="data row3 col7" >6.55%</td>
#             </tr>
#             <tr>
#                         <th id="T_71210890_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >Sleet</th>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >0.66%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >0.18%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >0.22%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row4_col3" class="data row4 col3" >0.15%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row4_col4" class="data row4 col4" >0.13%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row4_col5" class="data row4 col5" >0.16%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row4_col6" class="data row4 col6" >0.22%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row4_col7" class="data row4 col7" >0.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_71210890_d199_11ea_9cd1_acde48001122level0_row5" class="row_heading level0 row5" >Snow</th>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row5_col0" class="data row5 col0" >13.28%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row5_col1" class="data row5 col1" >2.00%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row5_col2" class="data row5 col2" >1.63%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row5_col3" class="data row5 col3" >2.91%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row5_col4" class="data row5 col4" >1.67%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row5_col5" class="data row5 col5" >3.08%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row5_col6" class="data row5 col6" >2.01%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row5_col7" class="data row5 col7" >2.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_71210890_d199_11ea_9cd1_acde48001122level0_row6" class="row_heading level0 row6" >All</th>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row6_col0" class="data row6 col0" >100.00%</td>
#                         <td id="T_71210890_d199_11ea_9cd1_acde48001122row6_col1" class="data row6 col1" >100.00%</td>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Jahreszeit <a class="anchor" id="tables_jahreszeit_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["Jahreszeit"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_712f6714_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >Jahreszeit</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_712f6714_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Frühling</th>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >19.10%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >25.50%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >23.88%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row0_col3" class="data row0 col3" >25.84%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row0_col4" class="data row0 col4" >26.39%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row0_col5" class="data row0 col5" >24.47%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row0_col6" class="data row0 col6" >24.92%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row0_col7" class="data row0 col7" >25.14%</td>
#             </tr>
#             <tr>
#                         <th id="T_712f6714_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Herbst</th>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >15.92%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >23.62%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >25.14%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row1_col3" class="data row1 col3" >21.63%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row1_col4" class="data row1 col4" >21.62%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row1_col5" class="data row1 col5" >22.53%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row1_col6" class="data row1 col6" >23.34%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row1_col7" class="data row1 col7" >23.08%</td>
#             </tr>
#             <tr>
#                         <th id="T_712f6714_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Sommer</th>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >19.10%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >26.87%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >27.38%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row2_col3" class="data row2 col3" >25.45%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row2_col4" class="data row2 col4" >27.82%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row2_col5" class="data row2 col5" >25.28%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row2_col6" class="data row2 col6" >26.32%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row2_col7" class="data row2 col7" >26.48%</td>
#             </tr>
#             <tr>
#                         <th id="T_712f6714_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Winter</th>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >45.88%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >24.01%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >23.60%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row3_col3" class="data row3 col3" >27.08%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row3_col4" class="data row3 col4" >24.17%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row3_col5" class="data row3 col5" >27.71%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row3_col6" class="data row3 col6" >25.41%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row3_col7" class="data row3 col7" >25.30%</td>
#             </tr>
#             <tr>
#                         <th id="T_712f6714_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_712f6714_d199_11ea_9cd1_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Temperatur <a class="anchor" id="tables_cause_temp"></a>

# %%
freq_tab = pd.crosstab(index=df["TEMP_CLUSTER"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_713ce268_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >TEMP_CLUSTER</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_713ce268_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Heiß (>= 32° C)</th>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >3.51%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >5.14%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >9.02%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row0_col3" class="data row0 col3" >5.50%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row0_col4" class="data row0 col4" >5.92%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row0_col5" class="data row0 col5" >4.54%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row0_col6" class="data row0 col6" >8.29%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row0_col7" class="data row0 col7" >6.85%</td>
#             </tr>
#             <tr>
#                         <th id="T_713ce268_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Kalt (-30° - 0,01° C)</th>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >36.66%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >12.03%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >9.34%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row1_col3" class="data row1 col3" >16.90%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row1_col4" class="data row1 col4" >10.72%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row1_col5" class="data row1 col5" >12.64%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row1_col6" class="data row1 col6" >13.53%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row1_col7" class="data row1 col7" >13.25%</td>
#             </tr>
#             <tr>
#                         <th id="T_713ce268_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Moderat (0° bis 19,99° C)</th>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >36.55%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >49.66%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >42.23%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row2_col3" class="data row2 col3" >47.47%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row2_col4" class="data row2 col4" >49.21%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row2_col5" class="data row2 col5" >49.27%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row2_col6" class="data row2 col6" >47.16%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row2_col7" class="data row2 col7" >47.40%</td>
#             </tr>
#             <tr>
#                         <th id="T_713ce268_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Sehr Kalt (-45° - 30,01° C)</th>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >0.55%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >0.06%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >0.00%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row3_col3" class="data row3 col3" >0.09%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row3_col4" class="data row3 col4" >0.02%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row3_col5" class="data row3 col5" >0.00%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row3_col6" class="data row3 col6" >0.04%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row3_col7" class="data row3 col7" >0.05%</td>
#             </tr>
#             <tr>
#                         <th id="T_713ce268_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >Warm (20° bis 31,99° C)</th>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >22.72%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >33.12%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >39.41%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row4_col3" class="data row4 col3" >30.04%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row4_col4" class="data row4 col4" >34.13%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row4_col5" class="data row4 col5" >33.55%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row4_col6" class="data row4 col6" >30.99%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row4_col7" class="data row4 col7" >32.45%</td>
#             </tr>
#             <tr>
#                         <th id="T_713ce268_d199_11ea_9cd1_acde48001122level0_row5" class="row_heading level0 row5" >All</th>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row5_col0" class="data row5 col0" >100.00%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row5_col1" class="data row5 col1" >100.00%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row5_col2" class="data row5 col2" >100.00%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row5_col3" class="data row5 col3" >100.00%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row5_col4" class="data row5 col4" >100.00%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row5_col5" class="data row5 col5" >100.00%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row5_col6" class="data row5 col6" >100.00%</td>
#                         <td id="T_713ce268_d199_11ea_9cd1_acde48001122row5_col7" class="data row5 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Sichtbarkeit <a class="anchor" id="tables_vis_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["VISIBLTY"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_714c1eae_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >VISIBLTY</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_714c1eae_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Dark</th>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >45.99%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >45.37%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >21.18%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row0_col3" class="data row0 col3" >42.01%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row0_col4" class="data row0 col4" >42.23%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row0_col5" class="data row0 col5" >42.30%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row0_col6" class="data row0 col6" >37.68%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row0_col7" class="data row0 col7" >39.15%</td>
#             </tr>
#             <tr>
#                         <th id="T_714c1eae_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Dawn</th>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >3.51%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >4.94%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >4.66%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row1_col3" class="data row1 col3" >5.21%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row1_col4" class="data row1 col4" >4.83%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row1_col5" class="data row1 col5" >5.19%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row1_col6" class="data row1 col6" >4.23%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row1_col7" class="data row1 col7" >4.64%</td>
#             </tr>
#             <tr>
#                         <th id="T_714c1eae_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Day</th>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >43.58%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >44.30%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >70.40%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row2_col3" class="data row2 col3" >47.82%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row2_col4" class="data row2 col4" >46.93%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row2_col5" class="data row2 col5" >45.71%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row2_col6" class="data row2 col6" >53.35%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row2_col7" class="data row2 col7" >51.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_714c1eae_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Dusk</th>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >6.92%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >5.39%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >3.76%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row3_col3" class="data row3 col3" >4.95%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row3_col4" class="data row3 col4" >6.00%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row3_col5" class="data row3 col5" >6.81%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row3_col6" class="data row3 col6" >4.75%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row3_col7" class="data row3 col7" >5.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_714c1eae_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_714c1eae_d199_11ea_9cd1_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Sichtbarkeit nach Unfallursache  <a class="anchor" id="tables_cause_vis"></a>

# %%
format_dict = {'Dark':'{:.2f}%', 'Dawn': '{:.2f}%', 'Day': '{:.2f}%', 
               'Dusk': '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["ACCCAUSE_LVL2"],  columns=df["VISIBLTY"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_7159a416_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >VISIBLTY</th>        <th class="col_heading level0 col0" >Dark</th>        <th class="col_heading level0 col1" >Dawn</th>        <th class="col_heading level0 col2" >Day</th>        <th class="col_heading level0 col3" >Dusk</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7159a416_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Environmental Conditions</th>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >1.68%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >1.08%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >1.22%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row0_col3" class="data row0 col3" >1.97%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row0_col4" class="data row0 col4" >1.43%</td>
#             </tr>
#             <tr>
#                         <th id="T_7159a416_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Human Factors</th>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >29.28%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >26.85%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >21.86%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row1_col3" class="data row1 col3" >27.17%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row1_col4" class="data row1 col4" >25.26%</td>
#             </tr>
#             <tr>
#                         <th id="T_7159a416_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Loading</th>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >5.46%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >10.15%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >13.88%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row2_col3" class="data row2 col3" >7.58%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row2_col4" class="data row2 col4" >10.10%</td>
#             </tr>
#             <tr>
#                         <th id="T_7159a416_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Mechanical and Electrical Failures</th>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >14.77%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >15.45%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >12.85%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row3_col3" class="data row3 col3" >13.60%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row3_col4" class="data row3 col4" >13.76%</td>
#             </tr>
#             <tr>
#                         <th id="T_7159a416_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >Miscellaneous Causes</th>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >10.24%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >9.87%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >8.70%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row4_col3" class="data row4 col3" >11.38%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row4_col4" class="data row4 col4" >9.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_7159a416_d199_11ea_9cd1_acde48001122level0_row5" class="row_heading level0 row5" >Signal and Communication</th>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row5_col0" class="data row5 col0" >1.05%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row5_col1" class="data row5 col1" >1.08%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row5_col2" class="data row5 col2" >0.86%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row5_col3" class="data row5 col3" >1.32%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row5_col4" class="data row5 col4" >0.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_7159a416_d199_11ea_9cd1_acde48001122level0_row6" class="row_heading level0 row6" >Track, Roadbed and Structures</th>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row6_col0" class="data row6 col0" >37.53%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row6_col1" class="data row6 col1" >35.51%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row6_col2" class="data row6 col2" >40.63%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row6_col3" class="data row6 col3" >36.98%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row6_col4" class="data row6 col4" >38.99%</td>
#             </tr>
#             <tr>
#                         <th id="T_7159a416_d199_11ea_9cd1_acde48001122level0_row7" class="row_heading level0 row7" >All</th>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row7_col0" class="data row7 col0" >100.00%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row7_col1" class="data row7 col1" >100.00%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row7_col2" class="data row7 col2" >100.00%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row7_col3" class="data row7 col3" >100.00%</td>
#                         <td id="T_7159a416_d199_11ea_9cd1_acde48001122row7_col4" class="data row7 col4" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Geschwindigkeitsüberschreitung nach Unfallart  <a class="anchor" id="tables_speed_acctype"></a>

# %%
format_dict = {False:'{:.2f}%', True: '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["ACCIDENT_TYPE"],  columns=df["SPD_TOO_HIGH"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_7164efc4_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >SPD_TOO_HIGH</th>        <th class="col_heading level0 col0" >False</th>        <th class="col_heading level0 col1" >True</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7164efc4_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Collision</th>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >4.82%</td>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >6.14%</td>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >4.86%</td>
#             </tr>
#             <tr>
#                         <th id="T_7164efc4_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Crossing</th>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >8.72%</td>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >6.68%</td>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >8.65%</td>
#             </tr>
#             <tr>
#                         <th id="T_7164efc4_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Derailment</th>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >84.95%</td>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >86.51%</td>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >85.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_7164efc4_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Fire / Violent Rupture / Explosive Detonation</th>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >1.51%</td>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >0.67%</td>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >1.48%</td>
#             </tr>
#             <tr>
#                         <th id="T_7164efc4_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_7164efc4_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Geschwindigkeitsüberschreitung nach Streckenart  <a class="anchor" id="tables_speed_typtrk"></a>

# %%
format_dict = {False:'{:.2f}%', True: '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["TYPTRK"],  columns=df["SPD_TOO_HIGH"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_7170380c_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >SPD_TOO_HIGH</th>        <th class="col_heading level0 col0" >False</th>        <th class="col_heading level0 col1" >True</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >TYPTRK</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7170380c_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Industry</th>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >9.63%</td>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >6.14%</td>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >9.50%</td>
#             </tr>
#             <tr>
#                         <th id="T_7170380c_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Main</th>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >40.32%</td>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >62.66%</td>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >41.10%</td>
#             </tr>
#             <tr>
#                         <th id="T_7170380c_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Siding</th>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >3.89%</td>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >4.62%</td>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >3.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_7170380c_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Yard</th>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >46.17%</td>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >26.58%</td>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >45.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_7170380c_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_7170380c_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Geschwindigkeitsüberschreitung nach Zugart  <a class="anchor" id="tables_speed_eqtype"></a>

# %%
format_dict = {False:'{:.2f}%', True: '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["EQUIPMENT_TYPE"],  columns=df["SPD_TOO_HIGH"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_717c7838_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="index_name level0" >SPD_TOO_HIGH</th>        <th class="col_heading level0 col0" >False</th>        <th class="col_heading level0 col1" >True</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >EQUIPMENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_717c7838_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Commuter Train</th>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >0.59%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >0.31%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >0.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_717c7838_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Cut of Cars</th>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >1.77%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >3.81%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >1.84%</td>
#             </tr>
#             <tr>
#                         <th id="T_717c7838_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Freight Train</th>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >61.17%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >76.15%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >61.70%</td>
#             </tr>
#             <tr>
#                         <th id="T_717c7838_d199_11ea_9cd1_acde48001122level0_row3" class="row_heading level0 row3" >Locomotive</th>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row3_col0" class="data row3 col0" >3.05%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row3_col1" class="data row3 col1" >2.29%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row3_col2" class="data row3 col2" >3.02%</td>
#             </tr>
#             <tr>
#                         <th id="T_717c7838_d199_11ea_9cd1_acde48001122level0_row4" class="row_heading level0 row4" >Passenger Train</th>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row4_col0" class="data row4 col0" >2.77%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row4_col1" class="data row4 col1" >2.47%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row4_col2" class="data row4 col2" >2.76%</td>
#             </tr>
#             <tr>
#                         <th id="T_717c7838_d199_11ea_9cd1_acde48001122level0_row5" class="row_heading level0 row5" >Single Car</th>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row5_col0" class="data row5 col0" >0.77%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row5_col1" class="data row5 col1" >1.79%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row5_col2" class="data row5 col2" >0.81%</td>
#             </tr>
#             <tr>
#                         <th id="T_717c7838_d199_11ea_9cd1_acde48001122level0_row6" class="row_heading level0 row6" >Work Train</th>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row6_col0" class="data row6 col0" >0.95%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row6_col1" class="data row6 col1" >0.72%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row6_col2" class="data row6 col2" >0.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_717c7838_d199_11ea_9cd1_acde48001122level0_row7" class="row_heading level0 row7" >Yard/Switching</th>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row7_col0" class="data row7 col0" >28.93%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row7_col1" class="data row7 col1" >12.46%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row7_col2" class="data row7 col2" >28.35%</td>
#             </tr>
#             <tr>
#                         <th id="T_717c7838_d199_11ea_9cd1_acde48001122level0_row8" class="row_heading level0 row8" >All</th>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row8_col0" class="data row8 col0" >100.00%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row8_col1" class="data row8 col1" >100.00%</td>
#                         <td id="T_717c7838_d199_11ea_9cd1_acde48001122row8_col2" class="data row8 col2" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Boxenplots und Histogramme <a class="anchor" id="boxenplots"></a>
#
# [Hadley Wickham: Letter-value plots: Boxplots for large data](https://doi.org/10.1080/10618600.2017.1305277)

# %% [markdown]
# #### Boxenplot Infrastrukturschaden (ohne Ausreißer) <a class="anchor" id="infrastrukturdmg"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
plt.yscale("log")
ax.set_ylabels("Infrastrukturschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Infrastrukturschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Infrastrukturschaden (ohne Ausreißer)¶

# %%
df['INFRASTRUCTURE_DMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Infrastrukturschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Materialschaden (ohne Ausreißer) <a class="anchor" id="EQPDMG"></a>

# %%
ax = sns.catplot(y='EQPDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
plt.yscale("log")
ax.set_ylabels("Materialschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Materialschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Materialschaden (ohne Ausreißer)¶

# %%
df['EQPDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Materialschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Streckenchaden (ohne Ausreißer) <a class="anchor" id="TRKDMG"></a>

# %%
ax = sns.catplot(y='TRKDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Streckenschaden in Dollar")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Streckenschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Materialschaden (ohne Ausreißer)¶

# %%
df['TRKDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Streckenschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Zuggeschwindigkeit <a class="anchor" id="zuggeschwindigkeit"></a>

# %%
ax = sns.catplot(y='SPEED', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Geschwindigkeit des Zuges")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Zuggeschwindigkeit.png')

# %% [markdown]
# #### Histogramm Zuggeschwindigkeit

# %%
df['SPEED'].hist(bins=50)
plt.savefig('Images/Histogramm_Zuggeschwindigkeit.png')

# %% [markdown]
# #### Boxenplot Zuggewicht <a class="anchor" id="tons"></a>

# %%
ax = sns.catplot(y='TONS', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Gewicht des Zuges")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Zuggewicht.png')

# %% [markdown]
# #### Histogramm Zuggewicht

# %%
df['TONS'].hist(bins=50)
plt.savefig('Images/Histogramm_Zuggewicht.png')

# %% [markdown]
# #### Boxenplot Zugart und Geschwindigkeit <a class="anchor" id="zugart"></a>

# %%
ax = sns.catplot(y='SPEED', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Geschwindigkeit des Zuges")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Geschwindigkeit_Zugart.png')

# %% [markdown]
# #### Boxenplot Zugart und Gewicht

# %%
ax = sns.catplot(y='TONS', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Gewicht in t(ohne Lokomotiven)")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Gewicht_Zugart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Zugart

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Infrastruktur_Zugart.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Zugart

# %%
ax = sns.catplot(y='EQPDMG', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Material_Zugart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallart <a class="anchor" id="unfallart"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCIDENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallart")
plt.savefig('Images/Boxplot_Infrastruktur_Unfallart.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallart

# %%
ax = sns.catplot(y='EQPDMG', x='ACCIDENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallart")
plt.savefig('Images/Boxplot_Material_Unfallart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Streckenart <a class="anchor" id="typtrk"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='TYPTRK', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Streckenart")
plt.savefig('Images/Boxplot_Infrastruktur_Streckenart.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Streckenart

# %%
ax = sns.catplot(y='EQPDMG', x='TYPTRK', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Streckenart")
plt.savefig('Images/Boxplot_Material_Streckenart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallursache <a class="anchor" id="cause"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCCAUSE_LVL2', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallursache")
plt.savefig('Images/Boxplot_Infrastruktur_Unfallursache.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallursache

# %%
ax = sns.catplot(y='EQPDMG', x='ACCCAUSE_LVL2', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallursache")
plt.savefig('Images/Boxplot_Material_Unfallursache.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallschwere <a class="anchor" id="unfallsignifikanz"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCTYPE', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallschwere")
plt.savefig('Images/Boxplot_Infrastruktur_Unfallschwere.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallschwere

# %%
ax = sns.catplot(y='EQPDMG', x='ACCTYPE', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallschwere")
plt.savefig('Images/Boxplot_Material_Unfallschwere.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Wetter <a class="anchor" id="wetter"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='WEATHER', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Wetter")
plt.savefig('Images/Boxplot_Infrastruktur_Wetter.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Wetter

# %%
ax = sns.catplot(y='EQPDMG', x='WEATHER', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Wetter")
plt.savefig('Images/Boxplot_Material_Wetter.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Temperatur <a class="anchor" id="temp"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='TEMP_CLUSTER', data=df, palette="colorblind", order=temp_order, kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Temperatur")
plt.savefig('Images/Boxplot_Infrastruktur_Temperatur.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Temperatur

# %%
ax = sns.catplot(y='EQPDMG', x='TEMP_CLUSTER', data=df, palette="colorblind", order=temp_order, kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Temperatur")
plt.savefig('Images/Boxplot_Material_Temperatur.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Sichtbarkeit <a class="anchor" id="vis"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='VISIBLTY', data=df, palette="colorblind", kind='boxen', order=vis_order, height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Sichtbarkeit")
plt.savefig('Images/Boxplot_Infrastruktur_Sichtbarkeit.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Temperatur

# %%
ax = sns.catplot(y='EQPDMG', x='VISIBLTY', data=df, palette="colorblind", order=vis_order, kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Sichtbarkeit")
plt.savefig('Images/Boxplot_Material_Sichtbarkeit.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahreszeit <a class="anchor" id="jahreszeit"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='Jahreszeit', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Infrastruktur_Jahreszeit.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahreszeit (nach Unfallursache)

# %%
bp = sns.catplot(y='INFRASTRUCTURE_DMG', x='Jahreszeit', data=df, palette="colorblind", hue='ACCCAUSE_LVL2', kind="boxen", legend=False, height=10, aspect=1.5)
plt.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=4, frameon=False)
bp.set_ylabels("Infrastrukturschaden in Dollar")
bp.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Infrastruktur_Ursache_Sommer.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahreszeit

# %%
ax = sns.catplot(y='EQPDMG', x='Jahreszeit', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Material_Jahreszeit.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahreszeit (nach Unfallursache)

# %%
bp = sns.catplot(y='EQPDMG', x='Jahreszeit', data=df, palette="colorblind", hue='ACCCAUSE_LVL2', kind="boxen", legend=False, height=10, aspect=1.5)
plt.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=3, frameon=False)
bp.set_ylabels("Materialschaden in Dollar")
bp.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Material_Ursache_Sommer.png')
plt.show()

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahr <a class="anchor" id="jahr"></a>

# %%
bp = sns.catplot(x="YEAR4", y="INFRASTRUCTURE_DMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Infrastrukturschaden in Dollar', fontsize=12)
plt.savefig('Images/Boxplot_Infrastruktur_Jahr.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahr

# %%
bp = sns.catplot(x="YEAR4", y="EQPDMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Materialschaden in Dollar', fontsize=12)
plt.savefig('Images/Boxplot_Material_Jahr.png')

# %% [markdown]
# #### Boxenplot Streckenschaden und Jahr

# %%
bp = sns.catplot(x="YEAR4", y="TRKDMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Streckenschaden in Dollar', fontsize=12)
plt.savefig('Images/Boxplot_Strecke_Jahr.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Zug zu schnell? <a class="anchor" id="speed"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='SPD_TOO_HIGH', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Zug zu schnell?")
plt.savefig('Images/Boxplot_Infrastruktur_Zug_zu_schnell.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Zug zu schnell?

# %%
ax = sns.catplot(y='EQPDMG', x='SPD_TOO_HIGH', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Zug zu schnell?")
plt.savefig('Images/Boxplot_Material_Zug_zu_schnell.png')

# %% [markdown]
# ### Common Statistics <a class="anchor" id="common_statistics"></a>

# %%
x_data = df[['YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'TEMP_CLUSTER', 'SPEED', 'ACCCAUSE_LVL1', 'ACCIDENT_TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']]
y = df['INFRASTRUCTURE_DMG']

# %%
x_data.describe(include=np.number, percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
#               YEAR4         MONTH  LOCOMOTIVES1        LOADF1        LOADP1  \
# count  63695.000000  63695.000000  63695.000000  63695.000000  63695.000000
# mean    2000.986985      6.420378      2.409671     36.515755      0.129319
# std        9.855417      3.435645      1.262300     34.609016      0.803931
# min     1985.000000      1.000000      0.000000      0.000000      0.000000
# 10%     1988.000000      2.000000      1.000000      0.000000      0.000000
# 20%     1991.000000      3.000000      1.000000      4.000000      0.000000
# 30%     1994.000000      4.000000      2.000000     11.000000      0.000000
# 40%     1998.000000      5.000000      2.000000     19.000000      0.000000
# 50%     2001.000000      6.000000      2.000000     27.000000      0.000000
# 60%     2004.000000      8.000000      2.000000     37.000000      0.000000
# 70%     2007.000000      9.000000      3.000000     50.000000      0.000000
# 80%     2011.000000     10.000000      3.000000     65.000000      0.000000
# 90%     2015.000000     11.000000      4.000000     90.000000      0.000000
# max     2020.000000     12.000000      7.000000    161.000000      7.000000
#
#            EMPTYF1       EMPTYP1  LOCOMOTIVES2        LOADF2       EMPTYF2  \
# count  63695.00000  63695.000000  63695.000000  63695.000000  63695.000000
# mean      16.88817      0.013518      0.131549      2.802041      1.055876
# std       24.64836      0.176906      0.421923      3.500461      2.071424
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 10%        0.00000      0.000000      0.000000      0.000000      0.000000
# 20%        0.00000      0.000000      0.000000      0.000000      0.000000
# 30%        0.00000      0.000000      0.000000      0.000000      0.000000
# 40%        1.00000      0.000000      0.000000      1.000000      0.000000
# 50%        4.00000      0.000000      0.000000      2.000000      0.000000
# 60%       11.00000      0.000000      0.000000      3.000000      0.000000
# 70%       20.00000      0.000000      0.000000      4.000000      1.000000
# 80%       32.00000      0.000000      0.000000      5.000000      2.000000
# 90%       53.00000      0.000000      0.000000      7.000000      4.000000
# max      116.00000      3.000000      2.000000     20.000000     12.000000
#
#                TONS         SPEED
# count  63695.000000  63695.000000
# mean    4768.492191     13.937725
# std     4595.507411     15.607561
# min        0.000000      0.000000
# 10%      270.400000      3.000000
# 20%      977.975515      4.000000
# 30%     1800.000000      5.000000
# 40%     2666.233875      6.000000
# 50%     3564.000000      7.000000
# 60%     4714.000000      9.000000
# 70%     6053.000000     10.000000
# 80%     7850.000000     23.000000
# 90%    10921.000000     40.000000
# max    98000.000000    135.000000

# %%
x_data.describe(include=np.object, percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
#                      TEMP_CLUSTER   ACCCAUSE_LVL1 ACCIDENT_TYPE  \
# count                       63695           63695         63695
# unique                          5              31             4
# top     Moderat (0° bis 19,99° C)  Track Geometry    Derailment
# freq                        30190           10293         54145
#
#        EQUIPMENT_TYPE TYPTRK VISIBLTY WEATHER  STATE          ACCTYPE  \
# count           63695  63695    63694   63658  63695            63695
# unique              8      4        4       6     50                2
# top     Freight Train   Yard      Day   Clear  Texas  Not Significant
# freq            39297  28973    32612   41956   7250            54425
#
#        Jahreszeit
# count       63695
# unique          4
# top        Sommer
# freq        16864

# %%
y.describe(include='all', percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
# count    6.369500e+04
# mean     6.958978e+04
# std      1.390846e+05
# min      3.300000e+01
# 10%      8.500000e+03
# 20%      1.100000e+04
# 30%      1.396600e+04
# 40%      1.790000e+04
# 50%      2.335800e+04
# 60%      3.183860e+04
# 70%      4.690000e+04
# 80%      7.680160e+04
# 90%      1.601858e+05
# max      1.449030e+06
# Name: INFRASTRUCTURE_DMG, dtype: float64

# %%
ax = sns.jointplot(x='SPEED', y='INFRASTRUCTURE_DMG', data=df, kind='hex', gridsize=20)
plt.savefig(r"Images/JOINTPLOT_SPEED_INFRASTRUCTURE_DMG.png")

# %%
ax = sns.jointplot(x='TONS', y='INFRASTRUCTURE_DMG', data=df, kind='hex', gridsize=20)
plt.savefig(r"Images/JOINTPLOT_TONS_INFRASTRUCTURE_DMG.png")

# %% [markdown]
# ### Scattermatrix und Korrelationen der Daten <a class="anchor" id="correlations"></a>
# Jahr, Monat, Anzahl der beladenen Frachtwagons und Personenwagons, Gewicht, Temperatur, Geschwindigkeit und Unfallkosten

# %%
"""
scattermatrix = scatter_matrix(df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'SPEED']], diagonal='kde', figsize=(18, 18))
n = len(df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'SPEED']].columns)
for x in range(n):
    for y in range(n):
        # to get the axis of subplots
        ax = scattermatrix[x, y]
        # to make x axis name vertical  
        ax.xaxis.label.set_rotation(-90)
        # to make y axis name horizontal 
        ax.yaxis.label.set_rotation(0)
        # to make sure y axis names are outside the plot area
        ax.yaxis.labelpad = 50
plt.savefig(r"Images/scatterALL.png")
"""
# Out:
# '\nscattermatrix = scatter_matrix(df[[\'INFRASTRUCTURE_DMG\', \'EQPDMG\', \'TRKDMG\', \'YEAR4\', \'MONTH\', \'LOCOMOTIVES1\', \'LOADF1\', \'LOADP1\', \'EMPTYF1\', \'EMPTYP1\',\'LOCOMOTIVES2\', \'LOADF2\', \'EMPTYF2\', \'TONS\', \'SPEED\']], diagonal=\'kde\', figsize=(18, 18))\nn = len(df[[\'INFRASTRUCTURE_DMG\', \'EQPDMG\', \'TRKDMG\', \'YEAR4\', \'MONTH\', \'LOCOMOTIVES1\', \'LOADF1\', \'LOADP1\', \'EMPTYF1\', \'EMPTYP1\',\'LOCOMOTIVES2\', \'LOADF2\', \'EMPTYF2\', \'TONS\', \'SPEED\']].columns)\nfor x in range(n):\n    for y in range(n):\n        # to get the axis of subplots\n        ax = scattermatrix[x, y]\n        # to make x axis name vertical  \n        ax.xaxis.label.set_rotation(-90)\n        # to make y axis name horizontal \n        ax.yaxis.label.set_rotation(0)\n        # to make sure y axis names are outside the plot area\n        ax.yaxis.labelpad = 50\nplt.savefig(r"Images/scatterALL.png")\n'

# %%
colormap = plt.cm.RdBu
corr = df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'TEMP_CLUSTER', 'SPEED', 'ACCCAUSE_LVL1', 'TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']].corr()
corr
# Out:
#                     INFRASTRUCTURE_DMG    EQPDMG    TRKDMG     YEAR4  \
# INFRASTRUCTURE_DMG            1.000000  0.851683  0.700958  0.128512
# EQPDMG                        0.851683  1.000000  0.287464  0.087816
# TRKDMG                        0.700958  0.287464  1.000000  0.118043
# YEAR4                         0.128512  0.087816  0.118043  1.000000
# MONTH                        -0.005744 -0.001339 -0.009081 -0.010143
# LOCOMOTIVES1                  0.138648  0.106961  0.119405 -0.071370
# LOADF1                        0.248801  0.197976  0.205955 -0.030499
# LOADP1                       -0.000245  0.026392 -0.046044  0.046940
# EMPTYF1                      -0.008989 -0.013557  0.001279 -0.010263
# EMPTYP1                       0.001886  0.010238 -0.012417  0.011735
# LOCOMOTIVES2                  0.022470  0.032222 -0.003802  0.081675
# LOADF2                        0.425659  0.440436  0.230345 -0.123448
# EMPTYF2                       0.082388  0.099293  0.028967 -0.030673
# TONS                          0.241746  0.190275  0.201899  0.003923
# SPEED                         0.231812  0.221059  0.143657 -0.018585
# SPD_TOO_HIGH                  0.031220  0.034153  0.003669 -0.089622
#
#                        MONTH  LOCOMOTIVES1    LOADF1    LOADP1   EMPTYF1  \
# INFRASTRUCTURE_DMG -0.005744      0.138648  0.248801 -0.000245 -0.008989
# EQPDMG             -0.001339      0.106961  0.197976  0.026392 -0.013557
# TRKDMG             -0.009081      0.119405  0.205955 -0.046044  0.001279
# YEAR4              -0.010143     -0.071370 -0.030499  0.046940 -0.010263
# MONTH               1.000000      0.004140  0.005809  0.000491  0.007574
# LOCOMOTIVES1        0.004140      1.000000  0.404186 -0.144785  0.170587
# LOADF1              0.005809      0.404186  1.000000 -0.169353 -0.106066
# LOADP1              0.000491     -0.144785 -0.169353  1.000000 -0.110088
# EMPTYF1             0.007574      0.170587 -0.106066 -0.110088  1.000000
# EMPTYP1             0.006072     -0.072537 -0.076401  0.059463 -0.050360
# LOCOMOTIVES2       -0.003805      0.032968 -0.119782 -0.008959 -0.073285
# LOADF2             -0.014705      0.194555  0.435439 -0.128414 -0.173409
# EMPTYF2             0.003631      0.062272 -0.131381 -0.081827  0.446054
# TONS                0.002736      0.379888  0.847488 -0.157030  0.069828
# SPEED              -0.003343      0.110583  0.093452  0.378001  0.045357
# SPD_TOO_HIGH        0.002066      0.019756  0.007524 -0.012058 -0.007298
#
#                      EMPTYP1  LOCOMOTIVES2    LOADF2   EMPTYF2      TONS  \
# INFRASTRUCTURE_DMG  0.001886      0.022470  0.425659  0.082388  0.241746
# EQPDMG              0.010238      0.032222  0.440436  0.099293  0.190275
# TRKDMG             -0.012417     -0.003802  0.230345  0.028967  0.201899
# YEAR4               0.011735      0.081675 -0.123448 -0.030673  0.003923
# MONTH               0.006072     -0.003805 -0.014705  0.003631  0.002736
# LOCOMOTIVES1       -0.072537      0.032968  0.194555  0.062272  0.379888
# LOADF1             -0.076401     -0.119782  0.435439 -0.131381  0.847488
# LOADP1              0.059463     -0.008959 -0.128414 -0.081827 -0.157030
# EMPTYF1            -0.050360     -0.073285 -0.173409  0.446054  0.069828
# EMPTYP1             1.000000      0.034651 -0.057693 -0.035736 -0.073272
# LOCOMOTIVES2        0.034651      1.000000 -0.122570 -0.076296 -0.112330
# LOADF2             -0.057693     -0.122570  1.000000 -0.113280  0.362869
# EMPTYF2            -0.035736     -0.076296 -0.113280  1.000000 -0.042221
# TONS               -0.073272     -0.112330  0.362869 -0.042221  1.000000
# SPEED               0.012413     -0.053661 -0.019168 -0.042952  0.068687
# SPD_TOO_HIGH        0.001855      0.001116  0.045929  0.006445 -0.002270
#
#                        SPEED  SPD_TOO_HIGH
# INFRASTRUCTURE_DMG  0.231812      0.031220
# EQPDMG              0.221059      0.034153
# TRKDMG              0.143657      0.003669
# YEAR4              -0.018585     -0.089622
# MONTH              -0.003343      0.002066
# LOCOMOTIVES1        0.110583      0.019756
# LOADF1              0.093452      0.007524
# LOADP1              0.378001     -0.012058
# EMPTYF1             0.045357     -0.007298
# EMPTYP1             0.012413      0.001855
# LOCOMOTIVES2       -0.053661      0.001116
# LOADF2             -0.019168      0.045929
# EMPTYF2            -0.042952      0.006445
# TONS                0.068687     -0.002270
# SPEED               1.000000      0.111384
# SPD_TOO_HIGH        0.111384      1.000000

# %%
ax=plt.figure(figsize=(20,15)).gca()
ax=sns.heatmap(corr,ax=ax,linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True);
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.savefig(r"Images/corrALL.png")

# %%
corr = df[df['TONS']!=0][['TONS', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1', 'LOADF2', 'EMPTYF2']].corr()
corr
# Out:
#              TONS    LOADF1    LOADP1   EMPTYF1   EMPTYP1    LOADF2   EMPTYF2
# TONS     1.000000  0.842174 -0.164990  0.049182 -0.076928  0.346468 -0.059735
# LOADF1   0.842174  1.000000 -0.177718 -0.131470 -0.080198  0.420814 -0.151142
# LOADP1  -0.164990 -0.177718  1.000000 -0.114353  0.059143 -0.133756 -0.084724
# EMPTYF1  0.049182 -0.131470 -0.114353  1.000000 -0.052304 -0.193563  0.440307
# EMPTYP1 -0.076928 -0.080198  0.059143 -0.052304  1.000000 -0.060118 -0.037049
# LOADF2   0.346468  0.420814 -0.133756 -0.193563 -0.060118  1.000000 -0.127611
# EMPTYF2 -0.059735 -0.151142 -0.084724  0.440307 -0.037049 -0.127611  1.000000

# %% [markdown]
# ### ANOVA <a class="anchor" id="ANOVA"></a>

# %%
anova_df =df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'TEMP_CLUSTER', 'ACCCAUSE_LVL1', 'ACCCAUSE_LVL2', 'ACCIDENT_TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']]

# %%
anova = anova_df.copy()
anova = anova.dropna

# %%
def anova(dmg, cat):
    #print ("ANOVA für INFRASTRUCUTURE_DMG ~ %s :" % (cat))
    mod= ols(dmg + ' ~ ' + cat , data=anova_df).fit()
    anova_table = sm.stats.anova_lm(mod, typ=2)
    esq_sm = anova_table['sum_sq'][0]/(anova_table['sum_sq'][0]+anova_table['sum_sq'][1])
    anova_table['EtaSq'] = [esq_sm, 'NaN']
    anova_table
    pair_t = mod.t_test_pairwise(cat)
    anova_table
    pair_t.result_frame
    return [anova_table, pair_t.result_frame]

# %% [markdown]
# #### ANOVA Korrelation Temperatur Cluster und Damage

# %%
temp_cluster = anova("INFRASTRUCTURE_DMG","TEMP_CLUSTER")

# %%
temp_cluster[0]
# Out:
#                     sum_sq       df          F        PR(>F)       EtaSq
# TEMP_CLUSTER  3.186341e+12      4.0  41.282999  1.286372e-34  0.00258604
# Residual      1.228944e+15  63690.0        NaN           NaN         NaN

# %%
temp_cluster[1]
# Out:
#                                                                coef  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                  -5386.997281
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)             -20552.222011
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)           -10402.539982
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)               -21487.334211
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)       -15165.224730
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      -5015.542701
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)         -16100.336930
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  10149.682028
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)       -935.112200
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)   -11084.794228
#
#                                                             std err         t  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                   2589.653752 -2.080200
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               2249.151991 -9.137765
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)            24645.705351 -0.422083
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 2313.676811 -9.287094
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)         1710.528398 -8.865813
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      24602.398562 -0.203864
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           1794.525873 -8.971917
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  24568.890759  0.413111
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)       1254.073855 -0.745660
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)    24574.881664 -0.451062
#
#                                                               P>|t|  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                  3.751120e-02
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)              6.556644e-20
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)            6.729657e-01
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                1.633619e-20
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)        7.785848e-19
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      8.384605e-01
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)          2.990861e-19
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  6.795266e-01
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)      4.558758e-01
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)    6.519464e-01
#
#                                                        Conf. Int. Low  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                   -10462.721826
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               -24960.562686
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)             -58708.152844
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 -26022.143612
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)         -18517.862498
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)       -53236.274202
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           -19617.609851
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)   -38005.374137
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)        -3393.098500
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)     -59251.592576
#
#                                                        Conf. Int. Upp.  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                      -311.272736
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)                -16143.881336
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)               37903.072880
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                  -16952.524809
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)          -11812.586961
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)         43205.188799
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)            -12583.064008
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)     58304.738194
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)          1522.874100
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)       37082.004120
#
#                                                        pvalue-hs  reject-hs
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                   0.204987      False
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               0.000000       True
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)             0.985325      False
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 0.000000       True
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)         0.000000       True
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)       0.985325      False
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           0.000000       True
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)   0.985325      False
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)       0.952303      False
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)     0.985325      False

# %% [markdown]
# #### ANOVA Korrelation Unfallursachen Cluster und Damage

# %%
cause = anova("INFRASTRUCTURE_DMG","ACCCAUSE_LVL2")

# %%
cause[0]
# Out:
#                      sum_sq       df           F         PR(>F)      EtaSq
# ACCCAUSE_LVL2  2.445390e+13      6.0  214.933298  1.164699e-272  0.0198468
# Residual       1.207677e+15  63688.0         NaN            NaN        NaN

# %%
cause[1]
# Out:
#                                                                           coef  \
# Human Factors-Environmental Conditions                           -89089.442755
# Loading-Environmental Conditions                                 -83768.470797
# Mechanical and Electrical Failures-Environmental Conditions      -34485.936723
# Miscellaneous Causes-Environmental Conditions                    -74388.949947
# Signal and Communication-Environmental Conditions                -93953.235419
# Track, Roadbed and Structures-Environmental Conditions           -61703.438111
# Loading-Human Factors                                              5320.971958
# Mechanical and Electrical Failures-Human Factors                  54603.506032
# Miscellaneous Causes-Human Factors                                14700.492808
# Signal and Communication-Human Factors                            -4863.792664
# Track, Roadbed and Structures-Human Factors                       27386.004644
# Mechanical and Electrical Failures-Loading                        49282.534074
# Miscellaneous Causes-Loading                                       9379.520850
# Signal and Communication-Loading                                 -10184.764622
# Track, Roadbed and Structures-Loading                             22065.032686
# Miscellaneous Causes-Mechanical and Electrical Failures          -39903.013224
# Signal and Communication-Mechanical and Electrical Failures      -59467.298696
# Track, Roadbed and Structures-Mechanical and Electrical Failures -27217.501388
# Signal and Communication-Miscellaneous Causes                    -19564.285472
# Track, Roadbed and Structures-Miscellaneous Causes                12685.511836
# Track, Roadbed and Structures-Signal and Communication            32249.797308
#
#                                                                       std err  \
# Human Factors-Environmental Conditions                            4689.724296
# Loading-Environmental Conditions                                  4874.736252
# Mechanical and Electrical Failures-Environmental Conditions       4793.598760
# Miscellaneous Causes-Environmental Conditions                     4894.056863
# Signal and Communication-Environmental Conditions                 7179.702879
# Track, Roadbed and Structures-Environmental Conditions            4645.254990
# Loading-Human Factors                                             2031.434655
# Mechanical and Electrical Failures-Human Factors                  1828.185521
# Miscellaneous Causes-Human Factors                                2077.369925
# Signal and Communication-Human Factors                            5649.053608
# Track, Roadbed and Structures-Human Factors                       1393.580693
# Mechanical and Electrical Failures-Loading                        2260.929422
# Miscellaneous Causes-Loading                                      2466.780363
# Signal and Communication-Loading                                  5803.563235
# Track, Roadbed and Structures-Loading                             1926.553062
# Miscellaneous Causes-Mechanical and Electrical Failures           2302.290359
# Signal and Communication-Mechanical and Electrical Failures       5735.580333
# Track, Roadbed and Structures-Mechanical and Electrical Failures  1710.889313
# Signal and Communication-Miscellaneous Causes                     5819.801136
# Track, Roadbed and Structures-Miscellaneous Causes                1974.929302
# Track, Roadbed and Structures-Signal and Communication            5612.190892
#
#                                                                           t  \
# Human Factors-Environmental Conditions                           -18.996734
# Loading-Environmental Conditions                                 -17.184206
# Mechanical and Electrical Failures-Environmental Conditions       -7.194164
# Miscellaneous Causes-Environmental Conditions                    -15.199854
# Signal and Communication-Environmental Conditions                -13.085950
# Track, Roadbed and Structures-Environmental Conditions           -13.283111
# Loading-Human Factors                                              2.619317
# Mechanical and Electrical Failures-Human Factors                  29.867596
# Miscellaneous Causes-Human Factors                                 7.076493
# Signal and Communication-Human Factors                            -0.860992
# Track, Roadbed and Structures-Human Factors                       19.651539
# Mechanical and Electrical Failures-Loading                        21.797467
# Miscellaneous Causes-Loading                                       3.802333
# Signal and Communication-Loading                                  -1.754916
# Track, Roadbed and Structures-Loading                             11.453114
# Miscellaneous Causes-Mechanical and Electrical Failures          -17.331877
# Signal and Communication-Mechanical and Electrical Failures      -10.368140
# Track, Roadbed and Structures-Mechanical and Electrical Failures -15.908394
# Signal and Communication-Miscellaneous Causes                     -3.361676
# Track, Roadbed and Structures-Miscellaneous Causes                 6.423274
# Track, Roadbed and Structures-Signal and Communication             5.746383
#
#                                                                           P>|t|  \
# Human Factors-Environmental Conditions                             3.028785e-80
# Loading-Environmental Conditions                                   4.916326e-66
# Mechanical and Electrical Failures-Environmental Conditions        6.353403e-13
# Miscellaneous Causes-Environmental Conditions                      4.375900e-52
# Signal and Communication-Environmental Conditions                  4.450086e-39
# Track, Roadbed and Structures-Environmental Conditions             3.281716e-40
# Loading-Human Factors                                              8.812683e-03
# Mechanical and Electrical Failures-Human Factors                  1.153815e-194
# Miscellaneous Causes-Human Factors                                 1.493687e-12
# Signal and Communication-Human Factors                             3.892454e-01
# Track, Roadbed and Structures-Human Factors                        1.007845e-85
# Mechanical and Electrical Failures-Loading                        5.944427e-105
# Miscellaneous Causes-Loading                                       1.434733e-04
# Signal and Communication-Loading                                   7.927852e-02
# Track, Roadbed and Structures-Loading                              2.429234e-30
# Miscellaneous Causes-Mechanical and Electrical Failures            3.857555e-67
# Signal and Communication-Mechanical and Electrical Failures        3.625497e-25
# Track, Roadbed and Structures-Mechanical and Electrical Failures   7.135100e-57
# Signal and Communication-Miscellaneous Causes                      7.751653e-04
# Track, Roadbed and Structures-Miscellaneous Causes                 1.343110e-10
# Track, Roadbed and Structures-Signal and Communication             9.158714e-09
#
#                                                                   Conf. Int. Low  \
# Human Factors-Environmental Conditions                             -98281.308160
# Loading-Environmental Conditions                                   -93322.959865
# Mechanical and Electrical Failures-Environmental Conditions        -43881.396205
# Miscellaneous Causes-Environmental Conditions                      -83981.307435
# Signal and Communication-Environmental Conditions                 -108025.461919
# Track, Roadbed and Structures-Environmental Conditions             -70808.143621
# Loading-Human Factors                                                1339.357528
# Mechanical and Electrical Failures-Human Factors                    51020.260156
# Miscellaneous Causes-Human Factors                                  10628.845193
# Signal and Communication-Human Factors                             -15935.944704
# Track, Roadbed and Structures-Human Factors                         24654.584766
# Mechanical and Electrical Failures-Loading                          44851.109617
# Miscellaneous Causes-Loading                                         4544.628296
# Signal and Communication-Loading                                   -21559.755721
# Track, Roadbed and Structures-Loading                               18288.986307
# Miscellaneous Causes-Mechanical and Electrical Failures            -44415.505168
# Signal and Communication-Mechanical and Electrical Failures        -70709.043224
# Track, Roadbed and Structures-Mechanical and Electrical Failures   -30570.846553
# Signal and Communication-Miscellaneous Causes                      -30971.102878
# Track, Roadbed and Structures-Miscellaneous Causes                   8814.647968
# Track, Roadbed and Structures-Signal and Communication              21249.896237
#
#                                                                   Conf. Int. Upp.  \
# Human Factors-Environmental Conditions                              -79897.577349
# Loading-Environmental Conditions                                    -74213.981729
# Mechanical and Electrical Failures-Environmental Conditions         -25090.477241
# Miscellaneous Causes-Environmental Conditions                       -64796.592459
# Signal and Communication-Environmental Conditions                   -79881.008919
# Track, Roadbed and Structures-Environmental Conditions              -52598.732601
# Loading-Human Factors                                                 9302.586387
# Mechanical and Electrical Failures-Human Factors                     58186.751908
# Miscellaneous Causes-Human Factors                                   18772.140423
# Signal and Communication-Human Factors                                6208.359376
# Track, Roadbed and Structures-Human Factors                          30117.424521
# Mechanical and Electrical Failures-Loading                           53713.958531
# Miscellaneous Causes-Loading                                         14214.413404
# Signal and Communication-Loading                                      1190.226477
# Track, Roadbed and Structures-Loading                                25841.079065
# Miscellaneous Causes-Mechanical and Electrical Failures             -35390.521280
# Signal and Communication-Mechanical and Electrical Failures         -48225.554168
# Track, Roadbed and Structures-Mechanical and Electrical Failures    -23864.156223
# Signal and Communication-Miscellaneous Causes                        -8157.468066
# Track, Roadbed and Structures-Miscellaneous Causes                   16556.375704
# Track, Roadbed and Structures-Signal and Communication               43249.698379
#
#                                                                      pvalue-hs  \
# Human Factors-Environmental Conditions                            0.000000e+00
# Loading-Environmental Conditions                                  0.000000e+00
# Mechanical and Electrical Failures-Environmental Conditions       5.718426e-12
# Miscellaneous Causes-Environmental Conditions                     0.000000e+00
# Signal and Communication-Environmental Conditions                 0.000000e+00
# Track, Roadbed and Structures-Environmental Conditions            0.000000e+00
# Loading-Human Factors                                             2.620574e-02
# Mechanical and Electrical Failures-Human Factors                  0.000000e+00
# Miscellaneous Causes-Human Factors                                1.194955e-11
# Signal and Communication-Human Factors                            3.892454e-01
# Track, Roadbed and Structures-Human Factors                       0.000000e+00
# Mechanical and Electrical Failures-Loading                        0.000000e+00
# Miscellaneous Causes-Loading                                      7.171609e-04
# Signal and Communication-Loading                                  1.522720e-01
# Track, Roadbed and Structures-Loading                             0.000000e+00
# Miscellaneous Causes-Mechanical and Electrical Failures           0.000000e+00
# Signal and Communication-Mechanical and Electrical Failures       0.000000e+00
# Track, Roadbed and Structures-Mechanical and Electrical Failures  0.000000e+00
# Signal and Communication-Miscellaneous Causes                     3.097058e-03
# Track, Roadbed and Structures-Miscellaneous Causes                9.401770e-10
# Track, Roadbed and Structures-Signal and Communication            5.495229e-08
#
#                                                                   reject-hs
# Human Factors-Environmental Conditions                                 True
# Loading-Environmental Conditions                                       True
# Mechanical and Electrical Failures-Environmental Conditions            True
# Miscellaneous Causes-Environmental Conditions                          True
# Signal and Communication-Environmental Conditions                      True
# Track, Roadbed and Structures-Environmental Conditions                 True
# Loading-Human Factors                                                  True
# Mechanical and Electrical Failures-Human Factors                       True
# Miscellaneous Causes-Human Factors                                     True
# Signal and Communication-Human Factors                                False
# Track, Roadbed and Structures-Human Factors                            True
# Mechanical and Electrical Failures-Loading                             True
# Miscellaneous Causes-Loading                                           True
# Signal and Communication-Loading                                      False
# Track, Roadbed and Structures-Loading                                  True
# Miscellaneous Causes-Mechanical and Electrical Failures                True
# Signal and Communication-Mechanical and Electrical Failures            True
# Track, Roadbed and Structures-Mechanical and Electrical Failures       True
# Signal and Communication-Miscellaneous Causes                          True
# Track, Roadbed and Structures-Miscellaneous Causes                     True
# Track, Roadbed and Structures-Signal and Communication                 True

# %% [markdown]
# #### ANOVA Korrelation Unfallart und Damage

# %%
accidenttype = anova("INFRASTRUCTURE_DMG","ACCIDENT_TYPE")

# %%
accidenttype[0]
# Out:
#                      sum_sq       df          F        PR(>F)      EtaSq
# ACCIDENT_TYPE  3.221772e+12      3.0  55.658547  6.374218e-36  0.0026148
# Residual       1.228909e+15  63691.0        NaN           NaN        NaN

# %%
accidenttype[1]
# Out:
#                                                                   coef  \
# Crossing-Collision                                       -10046.683882
# Derailment-Collision                                      13595.025376
# Fire / Violent Rupture / Explosive Detonation-Collision   17656.162539
# Derailment-Crossing                                       23641.709258
# Fire / Violent Rupture / Explosive Detonation-Crossing    27702.846421
# Fire / Violent Rupture / Explosive Detonation-Derailment   4061.137163
#
#                                                               std err  \
# Crossing-Collision                                        3119.287806
# Derailment-Collision                                      2566.032377
# Fire / Violent Rupture / Explosive Detonation-Collision   5168.271844
# Derailment-Crossing                                       1964.216120
# Fire / Violent Rupture / Explosive Detonation-Crossing    4897.413262
# Fire / Violent Rupture / Explosive Detonation-Derailment  4564.999716
#
#                                                                   t  \
# Crossing-Collision                                        -3.220826
# Derailment-Collision                                       5.298072
# Fire / Violent Rupture / Explosive Detonation-Collision    3.416260
# Derailment-Crossing                                       12.036206
# Fire / Violent Rupture / Explosive Detonation-Crossing     5.656628
# Fire / Violent Rupture / Explosive Detonation-Derailment   0.889625
#
#                                                                  P>|t|  \
# Crossing-Collision                                        1.278858e-03
# Derailment-Collision                                      1.174195e-07
# Fire / Violent Rupture / Explosive Detonation-Collision   6.352712e-04
# Derailment-Crossing                                       2.491970e-33
# Fire / Violent Rupture / Explosive Detonation-Crossing    1.550355e-08
# Fire / Violent Rupture / Explosive Detonation-Derailment  3.736707e-01
#
#                                                           Conf. Int. Low  \
# Crossing-Collision                                         -16160.491824
# Derailment-Collision                                         8565.598756
# Fire / Violent Rupture / Explosive Detonation-Collision      7526.343359
# Derailment-Crossing                                         19791.843243
# Fire / Violent Rupture / Explosive Detonation-Crossing      18103.910395
# Fire / Violent Rupture / Explosive Detonation-Derailment    -4886.267903
#
#                                                           Conf. Int. Upp.  \
# Crossing-Collision                                           -3932.875941
# Derailment-Collision                                         18624.451996
# Fire / Violent Rupture / Explosive Detonation-Collision      27785.981719
# Derailment-Crossing                                          27491.575274
# Fire / Violent Rupture / Explosive Detonation-Crossing       37301.782447
# Fire / Violent Rupture / Explosive Detonation-Derailment     13008.542228
#
#                                                              pvalue-hs  \
# Crossing-Collision                                        2.556080e-03
# Derailment-Collision                                      4.696777e-07
# Fire / Violent Rupture / Explosive Detonation-Collision   1.904603e-03
# Derailment-Crossing                                       0.000000e+00
# Fire / Violent Rupture / Explosive Detonation-Crossing    7.751774e-08
# Fire / Violent Rupture / Explosive Detonation-Derailment  3.736707e-01
#
#                                                           reject-hs
# Crossing-Collision                                             True
# Derailment-Collision                                           True
# Fire / Violent Rupture / Explosive Detonation-Collision        True
# Derailment-Crossing                                            True
# Fire / Violent Rupture / Explosive Detonation-Crossing         True
# Fire / Violent Rupture / Explosive Detonation-Derailment      False

# %% [markdown]
# #### ANOVA Korrelation Zugart und Damage

# %%
eqtype = anova("INFRASTRUCTURE_DMG","EQUIPMENT_TYPE")

# %%
eqtype[0]
# Out:
#                       sum_sq       df           F  PR(>F)      EtaSq
# EQUIPMENT_TYPE  3.866284e+13      7.0  294.737757     0.0  0.0313788
# Residual        1.193468e+15  63687.0         NaN     NaN        NaN

# %%
eqtype[1]
# Out:
#                                         coef      std err          t  \
# Cut of Cars-Commuter Train     -32833.201735  8185.970930  -4.010911
# Freight Train-Commuter Train    20410.870793  7179.025580   2.843126
# Locomotive-Commuter Train      -34978.711544  7797.203772  -4.486058
# Passenger Train-Commuter Train     22.730199  7856.666525   0.002893
# Single Car-Commuter Train      -38132.784720  9355.205659  -4.076103
# Work Train-Commuter Train       -5228.301674  9065.892967  -0.576700
# Yard/Switching-Commuter Train  -31633.158809  7217.983226  -4.382548
# Freight Train-Cut of Cars       53244.072528  4052.832715  13.137496
# Locomotive-Cut of Cars          -2145.509809  5067.882339  -0.423354
# Passenger Train-Cut of Cars     32855.931933  5158.900427   6.368786
# Single Car-Cut of Cars          -5299.582985  7239.262232  -0.732061
# Work Train-Cut of Cars          27604.900061  6861.301627   4.023275
# Yard/Switching-Cut of Cars       1200.042926  4121.447146   0.291170
# Locomotive-Freight Train       -55389.582337  3195.578134 -17.333196
# Passenger Train-Freight Train  -20388.140594  3338.044611  -6.107810
# Single Car-Freight Train       -58543.655513  6077.434152  -9.632956
# Work Train-Freight Train       -25639.172467  5621.898987  -4.560589
# Yard/Switching-Freight Train   -52044.029602  1230.696870 -42.288260
# Passenger Train-Locomotive      35001.441743  4516.693505   7.749351
# Single Car-Locomotive           -3154.073176  6796.556795  -0.464069
# Work Train-Locomotive           29750.409870  6392.474217   4.653974
# Yard/Switching-Locomotive        3345.552735  3282.162881   1.019313
# Single Car-Passenger Train     -38155.514919  6864.692745  -5.558226
# Work Train-Passenger Train      -5251.031873  6464.870365  -0.812241
# Yard/Switching-Passenger Train -31655.889007  3421.025488  -9.253333
# Work Train-Single Car           32904.483046  8221.144256   4.002421
# Yard/Switching-Single Car        6499.625911  6123.404236   1.061440
# Yard/Switching-Work Train      -26404.857135  5671.562553  -4.655658
#
#                                        P>|t|  Conf. Int. Low  Conf. Int. Upp.  \
# Cut of Cars-Commuter Train      6.055384e-05   -48877.714861    -16788.688608
# Freight Train-Commuter Train    4.468768e-03     6339.971796     34481.769790
# Locomotive-Commuter Train       7.267955e-06   -50261.240561    -19696.182527
# Passenger Train-Commuter Train  9.976916e-01   -15376.345886     15421.806284
# Single Car-Commuter Train       4.585218e-05   -56468.999358    -19796.570082
# Work Train-Commuter Train       5.641441e-01   -22997.463077     12540.859730
# Yard/Switching-Commuter Train   1.174866e-05   -45780.414839    -17485.902779
# Freight Train-Cut of Cars       2.259220e-39    45300.515405     61187.629650
# Locomotive-Cut of Cars          6.720382e-01   -12078.565449      7787.545830
# Passenger Train-Cut of Cars     1.918248e-10    22744.480729     42967.383138
# Single Car-Cut of Cars          4.641339e-01   -19488.545895      8889.379924
# Work Train-Cut of Cars          5.746073e-05    14156.740404     41053.059718
# Yard/Switching-Cut of Cars      7.709220e-01    -6877.998567      9278.084419
# Locomotive-Freight Train        3.770501e-67   -61652.919423    -49126.245251
# Passenger Train-Freight Train   1.015903e-09   -26930.712151    -13845.569037
# Single Car-Freight Train        6.007220e-22   -70455.433951    -46631.877075
# Work Train-Freight Train        5.110514e-06   -36658.101420    -14620.243513
# Yard/Switching-Freight Train    0.000000e+00   -54456.196985    -49631.862219
# Passenger Train-Locomotive      9.372347e-15    26148.716899     43854.166586
# Single Car-Locomotive           6.425997e-01   -16475.332881     10167.186529
# Work Train-Locomotive           3.262522e-06    17221.152516     42279.667225
# Yard/Switching-Locomotive       3.080581e-01    -3087.490562      9778.596032
# Single Car-Passenger Train      2.736182e-08   -51610.321170    -24700.708667
# Work Train-Passenger Train      4.166565e-01   -17922.185766      7420.122021
# Yard/Switching-Passenger Train  2.240959e-20   -38361.103186    -24950.674829
# Work Train-Single Car           6.276843e-05    16791.030158     49017.935934
# Yard/Switching-Single Car       2.884940e-01    -5502.253949     18501.505771
# Yard/Switching-Work Train       3.235973e-06   -37521.126738    -15288.587532
#
#                                    pvalue-hs  reject-hs
# Cut of Cars-Commuter Train      7.467320e-04       True
# Freight Train-Commuter Train    4.379967e-02       True
# Locomotive-Commuter Train       1.162809e-04       True
# Passenger Train-Commuter Train  9.976916e-01      False
# Single Car-Commuter Train       6.417393e-04       True
# Work Train-Commuter Train       9.842705e-01      False
# Yard/Switching-Commuter Train   1.762154e-04       True
# Freight Train-Cut of Cars       0.000000e+00       True
# Locomotive-Cut of Cars          9.842705e-01      False
# Passenger Train-Cut of Cars     4.220145e-09       True
# Single Car-Cut of Cars          9.770136e-01      False
# Work Train-Cut of Cars          7.467320e-04       True
# Yard/Switching-Cut of Cars      9.842705e-01      False
# Locomotive-Freight Train        0.000000e+00       True
# Passenger Train-Freight Train   2.133397e-08       True
# Single Car-Freight Train        0.000000e+00       True
# Work Train-Freight Train        8.687518e-05       True
# Yard/Switching-Freight Train    0.000000e+00       True
# Passenger Train-Locomotive      2.144951e-13       True
# Single Car-Locomotive           9.842705e-01      False
# Work Train-Locomotive           6.148170e-05       True
# Yard/Switching-Locomotive       9.532688e-01      False
# Single Car-Passenger Train      5.472363e-07       True
# Work Train-Passenger Train      9.770136e-01      False
# Yard/Switching-Passenger Train  0.000000e+00       True
# Work Train-Single Car           7.467320e-04       True
# Yard/Switching-Single Car       9.532688e-01      False
# Yard/Switching-Work Train       6.148170e-05       True

# %% [markdown]
# #### ANOVA Korrelation Sichtbarkeit und Damage

# %%
vis = anova("INFRASTRUCTURE_DMG","VISIBLTY")

# %%
vis[0]
# Out:
#                 sum_sq       df          F        PR(>F)        EtaSq
# VISIBLTY  1.190817e+12      3.0  20.538037  2.695213e-13  0.000966471
# Residual  1.230937e+15  63690.0        NaN           NaN          NaN

# %%
vis[1]
# Out:
#                    coef      std err         t         P>|t|  Conf. Int. Low  \
# Dawn-Dark  15420.108653  2703.913353  5.702886  1.183158e-08    10120.435149
# Day-Dark   -4043.824952  1169.513512 -3.457698  5.451666e-04    -6336.072877
# Dusk-Dark  -6480.977858  2613.781342 -2.479541  1.315773e-02   -11603.992509
# Day-Dawn  -19463.933606  2669.954228 -7.289988  3.135666e-13   -24697.047183
# Dusk-Dawn -21901.086511  3548.626020 -6.171709  6.796159e-10   -28856.397883
# Dusk-Day   -2437.152906  2578.635503 -0.945133  3.445947e-01    -7491.281670
#
#            Conf. Int. Upp.     pvalue-hs  reject-hs
# Dawn-Dark     20719.782158  4.732630e-08       True
# Day-Dark      -1751.577027  1.634608e-03       True
# Dusk-Dark     -1357.963207  2.614233e-02       True
# Day-Dawn     -14230.820028  1.881162e-12       True
# Dusk-Dawn    -14945.775140  3.398080e-09       True
# Dusk-Day       2616.975859  3.445947e-01      False

# %% [markdown]
# #### ANOVA Korrelation Wetter und Damage

# %%
weather = anova("INFRASTRUCTURE_DMG","WEATHER")

# %%
weather[0]
# Out:
#                 sum_sq       df         F    PR(>F)        EtaSq
# WEATHER   2.991390e+11      5.0  3.091751  0.008577  0.000242805
# Residual  1.231716e+15  63652.0       NaN       NaN          NaN

# %%
weather[1]
# Out:
#                       coef       std err         t     P>|t|  Conf. Int. Low  \
# Cloudy-Clear   -637.994700   1316.227213 -0.484715  0.627880    -3217.801689
# Fog-Clear     10860.062350   5088.154479  2.134381  0.032815      887.273188
# Rain-Clear      670.567507   2258.446226  0.296915  0.766532    -3755.989928
# Sleet-Clear    5868.148380  12411.239541  0.472809  0.636351   -18457.896692
# Snow-Clear    11938.845587   3750.914876  3.182916  0.001459     4587.047724
# Fog-Cloudy    11498.057050   5167.140197  2.225226  0.026070     1370.455781
# Rain-Cloudy    1308.562207   2431.172797  0.538243  0.590411    -3456.539525
# Sleet-Cloudy   6506.143079  12443.829345  0.522841  0.601087   -17883.778049
# Snow-Cloudy   12576.840286   3857.380487  3.260461  0.001113     5016.369693
# Rain-Fog     -10189.494843   5483.380626 -1.858251  0.063138   -20936.927750
# Sleet-Fog     -4991.913971  13379.303072 -0.373107  0.709070   -31215.364777
# Snow-Fog       1078.783236   6247.899339  0.172663  0.862917   -11167.107306
# Sleet-Rain     5197.580872  12578.434483  0.413214  0.679451   -19456.166495
# Snow-Rain     11268.278079   4271.710371  2.637884  0.008345     2895.720392
# Snow-Sleet     6070.697207  12930.034690  0.469504  0.638711   -19272.187008
#
#               Conf. Int. Upp.  pvalue-hs  reject-hs
# Cloudy-Clear      1941.812289   0.999676      False
# Fog-Clear        20832.851513   0.307207      False
# Rain-Clear        5097.124943   0.999676      False
# Sleet-Clear      30194.193451   0.999676      False
# Snow-Clear       19290.643449   0.020229       True
# Fog-Cloudy       21625.658319   0.271658      False
# Rain-Cloudy       6073.663939   0.999676      False
# Sleet-Cloudy     30896.064207   0.999676      False
# Snow-Cloudy      20137.310880   0.016564       True
# Rain-Fog           557.938065   0.479098      False
# Sleet-Fog        21231.536836   0.999676      False
# Snow-Fog         13324.673779   0.999676      False
# Sleet-Rain       29851.328239   0.999676      False
# Snow-Rain        19640.835767   0.103210      False
# Snow-Sleet       31413.581422   0.999676      False

# %% [markdown]
# #### ANOVA Korrelation zu hoher Geschwindigkeit und Damage

# %%
spd = anova("INFRASTRUCTURE_DMG","SPD_TOO_HIGH")

# %%
spd[0]
# Out:
#                     sum_sq       df          F        PR(>F)        EtaSq
# SPD_TOO_HIGH  1.200949e+12      1.0  62.141691  3.246479e-15  0.000974693
# Residual      1.230930e+15  63693.0        NaN           NaN          NaN

# %%
spd[1]
# Out:
#                     coef      std err      t         P>|t|  Conf. Int. Low  \
# True-False  23618.635295  2996.148025  7.883  3.246479e-15    17746.181479
#
#             Conf. Int. Upp.     pvalue-hs  reject-hs
# True-False     29491.089112  3.219647e-15       True

# %% [markdown]
# #### ANOVA Korrelation Streckenart und Damage

# %%
typtrk = anova("INFRASTRUCTURE_DMG","TYPTRK")

# %%
typtrk[0]
# Out:
#                 sum_sq       df            F  PR(>F)      EtaSq
# TYPTRK    8.041235e+13      3.0  1482.290384     0.0  0.0652628
# Residual  1.151718e+15  63691.0          NaN     NaN        NaN

# %%
typtrk[1]
# Out:
#                          coef      std err          t         P>|t|  \
# Main-Industry    74525.146800  1917.862374  38.858444  0.000000e+00
# Siding-Industry  31489.286890  3201.050581   9.837173  8.084201e-23
# Yard-Industry     1533.316206  1900.410052   0.806834  4.197649e-01
# Siding-Main     -43035.859910  2819.585668 -15.263186  1.666718e-52
# Yard-Main       -72991.830595  1146.689533 -63.654397  0.000000e+00
# Yard-Siding     -29955.970684  2807.743867 -10.669054  1.496016e-26
#
#                  Conf. Int. Low  Conf. Int. Upp.  pvalue-hs  reject-hs
# Main-Industry      70766.134185     78284.159416   0.000000       True
# Siding-Industry    25215.223809     37763.349971   0.000000       True
# Yard-Industry      -2191.489838      5258.122249   0.419765      False
# Siding-Main       -48562.251293    -37509.468528   0.000000       True
# Yard-Main         -75239.343492    -70744.317697   0.000000       True
# Yard-Siding       -35459.152122    -24452.789247   0.000000       True

# %% [markdown]
# #### ANOVA Korrelation Signifikanzlevel und Damage

# %%
acctype = anova("INFRASTRUCTURE_DMG","ACCTYPE")

# %%
acctype[0]
# Out:
#                 sum_sq       df             F  PR(>F)     EtaSq
# ACCTYPE   4.509579e+14      1.0  36768.890482     0.0  0.365998
# Residual  7.811729e+14  63693.0           NaN     NaN       NaN

# %%
acctype[1]
# Out:
#                                       coef     std err           t  P>|t|  \
# Significant-Not Significant  238606.116438  1244.34644  191.752159    0.0
#
#                              Conf. Int. Low  Conf. Int. Upp.  pvalue-hs  \
# Significant-Not Significant   236167.195884    241045.036992        0.0
#
#                              reject-hs
# Significant-Not Significant       True

# %% [markdown]
# #### ANOVA Korrelation Jahreszeit und Damage

# %%
jahreszeit = anova("INFRASTRUCTURE_DMG","Jahreszeit")

# %%
jahreszeit[0]
# Out:
#                   sum_sq       df         F    PR(>F)        EtaSq
# Jahreszeit  2.238746e+11      3.0  3.858191  0.008996  0.000181697
# Residual    1.231907e+15  63691.0       NaN       NaN          NaN

# %%
jahreszeit[1]
# Out:
#                         coef      std err         t     P>|t|  Conf. Int. Low  \
# Herbst-Frühling -3132.268192  1588.548959 -1.971779  0.048639    -6245.826108
# Sommer-Frühling  2131.575060  1534.544008  1.389061  0.164819     -876.133085
# Winter-Frühling  -866.666477  1551.792071 -0.558494  0.576509    -3908.180848
# Sommer-Herbst    5263.843253  1569.246525  3.354376  0.000796     2188.118131
# Winter-Herbst    2265.601715  1586.117264  1.428395  0.153183     -843.190076
# Winter-Sommer   -2998.241538  1532.026597 -1.957043  0.050347    -6001.015554
#
#                  Conf. Int. Upp.  pvalue-hs  reject-hs
# Herbst-Frühling       -18.710277   0.220661      False
# Sommer-Frühling      5139.283205   0.392749      False
# Winter-Frühling      2174.847893   0.576509      False
# Sommer-Herbst        8339.568374   0.004766       True
# Winter-Herbst        5374.393506   0.392749      False
# Winter-Sommer           4.532479   0.220661      False

# %%
temp_cluster_eqpdmg = anova("EQPDMG","TEMP_CLUSTER")
cause_eqpdmg = anova("EQPDMG","ACCCAUSE_LVL2")
accidenttype_eqpdmg = anova("EQPDMG","ACCIDENT_TYPE")
eqtype_eqpdmg = anova("EQPDMG","EQUIPMENT_TYPE")
vis_eqpdmg = anova("EQPDMG","VISIBLTY")
weather_eqpdmg = anova("EQPDMG","WEATHER")
spd_eqpdmg = anova("EQPDMG","SPD_TOO_HIGH")
typtrk_eqpdmg = anova("EQPDMG","TYPTRK")
acctype_eqpdmg = anova("EQPDMG","ACCTYPE")
jahreszeit_eqpdmg = anova("EQPDMG","Jahreszeit")

# %%
temp_cluster_trkdmg = anova("TRKDMG","TEMP_CLUSTER")
cause_trkdmg = anova("TRKDMG","ACCCAUSE_LVL2")
accidenttype_trkdmg = anova("TRKDMG","ACCIDENT_TYPE")
eqtype_trkdmg = anova("TRKDMG","EQUIPMENT_TYPE")
vis_trkdmg = anova("TRKDMG","VISIBLTY")
weather_trkdmg = anova("TRKDMG","WEATHER")
spd_trkdmg = anova("TRKDMG","SPD_TOO_HIGH")
typtrk_trkdmg = anova("TRKDMG","TYPTRK")
acctype_trkdmg = anova("TRKDMG","ACCTYPE")
jahreszeit_trkdmg = anova("TRKDMG","Jahreszeit")

# %%
compare_anova = [
                                [
                                    temp_cluster[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis[0]["EtaSq"]["VISIBLTY"],
                                    weather[0]["EtaSq"]["WEATHER"],
                                    spd[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk[0]["EtaSq"]["TYPTRK"],
                                    acctype[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit[0]["EtaSq"]["Jahreszeit"]
                                ],
                                [
                                    temp_cluster_eqpdmg[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause_eqpdmg[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype_eqpdmg[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype_eqpdmg[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis_eqpdmg[0]["EtaSq"]["VISIBLTY"],
                                    weather_eqpdmg[0]["EtaSq"]["WEATHER"],
                                    spd_eqpdmg[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk_eqpdmg[0]["EtaSq"]["TYPTRK"],
                                    acctype_eqpdmg[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit_eqpdmg[0]["EtaSq"]["Jahreszeit"]
                                ],
                                [
                                    temp_cluster_trkdmg[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause_trkdmg[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype_trkdmg[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype_trkdmg[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis_trkdmg[0]["EtaSq"]["VISIBLTY"],
                                    weather_trkdmg[0]["EtaSq"]["WEATHER"],
                                    spd_trkdmg[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk_trkdmg[0]["EtaSq"]["TYPTRK"],
                                    acctype_trkdmg[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit_trkdmg[0]["EtaSq"]["Jahreszeit"]
                                ]
                            ]
pd.DataFrame(compare_anova,columns=["Temperatur", "Ursache","Unfallart", "Zugart", "Sichtbarkeit", "Wetter", "Zug zu schnell?", "Streckenart", "Siginifikanz des Unfalls", "Jahreszeit"], index=["Infrastrukturschaden", "Materialschaden", "Streckenschaden"]).style.format("{:.1g}")
# Out:
# <style  type="text/css" >
# </style><table id="T_8975f860_d199_11ea_9cd1_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Temperatur</th>        <th class="col_heading level0 col1" >Ursache</th>        <th class="col_heading level0 col2" >Unfallart</th>        <th class="col_heading level0 col3" >Zugart</th>        <th class="col_heading level0 col4" >Sichtbarkeit</th>        <th class="col_heading level0 col5" >Wetter</th>        <th class="col_heading level0 col6" >Zug zu schnell?</th>        <th class="col_heading level0 col7" >Streckenart</th>        <th class="col_heading level0 col8" >Siginifikanz des Unfalls</th>        <th class="col_heading level0 col9" >Jahreszeit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8975f860_d199_11ea_9cd1_acde48001122level0_row0" class="row_heading level0 row0" >Infrastrukturschaden</th>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row0_col0" class="data row0 col0" >0.003</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row0_col1" class="data row0 col1" >0.02</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row0_col2" class="data row0 col2" >0.003</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row0_col3" class="data row0 col3" >0.03</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row0_col4" class="data row0 col4" >0.001</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row0_col5" class="data row0 col5" >0.0002</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row0_col6" class="data row0 col6" >0.001</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row0_col7" class="data row0 col7" >0.07</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row0_col8" class="data row0 col8" >0.4</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row0_col9" class="data row0 col9" >0.0002</td>
#             </tr>
#             <tr>
#                         <th id="T_8975f860_d199_11ea_9cd1_acde48001122level0_row1" class="row_heading level0 row1" >Materialschaden</th>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row1_col0" class="data row1 col0" >0.002</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row1_col1" class="data row1 col1" >0.01</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row1_col2" class="data row1 col2" >0.002</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row1_col3" class="data row1 col3" >0.02</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row1_col4" class="data row1 col4" >0.0004</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row1_col5" class="data row1 col5" >0.0003</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row1_col6" class="data row1 col6" >0.001</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row1_col7" class="data row1 col7" >0.05</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row1_col8" class="data row1 col8" >0.3</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row1_col9" class="data row1 col9" >2e-05</td>
#             </tr>
#             <tr>
#                         <th id="T_8975f860_d199_11ea_9cd1_acde48001122level0_row2" class="row_heading level0 row2" >Streckenschaden</th>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row2_col0" class="data row2 col0" >0.001</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row2_col1" class="data row2 col1" >0.02</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row2_col2" class="data row2 col2" >0.007</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row2_col3" class="data row2 col3" >0.02</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row2_col4" class="data row2 col4" >0.0009</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row2_col5" class="data row2 col5" >0.0004</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row2_col6" class="data row2 col6" >1e-05</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row2_col7" class="data row2 col7" >0.03</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row2_col8" class="data row2 col8" >0.2</td>
#                         <td id="T_8975f860_d199_11ea_9cd1_acde48001122row2_col9" class="data row2 col9" >0.0006</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### ANOVA Heatmap <a class="anchor" id="ANOVA_HEATMAP"></a>
#
# **Interpretation:** Nach Cohen (1988) bei .01 (kleiner Effekt), .06 (mittlerer Effekt) und .14 (großer Effekt)
#
# [Cohen, J. (1988)](http://www.utstat.toronto.edu/~brunner/oldclass/378f16/readings/CohenPower.pdf). Statistical Power Analysis for the Behavioral Sciences.

# %%
colormap = plt.cm.Blues
ax=plt.figure(figsize=(20,15)).gca()
x_axis_labels = ["Temperatur", "Ursache","Unfallart", "Zugart", "Sichtbarkeit", "Wetter", "Zug zu schnell?", "Streckenart", "Siginifikanz des Unfalls", "Jahreszeit"] # labels for x-axis
y_axis_labels = ["Infrastrukturschaden", "Materialschaden", "Streckenschaden"] # labels for y-axis
ax=sns.heatmap(compare_anova,ax=ax,linewidths=0.1, 
            square=True, cmap=colormap, linecolor='white', annot=True, xticklabels=x_axis_labels, yticklabels=y_axis_labels, vmin=0, vmax=0.5);
bottom, top = ax.get_ylim()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, horizontalalignment='right', verticalalignment='top')
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.savefig("Images/ANOVA_Heatmap.png")
