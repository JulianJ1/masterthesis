# %% [markdown]
# # Masterthesis
# ## Deskriptive Statistik
# #### Julian Jetz

# %% [markdown]
# ## Inhalt:
#
# * [Boxenplots und Histogramme der Schäden (mit Ausreißern)](#ausreißer)
#
#
# * [Entfernung der Ausreißer](#ausreißer-delete)
#
#
# * [Häufigkeitsverteilungen](#frequencies)
#     * [Zugart](#freq-zugart)
#     * [Unfallart](#freq-unfallart)
#     * [Streckenart](#freq-streckenart)
#     * [Unfallursache Lvl 2](#freq-cause)
#         * [Unfallursache Lvl 1 (nach Unfallart aufgeteilt)](#freq-cause_lvl1_lvl2_unfallart)
#     * [Unfallsignifikanz](#freq-acctype)
#         * [Unfallsignifikanz (nach Unfallursache Lvl 2)](#freq-acctype_cause)
#     * [Wetter](#freq-wetter)
#     * [Jahreszeit](#freq-jahreszeit)
#     * [Jahr](#freq-jahr)
#         * [Jahr nach Unfallart](#freq-jahr_unfallart)
#     * [Temperatur](#freq-temp)
#         * [Unfallursachen nach Temperatur](#freq-temp_cause)
#     * [Sichtbarkeit](#freq-vis)
#     * [Geschwindigkeitsüberschreitung](#freq-speed)
#
#
# * [Verteilungstabellen](#tables)
#     * [Zugart nach Unfallart](#tables_eqtype_type)
#     * [Unfallart nach Zugart](#tables_type_eqtype)
#     * [Unfallursache nach Zugart](#tables_zugart_cause)
#     * [Unfallursache nach Wetter](#tables_weather_cause)
#     * [Unfallursache nach Jahreszeit](#tables_jahreszeit_cause)
#     * [Unfallursache nach Temperatur](#tables_cause_temp)
#     * [Unfallursache nach Sichtbarkeit](#tables_vis_cause)
#     * [Sichtbarkeit nach Unfallursache](#tables_cause_vis)
#     * [Geschwindigkeitsüberschreitung nach Unfallart](#tables_speed_acctype)
#     * [Geschwindigkeitsüberschreitung nach Streckenart](#tables_speed_typtrk)
#     * [Geschwindigkeitsüberschreitung nach Zugart](#tables_speed_eqtype)
#
#
# * [Boxenplots und Histogramme](#boxenplots)
#     * [Infrastrukturschaden](#infrastrukturdmg)
#     * [Materialschaden](#EQPDMG)
#     * [Streckenschaden](#TRKDMG)
#     * [Zuggeschwindigkeit](#zuggeschwindigkeit)
#     * [Zuggewicht](#tons)
#     * [Zugart](#zugart)
#     * [Unfallart](#unfallart)
#     * [Streckenart](#typtrk)
#     * [Unfallursache Lvl 2](#cause)
#     * [Unfallsignifikanz](#unfallsignifikanz)
#     * [Wetter](#wetter)
#     * [Jahreszeit](#Jahreszeit)
#     * [Jahr](#jahr)
#     * [Temperatur](#temp)
#     * [Sichrbarkeit](#vis)
#     * [Geschwindigkeitsüberschreitung](#speed)
#
#
# * [Statistik](#common_statistics)
#
#
# * [Korrelationen](#correlations)
#
#
# * [Anova Varianz](#ANOVA)
#     * [Anova Heatmap](#ANOVA_HEATMAP)

# %%
import glob
import pandas as pd
import numpy as np
from scipy import stats
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from pandas.plotting import scatter_matrix
from datetime import date
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
na_values = ['nan', 'N/A', 'NaN', 'NaT']

# %%
df = pd.read_csv('resources/multi_train_accident_data.csv', sep=";", na_values=na_values, index_col=False, dtype = {"STATE" : "str", "TYPE" : "str", "TYPEQ" : "str", "TYPTRK" : "str", "WEATHER" : "str", "VISIBLTY" : "str", "TONS" : "float64"})
df.shape[0]
# Out:
# 8611

# %%
pd.set_option('display.max_colwidth', 500)

# %%
a4_dims = (18, 10)
sns.set(style="whitegrid")

# %% [markdown]
# ### Boxenplots und Histogramme der Schäden (mit Ausreißern) <a class="anchor" id="ausreißer"></a>

# %% [markdown]
# #### Boxenplot Infrastrukturschaden

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
#plt.yscale("log")
ax.set_ylabels("Infrastrukturschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Multi_Train/Boxplot_Infrastrukturschaden.png')

# %% [markdown]
# #### Histogramm Infrastrukturschaden (ohne Ausreißer)¶

# %%
df['INFRASTRUCTURE_DMG'].hist(bins=30)
plt.savefig('Images/Multi_Train/Histogramm_Infrastrukturschaden.png')

# %% [markdown]
# #### Boxenplot Materialschaden

# %%
ax = sns.catplot(y='EQPDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Multi_Train/Boxplot_Materialschaden.png')

# %% [markdown]
# #### Histogramm Materialschaden

# %%
df['EQPDMG'].hist(bins=30)
plt.savefig('Images/Multi_Train/Histogramm_Materialschaden.png')

# %% [markdown]
# #### Boxenplot Streckenschaden

# %%
ax = sns.catplot(y='TRKDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Streckenschaden in Dollar")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Multi_Train/Boxplot_Streckenschaden.png')

# %% [markdown]
# #### Histogramm Materialschaden

# %%
df['TRKDMG'].hist(bins=30)
plt.savefig('Images/Multi_Train/Histogramm_Streckenschaden.png')

# %% [markdown]
# #### Entfernung der Ausreißer <a class="anchor" id="ausreißer-delete"></a>

# %%
df.shape[0]
# Out:
# 8611

# %%
df=df.dropna(subset=['INFRASTRUCTURE_DMG', 'YEAR4', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'TEMP_CLUSTER', 'SPEED', 'ACCCAUSE_LVL1', 'TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'ACCIDENT_TYPE', 'Jahreszeit'])

# %%
df.shape[0]
# Out:
# 8601

# %%
std_dev = 3.5
df = df[(np.abs(stats.zscore(df[['LOCOMOTIVES1','LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2','LOADF2', 'EMPTYF2', 'INFRASTRUCTURE_DMG']])) < float(std_dev)).all(axis=1)]

# %%
df.shape[0]
# Out:
# 7920

# %% [markdown]
# ### Häufigkeiten <a class="anchor" id="frequencies"></a>

# %%
def bar_values(ax):
    for p in ax.patches:
        ax.annotate(format(p.get_height(), ',d').replace(",","."), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
    sns.despine()
    return ax

# %% [markdown]
# #### Häufigkeiten Zugart <a class="anchor" id="freq-zugart"></a>

# %%
def redurceEqTypes(cus_df):
    eqtypes = cus_df["EQUIPMENT_TYPE"].value_counts().keys().tolist()
    counts = cus_df["EQUIPMENT_TYPE"].value_counts().tolist()

    for (eqtype, count) in zip(eqtypes, counts):
        if count < 30:
            idxs = cus_df[cus_df["EQUIPMENT_TYPE"] == eqtype].index
            cus_df.drop(idxs, inplace=True)
            
    return cus_df

# %%
custom_df = df.copy(deep=True)
custom_df = redurceEqTypes(custom_df)

# %%
#fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.countplot(x="EQUIPMENT_TYPE", data=custom_df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Zugart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90, horizontalalignment='right')
plt.savefig('Images/Multi_Train/Count_Zugart.png')

# %% [markdown]
# #### Häufigkeiten Unfallart <a class="anchor" id="freq-unfallart"></a>

# %%
ax = sns.countplot(x="ACCIDENT_TYPE", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=25, horizontalalignment='right')
plt.savefig('Images/Multi_Train/Count_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Streckenart <a class="anchor" id="freq-streckenart"></a>

# %%
ax = sns.countplot(x="TYPTRK", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Streckenart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=25, horizontalalignment='right')
plt.savefig('Images/Multi_Train/Count_Streckenart.png')

# %% [markdown]
# #### Häufigkeiten Unfallursache <a class="anchor" id="freq-cause"></a>

# %%
#fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.countplot(x="ACCCAUSE_LVL2", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallursache")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')
plt.savefig('Images/Multi_Train/Count_Unfallursache.png')

# %% [markdown]
# #### Häufigkeiten Unfallursache Lvl 1 (eingefärbt nach Unfallursache Lvl2 und gruppiert nach Unfallart) <a class="anchor" id="freq-cause_lvl1_lvl2_unfallart"></a>

# %%
bp = sns.catplot(y="ACCCAUSE_LVL1", hue="ACCCAUSE_LVL2", data=df, kind="count", col="ACCIDENT_TYPE", col_wrap=2, height=14, aspect=0.7, legend=False, legend_out=False)
bp.set_xlabels('Anzahl', fontsize=12)
bp.set_ylabels('Unfallursache', fontsize=12)
for ax in bp.axes:
    ax.legend(bbox_to_anchor=(0, 1.08), loc='upper left', ncol=3, frameon=False, fontsize=10)
    ax.grid(axis='y')
    #plt.setp(ax.get_xticklabels(), visible=True)
    #ax.set_xticks([0,1,2,3,4,5], ax.get_xticklabels())
plt.subplots_adjust(wspace=0.1, hspace=0.15)
plt.savefig('Images/Multi_Train/Count_Unfallursache_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Unfallschwere <a class="anchor" id="freq-acctype"></a>

# %%
ax = sns.countplot(x="ACCTYPE", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallschwere")
plt.savefig('Images/Multi_Train/Count_Unfallschwere.png')

# %% [markdown]
# #### Häufigkeiten Unfallschwere (nach Zugart)  <a class="anchor" id="freq-acctype_cause"></a>

# %%
cp = sns.catplot(x="ACCTYPE", data=custom_df, col="EQUIPMENT_TYPE", palette="colorblind", kind="count", col_wrap=3, height=3, aspect=1.5)
cp.set_xlabels('Unfallschwere', fontsize=12)
cp.set_ylabels('Anzahl', fontsize=12)
plt.savefig('Images/Multi_Train/Count_Unfallschwere_Zugart.png')

# %% [markdown]
# #### Häufigkeiten Wetter <a class="anchor" id="freq-wetter"></a>

# %%
ax = sns.countplot(x="WEATHER", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Wetter")
plt.savefig('Images/Multi_Train/Count_Wetter.png')

# %% [markdown]
# #### Häufigkeiten Jahreszeit <a class="anchor" id="freq-jahreszeit"></a>

# %%
ax = sns.countplot(x="Jahreszeit", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Jahreszeit")
plt.savefig('Images/Multi_Train/Count_Jahreszeit.png')

# %% [markdown]
# #### Häufigkeiten Jahr <a class="anchor" id="freq-jahr"></a>

# %%
bp = sns.catplot(x="YEAR4", data=df, kind="count", height=10, aspect=1.5, palette="colorblind")
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Anzahl', fontsize=12)
plt.savefig('Images/Multi_Train/Count_Jahr.png')

# %% [markdown]
# #### Häufigkeiten Jahr (nach Unfallart) <a class="anchor" id="freq-jahr_unfallart"></a>

# %%
bp = sns.catplot(x="YEAR4", data=df, kind="count", col="ACCIDENT_TYPE", col_wrap=2, height=5, aspect=1.5, palette="colorblind")
bp.set_ylabels('Jahr', fontsize=12)
bp.set_xlabels('Anzahl', fontsize=12)
for x in bp.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
plt.savefig('Images/Multi_Train/Count_Jahr_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Temperatur <a class="anchor" id="freq-temp"></a>

# %%
temp_order = ["Sehr Kalt (-45° - 30,01° C)", "Kalt (-30° - 0,01° C)", "Moderat (0° bis 19,99° C)", "Warm (20° bis 31,99° C)", "Heiß (>= 32° C)"]
ax = sns.countplot(x="TEMP_CLUSTER", data=df, palette="colorblind", order=temp_order)
ax = bar_values(ax)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')
ax.set_xlabel("Temperatur")
plt.savefig('Images/Multi_Train/Count_Temperatur.png')

# %% [markdown]
# #### Häufigkeiten Temperatur (nach Unfallursache) <a class="anchor" id="freq-temp_cause"></a>

# %%
ax = sns.catplot(x="TEMP_CLUSTER", hue="ACCCAUSE_LVL2", kind="count", data=df, palette='colorblind', order=temp_order, legend=False, height=15, aspect=1.5)
for x in ax.axes.flat:
    x.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=3, frameon=False, fontsize=20)
    for label in x.get_xticklabels():
        label.set_rotation(-90)   
ax.set_xlabels("Temperatur")
plt.savefig('Images/Multi_Train/Count_Temperatur_Unfallursache.png')

# %% [markdown]
# #### Häufigkeiten Sichtbarkeit <a class="anchor" id="freq-vis"></a>

# %%
vis_order = ["Dawn", "Day", "Dusk", "Dark"]
ax = sns.countplot(x="VISIBLTY", data=df, palette="colorblind", order=vis_order)
ax = bar_values(ax)
ax.set_xlabel("Sichtbarkeit")
plt.savefig('Images/Multi_Train/Count_Sichtbarkeit.png')

# %% [markdown]
# #### Häufigkeiten zu hohe Zuggeschwindigkeit <a class="anchor" id="freq-speed"></a>

# %%
ax = sns.countplot(x="SPD_TOO_HIGH", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Zuggeschwindigkeit zu hoch")
plt.savefig('Images/Multi_Train/Count_Zug_zu_schnell.png')

# %% [markdown]
# ### Verteilungstabellen <a class="anchor" id="tables"></a>

# %% [markdown]
# #### Verteilungstabelle Zugart nach Unfallart <a class="anchor" id="tables_eqtype_type"></a>

# %%
format_dict = {'Commuter Train':'{:.2f}%', 'Cut of Cars': '{:.2f}%', 'Freight Train': '{:.2f}%', 
               'Locomotive': '{:.2f}%', 'Passenger Train': '{:.2f}%', 'Single Car': '{:.2f}%', 'Work Train': '{:.2f}%',
               'Yard/Switching': '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=custom_df["ACCIDENT_TYPE"],  columns=custom_df["EQUIPMENT_TYPE"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format('{:.2f}%')
# Out:
# <style  type="text/css" >
# </style><table id="T_9b3f7c56_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >EQUIPMENT_TYPE</th>        <th class="col_heading level0 col0" >Cut of Cars, Cut of Cars</th>        <th class="col_heading level0 col1" >Cut of Cars, Cut of Cars, Freight Train</th>        <th class="col_heading level0 col2" >Cut of Cars, Cut of Cars, Yard/Switching</th>        <th class="col_heading level0 col3" >Cut of Cars, Freight Train</th>        <th class="col_heading level0 col4" >Cut of Cars, Locomotive</th>        <th class="col_heading level0 col5" >Cut of Cars, Single Car</th>        <th class="col_heading level0 col6" >Cut of Cars, Yard/Switching</th>        <th class="col_heading level0 col7" >Freight Train, Freight Train</th>        <th class="col_heading level0 col8" >Freight Train, Locomotive</th>        <th class="col_heading level0 col9" >Freight Train, Single Car</th>        <th class="col_heading level0 col10" >Freight Train, Work Train</th>        <th class="col_heading level0 col11" >Freight Train, Yard/Switching</th>        <th class="col_heading level0 col12" >Locomotive, Locomotive</th>        <th class="col_heading level0 col13" >Locomotive, Single Car</th>        <th class="col_heading level0 col14" >Locomotive, Yard/Switching</th>        <th class="col_heading level0 col15" >Single Car, Single Car</th>        <th class="col_heading level0 col16" >Single Car, Yard/Switching</th>        <th class="col_heading level0 col17" >Work Train, Work Train</th>        <th class="col_heading level0 col18" >Yard/Switching, Yard/Switching</th>        <th class="col_heading level0 col19" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b3f7c56_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >Collision</th>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >72.30%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >34.38%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >31.43%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col3" class="data row0 col3" >50.84%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col4" class="data row0 col4" >83.20%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col5" class="data row0 col5" >67.23%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col6" class="data row0 col6" >54.48%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col7" class="data row0 col7" >69.75%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col8" class="data row0 col8" >77.42%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col9" class="data row0 col9" >65.22%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col10" class="data row0 col10" >87.14%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col11" class="data row0 col11" >80.32%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col12" class="data row0 col12" >96.45%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col13" class="data row0 col13" >90.57%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col14" class="data row0 col14" >77.92%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col15" class="data row0 col15" >86.96%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col16" class="data row0 col16" >58.93%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col17" class="data row0 col17" >97.67%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col18" class="data row0 col18" >83.12%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row0_col19" class="data row0 col19" >69.70%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b3f7c56_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Crossing</th>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col3" class="data row1 col3" >0.60%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col4" class="data row1 col4" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col5" class="data row1 col5" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col6" class="data row1 col6" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col7" class="data row1 col7" >1.36%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col8" class="data row1 col8" >0.32%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col9" class="data row1 col9" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col10" class="data row1 col10" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col11" class="data row1 col11" >0.26%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col12" class="data row1 col12" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col13" class="data row1 col13" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col14" class="data row1 col14" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col15" class="data row1 col15" >0.62%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col16" class="data row1 col16" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col17" class="data row1 col17" >0.00%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col18" class="data row1 col18" >0.15%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row1_col19" class="data row1 col19" >0.29%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b3f7c56_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Derailment</th>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >27.03%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >65.62%</td>
#                         <td id="T_9b3f7c56_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >68.57%</td>
#                         <td id="T_9b3f7c56_d199_11

# %% [markdown]
# #### Verteilungstabelle Unfallart nach Zugart <a class="anchor" id="tables_type_eqtype"></a>

# %%
format_dict = {'Collision':'{:.2f}%', 'Crossing': '{:.2f}%', 'Derailment': '{:.2f}%', 
               'Fire / Violent Rupture / Explosive Detonation': '{:.2f}%', 'All': '{:.2f}%'}
freq_tab_eqtype_type = pd.crosstab(index=custom_df["EQUIPMENT_TYPE"],  columns=custom_df["ACCIDENT_TYPE"], margins=True)
(freq_tab_eqtype_type/freq_tab_eqtype_type.loc["All"]*100).sort_values(by=['All'], ascending=False).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9b4ae47e_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="col_heading level0 col0" >Collision</th>        <th class="col_heading level0 col1" >Crossing</th>        <th class="col_heading level0 col2" >Derailment</th>        <th class="col_heading level0 col3" >Fire / Violent Rupture / Explosive Detonation</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="index_name level0" >EQUIPMENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b4ae47e_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >All</th>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >100.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >100.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >100.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row0_col3" class="data row0 col3" >100.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row0_col4" class="data row0 col4" >100.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b4ae47e_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Yard/Switching, Yard/Switching</th>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >21.03%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >9.09%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >9.84%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row1_col3" class="data row1 col3" >0.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row1_col4" class="data row1 col4" >17.63%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b4ae47e_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Cut of Cars, Yard/Switching</th>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >13.51%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >0.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >26.25%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row2_col3" class="data row2 col3" >0.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row2_col4" class="data row2 col4" >17.28%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b4ae47e_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Cut of Cars, Freight Train</th>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >8.01%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >22.73%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >17.80%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row3_col3" class="data row3 col3" >0.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row3_col4" class="data row3 col4" >10.99%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b4ae47e_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >Freight Train, Freight Train</th>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >10.63%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >50.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >10.24%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row4_col3" class="data row4 col3" >0.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row4_col4" class="data row4 col4" >10.62%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b4ae47e_d199_11ea_8a46_acde48001122level0_row5" class="row_heading level0 row5" >Freight Train, Yard/Switching</th>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row5_col0" class="data row5 col0" >11.44%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row5_col1" class="data row5 col1" >9.09%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row5_col2" class="data row5 col2" >6.43%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row5_col3" class="data row5 col3" >0.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row5_col4" class="data row5 col4" >9.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b4ae47e_d199_11ea_8a46_acde48001122level0_row6" class="row_heading level0 row6" >Single Car, Yard/Switching</th>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row6_col0" class="data row6 col0" >5.78%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row6_col1" class="data row6 col1" >0.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row6_col2" class="data row6 col2" >9.36%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row6_col3" class="data row6 col3" >0.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row6_col4" class="data row6 col4" >6.83%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b4ae47e_d199_11ea_8a46_acde48001122level0_row7" class="row_heading level0 row7" >Locomotive, Yard/Switching</th>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row7_col0" class="data row7 col0" >5.64%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row7_col1" class="data row7 col1" >0.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row7_col2" class="data row7 col2" >3.72%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row7_col3" class="data row7 col3" >0.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row7_col4" class="data row7 col4" >5.05%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b4ae47e_d199_11ea_8a46_acde48001122level0_row8" class="row_heading level0 row8" >Freight Train, Single Car</th>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row8_col0" class="data row8 col0" >4.23%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row8_col1" class="data row8 col1" >0.00%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row8_col2" class="data row8 col2" >5.21%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row8_col3" class="data row8 col3" >33.33%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row8_col4" class="data row8 col4" >4.52%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b4ae47e_d199_11ea_8a46_acde48001122level0_row9" class="row_heading level0 row9" >Freight Train, Locomotive</th>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row9_col0" class="data row9 col0" >4.51%</td>
#                         <td id="T_9b4ae47e_d199_11ea_8a46_acde48001122row9_col1" class="data row

# %%
format_dict = {'Environmental Conditions':'{:.2f}%', 'Human Factors': '{:.2f}%', 'Loading': '{:.2f}%', 
               'Mechanical and Electrical Failures': '{:.2f}%', 'Miscellaneous Causes': '{:.2f}%', 
               'Signal and Communication': '{:.2f}%', 'Track, Roadbed and Structures': '{:.2f}%',
               'All': '{:.2f}%'}

# %% [markdown]
# #### Verteilungstabelle Unfallart  nach Unfallursache <a class="anchor" id="tables_zugart_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["ACCIDENT_TYPE"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9b58a550_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b58a550_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >Collision</th>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >55.71%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >79.31%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >36.90%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row0_col3" class="data row0 col3" >48.30%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row0_col4" class="data row0 col4" >59.30%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row0_col5" class="data row0 col5" >61.78%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row0_col6" class="data row0 col6" >20.18%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row0_col7" class="data row0 col7" >69.27%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b58a550_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Crossing</th>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >0.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >0.03%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >32.14%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row1_col3" class="data row1 col3" >0.28%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row1_col4" class="data row1 col4" >0.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row1_col5" class="data row1 col5" >0.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row1_col6" class="data row1 col6" >0.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row1_col7" class="data row1 col7" >0.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b58a550_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Derailment</th>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >44.29%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >20.65%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >30.95%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row2_col3" class="data row2 col3" >51.42%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row2_col4" class="data row2 col4" >40.26%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row2_col5" class="data row2 col5" >38.22%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row2_col6" class="data row2 col6" >79.82%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row2_col7" class="data row2 col7" >30.32%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b58a550_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Fire / Violent Rupture / Explosive Detonation</th>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >0.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >0.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >0.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row3_col3" class="data row3 col3" >0.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row3_col4" class="data row3 col4" >0.44%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row3_col5" class="data row3 col5" >0.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row3_col6" class="data row3 col6" >0.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row3_col7" class="data row3 col7" >0.04%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b58a550_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_9b58a550_d199_11ea_8a46_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Zugart  <a class="anchor" id="tables_zugart_typtrk"></a>

# %%
freq_tab = pd.crosstab(index=df["TYPTRK"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9b649626_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >TYPTRK</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b649626_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >Industry</th>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >11.43%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >5.11%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >2.38%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row0_col3" class="data row0 col3" >3.98%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row0_col4" class="data row0 col4" >9.16%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row0_col5" class="data row0 col5" >1.05%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row0_col6" class="data row0 col6" >8.30%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row0_col7" class="data row0 col7" >5.66%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b649626_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Main</th>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >18.57%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >16.15%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >52.38%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row1_col3" class="data row1 col3" >26.14%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row1_col4" class="data row1 col4" >12.79%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row1_col5" class="data row1 col5" >3.66%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row1_col6" class="data row1 col6" >11.37%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row1_col7" class="data row1 col7" >15.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b649626_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Siding</th>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >7.14%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >2.47%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >7.14%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row2_col3" class="data row2 col3" >7.39%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row2_col4" class="data row2 col4" >2.62%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row2_col5" class="data row2 col5" >1.57%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row2_col6" class="data row2 col6" >3.07%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row2_col7" class="data row2 col7" >2.83%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b649626_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Yard</th>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >62.86%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >76.27%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >38.10%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row3_col3" class="data row3 col3" >62.50%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row3_col4" class="data row3 col4" >75.44%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row3_col5" class="data row3 col5" >93.72%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row3_col6" class="data row3 col6" >77.27%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row3_col7" class="data row3 col7" >75.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b649626_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_9b649626_d199_11ea_8a46_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach State <a class="anchor" id="tables_state_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["STATE"],  columns=df["ACCCAUSE_LVL2"], margins=True)
((freq_tab/freq_tab.loc["All"]*100).sort_values(by=['All'], ascending=False)).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9b717508_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >STATE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b717508_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >All</th>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >100.00%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >100.00%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >100.00%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row0_col3" class="data row0 col3" >100.00%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row0_col4" class="data row0 col4" >100.00%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row0_col5" class="data row0 col5" >100.00%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row0_col6" class="data row0 col6" >100.00%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row0_col7" class="data row0 col7" >100.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b717508_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Texas</th>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >7.14%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >11.74%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >8.33%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row1_col3" class="data row1 col3" >10.23%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row1_col4" class="data row1 col4" >8.87%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row1_col5" class="data row1 col5" >9.42%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row1_col6" class="data row1 col6" >13.41%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row1_col7" class="data row1 col7" >11.45%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b717508_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Illinois</th>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >20.00%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >9.68%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >9.52%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row2_col3" class="data row2 col3" >11.36%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row2_col4" class="data row2 col4" >11.48%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row2_col5" class="data row2 col5" >8.38%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row2_col6" class="data row2 col6" >10.22%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row2_col7" class="data row2 col7" >10.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b717508_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Georgia</th>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >4.29%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >3.96%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >1.19%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row3_col3" class="data row3 col3" >4.83%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row3_col4" class="data row3 col4" >4.51%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row3_col5" class="data row3 col5" >12.04%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row3_col6" class="data row3 col6" >2.43%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row3_col7" class="data row3 col7" >4.07%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b717508_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >Louisiana</th>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >0.00%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >4.47%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >2.38%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row4_col3" class="data row4 col3" >2.84%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row4_col4" class="data row4 col4" >1.16%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row4_col5" class="data row4 col5" >2.62%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row4_col6" class="data row4 col6" >5.11%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row4_col7" class="data row4 col7" >4.07%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b717508_d199_11ea_8a46_acde48001122level0_row5" class="row_heading level0 row5" >Kalifornien</th>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row5_col0" class="data row5 col0" >4.29%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row5_col1" class="data row5 col1" >4.42%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row5_col2" class="data row5 col2" >2.38%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row5_col3" class="data row5 col3" >3.69%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row5_col4" class="data row5 col4" >2.91%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row5_col5" class="data row5 col5" >3.14%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row5_col6" class="data row5 col6" >2.94%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row5_col7" class="data row5 col7" >4.05%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b717508_d199_11ea_8a46_acde48001122level0_row6" class="row_heading level0 row6" >Ohio</th>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row6_col0" class="data row6 col0" >4.29%</td>
#                         <td id="T_9b717508_d199_11ea_8a46_acde48001122row6_col1" class="data row6 c

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Wetter <a class="anchor" id="tables_weather_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["WEATHER"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9b7ed590_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >WEATHER</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b7ed590_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >Clear</th>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >24.29%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >64.81%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >73.81%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row0_col3" class="data row0 col3" >65.06%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row0_col4" class="data row0 col4" >66.86%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row0_col5" class="data row0 col5" >65.45%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row0_col6" class="data row0 col6" >62.07%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row0_col7" class="data row0 col7" >64.48%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b7ed590_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Cloudy</th>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >27.14%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >24.34%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >17.86%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row1_col3" class="data row1 col3" >25.85%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row1_col4" class="data row1 col4" >20.93%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row1_col5" class="data row1 col5" >23.56%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row1_col6" class="data row1 col6" >26.31%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row1_col7" class="data row1 col7" >24.24%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b7ed590_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Fog</th>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >1.43%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >1.81%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >1.19%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row2_col3" class="data row2 col3" >0.57%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row2_col4" class="data row2 col4" >1.45%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row2_col5" class="data row2 col5" >1.57%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row2_col6" class="data row2 col6" >0.89%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row2_col7" class="data row2 col7" >1.62%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b7ed590_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Rain</th>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >32.86%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >6.94%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >4.76%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row3_col3" class="data row3 col3" >7.39%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row3_col4" class="data row3 col4" >10.03%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row3_col5" class="data row3 col5" >8.38%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row3_col6" class="data row3 col6" >9.20%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row3_col7" class="data row3 col7" >7.69%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b7ed590_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >Sleet</th>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >0.00%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >0.23%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >2.38%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row4_col3" class="data row4 col3" >0.28%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row4_col4" class="data row4 col4" >0.00%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row4_col5" class="data row4 col5" >0.00%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row4_col6" class="data row4 col6" >0.13%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row4_col7" class="data row4 col7" >0.21%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b7ed590_d199_11ea_8a46_acde48001122level0_row5" class="row_heading level0 row5" >Snow</th>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row5_col0" class="data row5 col0" >14.29%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row5_col1" class="data row5 col1" >1.88%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row5_col2" class="data row5 col2" >0.00%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row5_col3" class="data row5 col3" >0.85%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row5_col4" class="data row5 col4" >0.73%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row5_col5" class="data row5 col5" >1.05%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row5_col6" class="data row5 col6" >1.40%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row5_col7" class="data row5 col7" >1.76%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b7ed590_d199_11ea_8a46_acde48001122level0_row6" class="row_heading level0 row6" >All</th>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row6_col0" class="data row6 col0" >100.00%</td>
#                         <td id="T_9b7ed590_d199_11ea_8a46_acde48001122row6_col1" class="data row6 col1" >100.00%</td>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Jahreszeit <a class="anchor" id="tables_jahreszeit_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["Jahreszeit"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9b891cc6_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >Jahreszeit</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b891cc6_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >Frühling</th>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >27.14%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >23.89%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >32.14%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row0_col3" class="data row0 col3" >27.56%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row0_col4" class="data row0 col4" >26.45%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row0_col5" class="data row0 col5" >20.42%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row0_col6" class="data row0 col6" >24.14%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row0_col7" class="data row0 col7" >24.33%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b891cc6_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Herbst</th>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >15.71%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >25.40%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >21.43%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row1_col3" class="data row1 col3" >20.74%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row1_col4" class="data row1 col4" >21.66%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row1_col5" class="data row1 col5" >29.32%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row1_col6" class="data row1 col6" >25.54%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row1_col7" class="data row1 col7" >24.85%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b891cc6_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Sommer</th>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >15.71%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >26.62%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >25.00%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row2_col3" class="data row2 col3" >28.41%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row2_col4" class="data row2 col4" >30.38%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row2_col5" class="data row2 col5" >24.08%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row2_col6" class="data row2 col6" >25.03%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row2_col7" class="data row2 col7" >26.69%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b891cc6_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Winter</th>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >41.43%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >24.10%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >21.43%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row3_col3" class="data row3 col3" >23.30%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row3_col4" class="data row3 col4" >21.51%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row3_col5" class="data row3 col5" >26.18%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row3_col6" class="data row3 col6" >25.29%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row3_col7" class="data row3 col7" >24.13%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b891cc6_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_9b891cc6_d199_11ea_8a46_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Temperatur <a class="anchor" id="tables_cause_temp"></a>

# %%
freq_tab = pd.crosstab(index=df["TEMP_CLUSTER"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9b9369f6_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >TEMP_CLUSTER</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b9369f6_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >Heiß (>= 32° C)</th>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >1.43%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >4.78%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >8.33%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row0_col3" class="data row0 col3" >6.25%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row0_col4" class="data row0 col4" >6.10%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row0_col5" class="data row0 col5" >3.14%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row0_col6" class="data row0 col6" >6.51%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row0_col7" class="data row0 col7" >5.10%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b9369f6_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Kalt (-30° - 0,01° C)</th>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >27.14%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >11.79%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >7.14%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row1_col3" class="data row1 col3" >14.20%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row1_col4" class="data row1 col4" >9.16%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row1_col5" class="data row1 col5" >12.04%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row1_col6" class="data row1 col6" >12.39%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row1_col7" class="data row1 col7" >11.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b9369f6_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Moderat (0° bis 19,99° C)</th>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >45.71%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >50.47%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >46.43%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row2_col3" class="data row2 col3" >45.17%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row2_col4" class="data row2 col4" >46.51%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row2_col5" class="data row2 col5" >51.83%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row2_col6" class="data row2 col6" >51.09%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row2_col7" class="data row2 col7" >49.90%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b9369f6_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Sehr Kalt (-45° - 30,01° C)</th>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >0.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >0.05%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >0.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row3_col3" class="data row3 col3" >0.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row3_col4" class="data row3 col4" >0.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row3_col5" class="data row3 col5" >0.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row3_col6" class="data row3 col6" >0.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row3_col7" class="data row3 col7" >0.04%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b9369f6_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >Warm (20° bis 31,99° C)</th>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >25.71%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >32.91%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >38.10%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row4_col3" class="data row4 col3" >34.38%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row4_col4" class="data row4 col4" >38.23%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row4_col5" class="data row4 col5" >32.98%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row4_col6" class="data row4 col6" >30.01%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row4_col7" class="data row4 col7" >33.14%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b9369f6_d199_11ea_8a46_acde48001122level0_row5" class="row_heading level0 row5" >All</th>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row5_col0" class="data row5 col0" >100.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row5_col1" class="data row5 col1" >100.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row5_col2" class="data row5 col2" >100.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row5_col3" class="data row5 col3" >100.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row5_col4" class="data row5 col4" >100.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row5_col5" class="data row5 col5" >100.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row5_col6" class="data row5 col6" >100.00%</td>
#                         <td id="T_9b9369f6_d199_11ea_8a46_acde48001122row5_col7" class="data row5 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Sichtbarkeit <a class="anchor" id="tables_vis_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["VISIBLTY"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9b9d731a_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >VISIBLTY</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b9d731a_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >Dark</th>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >41.43%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >46.35%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >36.90%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row0_col3" class="data row0 col3" >44.32%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row0_col4" class="data row0 col4" >45.35%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row0_col5" class="data row0 col5" >42.93%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row0_col6" class="data row0 col6" >41.51%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row0_col7" class="data row0 col7" >45.47%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b9d731a_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Dawn</th>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >4.29%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >4.02%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >2.38%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row1_col3" class="data row1 col3" >5.11%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row1_col4" class="data row1 col4" >3.34%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row1_col5" class="data row1 col5" >3.66%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row1_col6" class="data row1 col6" >4.34%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row1_col7" class="data row1 col7" >4.02%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b9d731a_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Day</th>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >45.71%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >44.63%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >52.38%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row2_col3" class="data row2 col3" >45.74%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row2_col4" class="data row2 col4" >46.95%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row2_col5" class="data row2 col5" >46.07%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row2_col6" class="data row2 col6" >49.81%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row2_col7" class="data row2 col7" >45.52%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b9d731a_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Dusk</th>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >8.57%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >5.01%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >8.33%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row3_col3" class="data row3 col3" >4.83%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row3_col4" class="data row3 col4" >4.36%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row3_col5" class="data row3 col5" >7.33%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row3_col6" class="data row3 col6" >4.34%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row3_col7" class="data row3 col7" >5.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9b9d731a_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_9b9d731a_d199_11ea_8a46_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Sichtbarkeit nach Unfallursache  <a class="anchor" id="tables_cause_vis"></a>

# %%
format_dict = {'Dark':'{:.2f}%', 'Dawn': '{:.2f}%', 'Day': '{:.2f}%', 
               'Dusk': '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["ACCCAUSE_LVL2"],  columns=df["VISIBLTY"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9ba7658c_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >VISIBLTY</th>        <th class="col_heading level0 col0" >Dark</th>        <th class="col_heading level0 col1" >Dawn</th>        <th class="col_heading level0 col2" >Day</th>        <th class="col_heading level0 col3" >Dusk</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9ba7658c_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >Environmental Conditions</th>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >0.81%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >0.94%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >0.89%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row0_col3" class="data row0 col3" >1.52%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row0_col4" class="data row0 col4" >0.88%</td>
#             </tr>
#             <tr>
#                         <th id="T_9ba7658c_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Human Factors</th>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >74.03%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >72.64%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >71.21%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row1_col3" class="data row1 col3" >72.73%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row1_col4" class="data row1 col4" >72.63%</td>
#             </tr>
#             <tr>
#                         <th id="T_9ba7658c_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Loading</th>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >0.86%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >0.63%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >1.22%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row2_col3" class="data row2 col3" >1.77%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row2_col4" class="data row2 col4" >1.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_9ba7658c_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Mechanical and Electrical Failures</th>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >4.33%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >5.66%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >4.47%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row3_col3" class="data row3 col3" >4.29%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row3_col4" class="data row3 col4" >4.44%</td>
#             </tr>
#             <tr>
#                         <th id="T_9ba7658c_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >Miscellaneous Causes</th>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >8.66%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >7.23%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >8.96%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row4_col3" class="data row4 col3" >7.58%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row4_col4" class="data row4 col4" >8.69%</td>
#             </tr>
#             <tr>
#                         <th id="T_9ba7658c_d199_11ea_8a46_acde48001122level0_row5" class="row_heading level0 row5" >Signal and Communication</th>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row5_col0" class="data row5 col0" >2.28%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row5_col1" class="data row5 col1" >2.20%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row5_col2" class="data row5 col2" >2.44%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row5_col3" class="data row5 col3" >3.54%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row5_col4" class="data row5 col4" >2.41%</td>
#             </tr>
#             <tr>
#                         <th id="T_9ba7658c_d199_11ea_8a46_acde48001122level0_row6" class="row_heading level0 row6" >Track, Roadbed and Structures</th>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row6_col0" class="data row6 col0" >9.03%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row6_col1" class="data row6 col1" >10.69%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row6_col2" class="data row6 col2" >10.82%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row6_col3" class="data row6 col3" >8.59%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row6_col4" class="data row6 col4" >9.89%</td>
#             </tr>
#             <tr>
#                         <th id="T_9ba7658c_d199_11ea_8a46_acde48001122level0_row7" class="row_heading level0 row7" >All</th>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row7_col0" class="data row7 col0" >100.00%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row7_col1" class="data row7 col1" >100.00%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row7_col2" class="data row7 col2" >100.00%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row7_col3" class="data row7 col3" >100.00%</td>
#                         <td id="T_9ba7658c_d199_11ea_8a46_acde48001122row7_col4" class="data row7 col4" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Geschwindigkeitsüberschreitung nach Unfallart  <a class="anchor" id="tables_speed_acctype"></a>

# %%
format_dict = {False:'{:.2f}%', True: '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["ACCIDENT_TYPE"],  columns=df["SPD_TOO_HIGH"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9bbb58e4_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >SPD_TOO_HIGH</th>        <th class="col_heading level0 col0" >False</th>        <th class="col_heading level0 col1" >True</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9bbb58e4_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >Collision</th>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >69.53%</td>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >61.71%</td>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >69.27%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bbb58e4_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Crossing</th>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >0.31%</td>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >2.23%</td>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >0.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bbb58e4_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Derailment</th>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >30.11%</td>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >36.06%</td>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >30.32%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bbb58e4_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Fire / Violent Rupture / Explosive Detonation</th>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >0.04%</td>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >0.00%</td>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >0.04%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bbb58e4_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_9bbb58e4_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Geschwindigkeitsüberschreitung nach Streckenart  <a class="anchor" id="tables_speed_typtrk"></a>

# %%
format_dict = {False:'{:.2f}%', True: '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["TYPTRK"],  columns=df["SPD_TOO_HIGH"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9bc53fd0_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >SPD_TOO_HIGH</th>        <th class="col_heading level0 col0" >False</th>        <th class="col_heading level0 col1" >True</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >TYPTRK</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9bc53fd0_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >Industry</th>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >5.49%</td>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >10.41%</td>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >5.66%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bc53fd0_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Main</th>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >15.85%</td>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >18.22%</td>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >15.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bc53fd0_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Siding</th>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >2.35%</td>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >16.36%</td>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >2.83%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bc53fd0_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Yard</th>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >76.30%</td>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >55.02%</td>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >75.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bc53fd0_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_9bc53fd0_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Geschwindigkeitsüberschreitung nach Zugart  <a class="anchor" id="tables_speed_eqtype"></a>

# %%
format_dict = {False:'{:.2f}%', True: '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["EQUIPMENT_TYPE"],  columns=df["SPD_TOO_HIGH"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).sort_values(by=['All'], ascending=False).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_9bcf5448_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="index_name level0" >SPD_TOO_HIGH</th>        <th class="col_heading level0 col0" >False</th>        <th class="col_heading level0 col1" >True</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >EQUIPMENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >All</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >100.00%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >100.00%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >100.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Yard/Switching, Yard/Switching</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >17.40%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >5.20%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >16.98%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Cut of Cars, Yard/Switching</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >16.94%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >8.18%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >16.64%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row3" class="row_heading level0 row3" >Cut of Cars, Freight Train</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row3_col0" class="data row3 col0" >10.30%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row3_col1" class="data row3 col1" >18.59%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row3_col2" class="data row3 col2" >10.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row4" class="row_heading level0 row4" >Freight Train, Freight Train</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row4_col0" class="data row4 col0" >10.06%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row4_col1" class="data row4 col1" >14.87%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row4_col2" class="data row4 col2" >10.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row5" class="row_heading level0 row5" >Freight Train, Yard/Switching</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row5_col0" class="data row5 col0" >9.74%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row5_col1" class="data row5 col1" >4.46%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row5_col2" class="data row5 col2" >9.56%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row6" class="row_heading level0 row6" >Single Car, Yard/Switching</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row6_col0" class="data row6 col0" >6.71%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row6_col1" class="data row6 col1" >2.97%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row6_col2" class="data row6 col2" >6.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row7" class="row_heading level0 row7" >Locomotive, Yard/Switching</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row7_col0" class="data row7 col0" >4.94%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row7_col1" class="data row7 col1" >2.60%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row7_col2" class="data row7 col2" >4.86%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row8" class="row_heading level0 row8" >Freight Train, Single Car</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row8_col0" class="data row8 col0" >4.40%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row8_col1" class="data row8 col1" >2.97%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row8_col2" class="data row8 col2" >4.36%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row9" class="row_heading level0 row9" >Freight Train, Locomotive</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row9_col0" class="data row9 col0" >3.86%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row9_col1" class="data row9 col1" >5.58%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row9_col2" class="data row9 col2" >3.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row10" class="row_heading level0 row10" >Locomotive, Locomotive</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row10_col0" class="data row10 col0" >2.05%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row10_col1" class="data row10 col1" >4.46%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row10_col2" class="data row10 col2" >2.13%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row11" class="row_heading level0 row11" >Single Car, Single Car</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row11_col0" class="data row11 col0" >1.97%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row11_col1" class="data row11 col1" >3.72%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row11_col2" class="data row11 col2" >2.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row12" class="row_heading level0 row12" >Cut of Cars, Cut of Cars</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row12_col0" class="data row12 col0" >1.79%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row12_col1" class="data row12 col1" >4.09%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row12_col2" class="data row12 col2" >1.87%</td>
#             </tr>
#             <tr>
#                         <th id="T_9bcf5448_d199_11ea_8a46_acde48001122level0_row13" class="row_heading level0 row13" >Cut of Cars, Locomotive</th>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row13_col0" class="data row13 col0" >1.42%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row13_col1" class="data row13 col1" >5.95%</td>
#                         <td id="T_9bcf5448_d199_11ea_8a46_acde48001122row13_col2" class="data row13 col2" >1.58%</td>
#             </tr>
#             <tr>

# %% [markdown]
# ### Boxenplots und Histogramme <a class="anchor" id="boxenplots"></a>
#
# [Hadley Wickham: Letter-value plots: Boxplots for large data](https://doi.org/10.1080/10618600.2017.1305277)

# %% [markdown]
# #### Boxenplot Infrastrukturschaden (ohne Ausreißer) <a class="anchor" id="infrastrukturdmg"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
plt.yscale("log")
ax.set_ylabels("Infrastrukturschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Multi_Train/Boxplot_Infrastrukturschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Infrastrukturschaden (ohne Ausreißer)¶

# %%
df['INFRASTRUCTURE_DMG'].hist(bins=30)
plt.savefig('Images/Multi_Train/Histogramm_Infrastrukturschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Materialschaden (ohne Ausreißer) <a class="anchor" id="EQPDMG"></a>

# %%
ax = sns.catplot(y='EQPDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
plt.yscale("log")
ax.set_ylabels("Materialschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Multi_Train/Boxplot_Materialschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Materialschaden (ohne Ausreißer)¶

# %%
df['EQPDMG'].hist(bins=30)
plt.savefig('Images/Multi_Train/Histogramm_Materialschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Streckenchaden (ohne Ausreißer) <a class="anchor" id="TRKDMG"></a>

# %%
ax = sns.catplot(y='TRKDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Streckenschaden in Dollar")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Multi_Train/Boxplot_Streckenschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Materialschaden (ohne Ausreißer)¶

# %%
df['TRKDMG'].hist(bins=30)
plt.savefig('Images/Multi_Train/Histogramm_Streckenschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Zuggeschwindigkeit <a class="anchor" id="zuggeschwindigkeit"></a>

# %%
ax = sns.catplot(y='SPEED', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Geschwindigkeit des Zuges")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Multi_Train/Boxplot_Zuggeschwindigkeit.png')

# %% [markdown]
# #### Histogramm Zuggeschwindigkeit

# %%
df['SPEED'].hist(bins=50)
plt.savefig('Images/Multi_Train/Histogramm_Zuggeschwindigkeit.png')

# %% [markdown]
# #### Boxenplot Zuggewicht <a class="anchor" id="tons"></a>

# %%
ax = sns.catplot(y='TONS', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Gewicht des Zuges")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Multi_Train/Boxplot_Zuggewicht.png')

# %% [markdown]
# #### Histogramm Zuggewicht

# %%
df['TONS'].hist(bins=50)
plt.savefig('Images/Multi_Train/Histogramm_Zuggewicht.png')

# %% [markdown]
# #### Boxenplot Zugart und Geschwindigkeit <a class="anchor" id="zugart"></a>

# %%
ax = sns.catplot(y='SPEED', x='EQUIPMENT_TYPE', data=custom_df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Geschwindigkeit des Zuges")
ax.set_xlabels("Zugart")
plt.savefig('Images/Multi_Train/Boxplot_Geschwindigkeit_Zugart.png')

# %% [markdown]
# #### Boxenplot Zugart und Gewicht

# %%
ax = sns.catplot(y='TONS', x='EQUIPMENT_TYPE', data=custom_df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Gewicht in t(ohne Lokomotiven)")
ax.set_xlabels("Zugart")
plt.savefig('Images/Multi_Train/Boxplot_Gewicht_Zugart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Zugart

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='EQUIPMENT_TYPE', data=custom_df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Zugart")
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Zugart.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Zugart

# %%
ax = sns.catplot(y='EQPDMG', x='EQUIPMENT_TYPE', data=custom_df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Zugart")
plt.savefig('Images/Multi_Train/Boxplot_Material_Zugart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallart <a class="anchor" id="unfallart"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCIDENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallart")
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Unfallart.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallart

# %%
ax = sns.catplot(y='EQPDMG', x='ACCIDENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallart")
plt.savefig('Images/Multi_Train/Boxplot_Material_Unfallart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Streckenart <a class="anchor" id="typtrk"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='TYPTRK', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Streckenart")
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Streckenart.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Streckenart

# %%
ax = sns.catplot(y='EQPDMG', x='TYPTRK', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Streckenart")
plt.savefig('Images/Multi_Train/Boxplot_Material_Streckenart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallursache <a class="anchor" id="cause"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCCAUSE_LVL2', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallursache")
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Unfallursache.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallursache

# %%
ax = sns.catplot(y='EQPDMG', x='ACCCAUSE_LVL2', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallursache")
plt.savefig('Images/Multi_Train/Boxplot_Material_Unfallursache.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallschwere <a class="anchor" id="unfallsignifikanz"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCTYPE', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallschwere")
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Unfallschwere.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallschwere

# %%
ax = sns.catplot(y='EQPDMG', x='ACCTYPE', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallschwere")
plt.savefig('Images/Multi_Train/Boxplot_Material_Unfallschwere.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Wetter <a class="anchor" id="wetter"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='WEATHER', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Wetter")
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Wetter.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Wetter

# %%
ax = sns.catplot(y='EQPDMG', x='WEATHER', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Wetter")
plt.savefig('Images/Multi_Train/Boxplot_Material_Wetter.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Temperatur <a class="anchor" id="temp"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='TEMP_CLUSTER', data=df, palette="colorblind", order=temp_order, kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Temperatur")
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Temperatur.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Temperatur

# %%
ax = sns.catplot(y='EQPDMG', x='TEMP_CLUSTER', data=df, palette="colorblind", order=temp_order, kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Temperatur")
plt.savefig('Images/Multi_Train/Boxplot_Material_Temperatur.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Sichtbarkeit <a class="anchor" id="vis"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='VISIBLTY', data=df, palette="colorblind", kind='boxen', order=vis_order, height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Sichtbarkeit")
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Sichtbarkeit.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Temperatur

# %%
ax = sns.catplot(y='EQPDMG', x='VISIBLTY', data=df, palette="colorblind", order=vis_order, kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Sichtbarkeit")
plt.savefig('Images/Multi_Train/Boxplot_Material_Sichtbarkeit.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahreszeit <a class="anchor" id="jahreszeit"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='Jahreszeit', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Jahreszeit")
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Jahreszeit.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahreszeit (nach Unfallursache)

# %%
bp = sns.catplot(y='INFRASTRUCTURE_DMG', x='Jahreszeit', data=df, palette="colorblind", hue='ACCCAUSE_LVL2', kind="boxen", legend=False, height=10, aspect=1.5)
plt.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=3, frameon=False)
bp.set_ylabels("Infrastrukturschaden in Dollar")
bp.set_xlabels("Jahreszeit")
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Ursache_Sommer.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahreszeit

# %%
ax = sns.catplot(y='EQPDMG', x='Jahreszeit', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Jahreszeit")
plt.savefig('Images/Multi_Train/Boxplot_Material_Jahreszeit.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahreszeit (nach Unfallursache)

# %%
bp = sns.catplot(y='EQPDMG', x='Jahreszeit', data=df, palette="colorblind", hue='ACCCAUSE_LVL2', kind="boxen", legend=False, height=10, aspect=1.5)
plt.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=3, frameon=False)
bp.set_ylabels("Materialschaden in Dollar")
bp.set_xlabels("Jahreszeit")
plt.savefig('Images/Multi_Train/Boxplot_Material_Ursache_Sommer.png')
plt.show()

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahr <a class="anchor" id="jahr"></a>

# %%
bp = sns.catplot(x="YEAR4", y="INFRASTRUCTURE_DMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Infrastrukturschaden in Dollar', fontsize=12)
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Jahr.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahr

# %%
bp = sns.catplot(x="YEAR4", y="EQPDMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Materialschaden in Dollar', fontsize=12)
plt.savefig('Images/Multi_Train/Boxplot_Material_Jahr.png')

# %% [markdown]
# #### Boxenplot Streckenschaden und Jahr

# %%
bp = sns.catplot(x="YEAR4", y="TRKDMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Streckenschaden in Dollar', fontsize=12)
plt.savefig('Images/Multi_Train/Boxplot_Strecke_Jahr.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Zug zu schnell? <a class="anchor" id="speed"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='SPD_TOO_HIGH', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Zug zu schnell?")
plt.savefig('Images/Multi_Train/Boxplot_Infrastruktur_Zug_zu_schnell.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Zug zu schnell?

# %%
ax = sns.catplot(y='EQPDMG', x='SPD_TOO_HIGH', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Zug zu schnell?")
plt.savefig('Images/Multi_Train/Boxplot_Material_Zug_zu_schnell.png')

# %% [markdown]
# ### Common Statistics <a class="anchor" id="common_statistics"></a>

# %%
x_data = df[['YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'TEMP_CLUSTER', 'SPEED', 'ACCCAUSE_LVL1', 'ACCIDENT_TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']]
y = df['INFRASTRUCTURE_DMG']

# %%
x_data.describe(include=np.number, percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
#              YEAR4        MONTH  LOCOMOTIVES1       LOADF1       LOADP1  \
# count  7920.000000  7920.000000   7920.000000  7920.000000  7920.000000
# mean   2000.012879     6.532702      2.975126    39.130051     0.004419
# std       9.966497     3.424866      1.901811    39.526162     0.104722
# min    1985.000000     1.000000      0.000000     0.000000     0.000000
# 10%    1987.000000     2.000000      1.000000     0.000000     0.000000
# 20%    1989.000000     3.000000      1.000000     4.000000     0.000000
# 30%    1993.000000     4.000000      2.000000    11.000000     0.000000
# 40%    1996.000000     5.000000      2.000000    18.000000     0.000000
# 50%    2000.000000     7.000000      3.000000    27.000000     0.000000
# 60%    2004.000000     8.000000      3.000000    37.000000     0.000000
# 70%    2006.000000     9.000000      4.000000    51.000000     0.000000
# 80%    2010.000000    10.000000      4.000000    69.000000     0.000000
# 90%    2014.000000    11.000000      5.100000    99.000000     0.000000
# max    2020.000000    12.000000     10.000000   198.000000     3.000000
#
#            EMPTYF1      EMPTYP1  LOCOMOTIVES2       LOADF2      EMPTYF2  \
# count  7920.000000  7920.000000   7920.000000  7920.000000  7920.000000
# mean     29.608712     0.011111      0.207071     1.348611     1.323359
# std      34.206725     0.181553      0.551251     2.231418     2.107326
# min       0.000000     0.000000      0.000000     0.000000     0.000000
# 10%       0.000000     0.000000      0.000000     0.000000     0.000000
# 20%       1.000000     0.000000      0.000000     0.000000     0.000000
# 30%       4.000000     0.000000      0.000000     0.000000     0.000000
# 40%      10.000000     0.000000      0.000000     0.000000     0.000000
# 50%      17.000000     0.000000      0.000000     0.000000     0.000000
# 60%      26.000000     0.000000      0.000000     1.000000     1.000000
# 70%      38.000000     0.000000      0.000000     2.000000     2.000000
# 80%      55.000000     0.000000      0.000000     2.000000     2.000000
# 90%      80.000000     0.000000      1.000000     4.000000     4.000000
# max     170.000000     4.000000      3.000000    16.000000    13.000000
#
#                TONS        SPEED
# count   7920.000000  7920.000000
# mean    5412.805471     7.487277
# std     5240.843239     7.753526
# min        0.000000     0.000000
# 10%      300.000000     2.500000
# 20%     1005.896235     3.000000
# 30%     1954.352898     3.954272
# 40%     2947.842779     4.500000
# 50%     4018.000000     4.949628
# 60%     5292.227091     5.944984
# 70%     6831.837877     7.000000
# 80%     8996.000000     9.926407
# 90%    12624.326818    14.903185
# max    80063.109447    84.578084

# %%
x_data.describe(include=np.object, percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
#                      TEMP_CLUSTER            ACCCAUSE_LVL1 ACCIDENT_TYPE  \
# count                        7920                     7920          7920
# unique                          5                       31             4
# top     Moderat (0° bis 19,99° C)  General Switching Rules     Collision
# freq                         3952                     2319          5486
#
#                         EQUIPMENT_TYPE TYPTRK VISIBLTY WEATHER  STATE  \
# count                             7920   7920     7920    7920   7920
# unique                              91      4        4       6     50
# top     Yard/Switching, Yard/Switching   Yard      Day   Clear  Texas
# freq                              1345   5986     3605    5107    907
#
#        SPD_TOO_HIGH          ACCTYPE Jahreszeit
# count          7920             7920       7920
# unique            2                2          4
# top           False  Not Significant     Sommer
# freq           7651             6857       2114

# %%
y.describe(include='all', percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
# count    7.920000e+03
# mean     6.359603e+04
# std      1.416938e+05
# min      4.714000e+03
# 10%      8.821000e+03
# 20%      1.150000e+04
# 30%      1.450000e+04
# 40%      1.864360e+04
# 50%      2.411100e+04
# 60%      3.250000e+04
# 70%      4.446920e+04
# 80%      6.917440e+04
# 90%      1.320120e+05
# max      2.143217e+06
# Name: INFRASTRUCTURE_DMG, dtype: float64

# %%
ax = sns.jointplot(x='SPEED', y='INFRASTRUCTURE_DMG', data=df, kind='hex', gridsize=20)
plt.savefig(r"Images/Multi_Train/JOINTPLOT_SPEED_INFRASTRUCTURE_DMG.png")

# %%
ax = sns.jointplot(x='TONS', y='INFRASTRUCTURE_DMG', data=df, kind='hex', gridsize=20)
plt.savefig(r"Images/Multi_Train/JOINTPLOT_TONS_INFRASTRUCTURE_DMG.png")

# %% [markdown]
# ### Scattermatrix und Korrelationen der Daten <a class="anchor" id="correlations"></a>
# Jahr, Monat, Anzahl der beladenen Frachtwagons und Personenwagons, Gewicht, Temperatur, Geschwindigkeit und Unfallkosten

# %%
"""
scattermatrix = scatter_matrix(df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'SPEED']], diagonal='kde', figsize=(18, 18))
n = len(df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'SPEED']].columns)
for x in range(n):
    for y in range(n):
        # to get the axis of subplots
        ax = scattermatrix[x, y]
        # to make x axis name vertical  
        ax.xaxis.label.set_rotation(-90)
        # to make y axis name horizontal 
        ax.yaxis.label.set_rotation(0)
        # to make sure y axis names are outside the plot area
        ax.yaxis.labelpad = 50
plt.savefig(r"Images/Multi_Train/scatterALL.png")
"""
# Out:
# '\nscattermatrix = scatter_matrix(df[[\'INFRASTRUCTURE_DMG\', \'EQPDMG\', \'TRKDMG\', \'YEAR4\', \'MONTH\', \'LOCOMOTIVES1\', \'LOADF1\', \'LOADP1\', \'EMPTYF1\', \'EMPTYP1\',\'LOCOMOTIVES2\', \'LOADF2\', \'EMPTYF2\', \'TONS\', \'SPEED\']], diagonal=\'kde\', figsize=(18, 18))\nn = len(df[[\'INFRASTRUCTURE_DMG\', \'EQPDMG\', \'TRKDMG\', \'YEAR4\', \'MONTH\', \'LOCOMOTIVES1\', \'LOADF1\', \'LOADP1\', \'EMPTYF1\', \'EMPTYP1\',\'LOCOMOTIVES2\', \'LOADF2\', \'EMPTYF2\', \'TONS\', \'SPEED\']].columns)\nfor x in range(n):\n    for y in range(n):\n        # to get the axis of subplots\n        ax = scattermatrix[x, y]\n        # to make x axis name vertical  \n        ax.xaxis.label.set_rotation(-90)\n        # to make y axis name horizontal \n        ax.yaxis.label.set_rotation(0)\n        # to make sure y axis names are outside the plot area\n        ax.yaxis.labelpad = 50\nplt.savefig(r"Images/Multi_Train/scatterALL.png")\n'

# %%
colormap = plt.cm.RdBu
corr = df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'TEMP_CLUSTER', 'SPEED', 'ACCCAUSE_LVL1', 'TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']].corr()
corr
# Out:
#                     INFRASTRUCTURE_DMG    EQPDMG    TRKDMG     YEAR4  \
# INFRASTRUCTURE_DMG            1.000000  0.954919  0.569437  0.152582
# EQPDMG                        0.954919  1.000000  0.350436  0.134180
# TRKDMG                        0.569437  0.350436  1.000000  0.138001
# YEAR4                         0.152582  0.134180  0.138001  1.000000
# MONTH                         0.009632  0.007828  0.000464  0.019965
# LOCOMOTIVES1                  0.210788  0.193779  0.154927  0.025333
# LOADF1                        0.254566  0.232034  0.192584  0.037547
# LOADP1                        0.010159  0.014749  0.001445  0.004059
# EMPTYF1                       0.128621  0.119188  0.087839  0.044440
# EMPTYP1                       0.005085  0.009392 -0.010333 -0.012292
# LOCOMOTIVES2                  0.304300  0.311687  0.123593 -0.015012
# LOADF2                        0.383797  0.323389  0.367499 -0.032238
# EMPTYF2                       0.203634  0.173150  0.181595  0.011310
# TONS                          0.243380  0.220540  0.188211  0.068744
# SPEED                         0.338420  0.312698  0.207176 -0.059306
#
#                        MONTH  LOCOMOTIVES1    LOADF1    LOADP1   EMPTYF1  \
# INFRASTRUCTURE_DMG  0.009632      0.210788  0.254566  0.010159  0.128621
# EQPDMG              0.007828      0.193779  0.232034  0.014749  0.119188
# TRKDMG              0.000464      0.154927  0.192584  0.001445  0.087839
# YEAR4               0.019965      0.025333  0.037547  0.004059  0.044440
# MONTH               1.000000      0.006649 -0.001309 -0.010085  0.010240
# LOCOMOTIVES1        0.006649      1.000000  0.418610 -0.027346  0.289043
# LOADF1             -0.001309      0.418610  1.000000 -0.031623  0.233091
# LOADP1             -0.010085     -0.027346 -0.031623  1.000000 -0.031032
# EMPTYF1             0.010240      0.289043  0.233091 -0.031032  1.000000
# EMPTYP1            -0.021299     -0.026995 -0.057586  0.136896 -0.047775
# LOCOMOTIVES2        0.015342      0.249672  0.089082 -0.000541 -0.000297
# LOADF2             -0.005895      0.137852  0.367333 -0.019023  0.007760
# EMPTYF2             0.009566      0.068207  0.069317 -0.024215  0.365263
# TONS                0.005641      0.414786  0.879623 -0.019790  0.422477
# SPEED               0.003560      0.182562  0.177521  0.062121  0.035131
#
#                      EMPTYP1  LOCOMOTIVES2    LOADF2   EMPTYF2      TONS  \
# INFRASTRUCTURE_DMG  0.005085      0.304300  0.383797  0.203634  0.243380
# EQPDMG              0.009392      0.311687  0.323389  0.173150  0.220540
# TRKDMG             -0.010333      0.123593  0.367499  0.181595  0.188211
# YEAR4              -0.012292     -0.015012 -0.032238  0.011310  0.068744
# MONTH              -0.021299      0.015342 -0.005895  0.009566  0.005641
# LOCOMOTIVES1       -0.026995      0.249672  0.137852  0.068207  0.414786
# LOADF1             -0.057586      0.089082  0.367333  0.069317  0.879623
# LOADP1              0.136896     -0.000541 -0.019023 -0.024215 -0.019790
# EMPTYF1            -0.047775     -0.000297  0.007760  0.365263  0.422477
# EMPTYP1             1.000000      0.014861 -0.035746 -0.036787 -0.058106
# LOCOMOTIVES2        0.014861      1.000000  0.082772 -0.021992  0.068301
# LOADF2             -0.035746      0.082772  1.000000  0.070123  0.301792
# EMPTYF2            -0.036787     -0.021992  0.070123  1.000000  0.143483
# TONS               -0.058106      0.068301  0.301792  0.143483  1.000000
# SPEED               0.003395      0.162219  0.163154  0.045516  0.144011
#
#                        SPEED
# INFRASTRUCTURE_DMG  0.338420
# EQPDMG              0.312698
# TRKDMG              0.207176
# YEAR4              -0.059306
# MONTH               0.003560
# LOCOMOTIVES1        0.182562
# LOADF1              0.177521
# LOADP1              0.062121
# EMPTYF1             0.035131
# EMPTYP1             0.003395
# LOCOMOTIVES2        0.162219
# LOADF2              0.163154
# EMPTYF2             0.045516
# TONS                0.144011
# SPEED               1.000000

# %%
ax=plt.figure(figsize=(20,15)).gca()
ax=sns.heatmap(corr,ax=ax,linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True);
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.savefig(r"Images/Multi_Train/corrALL.png")

# %%
corr = df[df['TONS']!=0][['TONS', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1', 'LOADF2', 'EMPTYF2']].corr()
corr
# Out:
#              TONS    LOADF1    LOADP1   EMPTYF1   EMPTYP1    LOADF2   EMPTYF2
# TONS     1.000000  0.876947 -0.020965  0.411335 -0.060152  0.292926  0.131659
# LOADF1   0.876947  1.000000 -0.032864  0.218795 -0.059513  0.359711  0.056843
# LOADP1  -0.020965 -0.032864  1.000000 -0.032073  0.136848 -0.019646 -0.024888
# EMPTYF1  0.411335  0.218795 -0.032073  1.000000 -0.049308 -0.003483  0.358010
# EMPTYP1 -0.060152 -0.059513  0.136848 -0.049308  1.000000 -0.036683 -0.037771
# LOADF2   0.292926  0.359711 -0.019646 -0.003483 -0.036683  1.000000  0.062505
# EMPTYF2  0.131659  0.056843 -0.024888  0.358010 -0.037771  0.062505  1.000000

# %% [markdown]
# ### ANOVA <a class="anchor" id="ANOVA"></a>

# %%
anova_df =df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'TEMP_CLUSTER', 'ACCCAUSE_LVL1', 'ACCCAUSE_LVL2', 'ACCIDENT_TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']]

# %%
anova = anova_df.copy()
anova = anova.dropna

# %%
def anova(dmg, cat):
    #print ("ANOVA für INFRASTRUCUTURE_DMG ~ %s :" % (cat))
    mod= ols(dmg + ' ~ ' + cat , data=anova_df).fit()
    anova_table = sm.stats.anova_lm(mod, typ=2)
    esq_sm = anova_table['sum_sq'][0]/(anova_table['sum_sq'][0]+anova_table['sum_sq'][1])
    anova_table['EtaSq'] = [esq_sm, 'NaN']
    anova_table
    pair_t = mod.t_test_pairwise(cat)
    anova_table
    pair_t.result_frame
    return [anova_table, pair_t.result_frame]

# %% [markdown]
# #### ANOVA Korrelation Temperatur Cluster und Damage

# %%
temp_cluster = anova("INFRASTRUCTURE_DMG","TEMP_CLUSTER")

# %%
temp_cluster[0]
# Out:
#                     sum_sq      df         F    PR(>F)       EtaSq
# TEMP_CLUSTER  5.872755e+11     4.0  7.336142  0.000007  0.00369377
# Residual      1.584036e+14  7915.0       NaN       NaN         NaN

# %%
temp_cluster[1]
# Out:
#                                                                 coef  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                   -5918.498503
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               -5295.667208
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)            419280.056518
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 -9309.247228
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)           622.831295
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      425198.555021
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           -3390.748725
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  424575.723726
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)       -4013.580020
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)   -428589.303746
#
#                                                             std err         t  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                   8421.333473 -0.702798
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               7389.275481 -0.716669
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)            81979.066292  5.114477
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 7560.514891 -1.231298
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)         5142.523431  0.121114
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      81807.160232  5.197571
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           5385.679207 -0.629586
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  81707.368088  5.196297
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)       3562.032453 -1.126767
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)    81723.032207 -5.244413
#
#                                                               P>|t|  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                  4.822022e-01
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)              4.735993e-01
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)            3.219924e-07
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                2.182480e-01
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)        9.036039e-01
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      2.069537e-07
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)          5.289836e-01
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  2.083723e-07
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)      2.598752e-01
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)    1.608380e-07
#
#                                                        Conf. Int. Low  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                   -22426.533220
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               -19780.596059
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)             258579.464770
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 -24129.850485
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)          -9457.870960
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)       264834.944491
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           -13948.100432
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)   264407.732118
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)       -10996.103107
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)    -588788.001160
#
#                                                        Conf. Int. Upp.  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                     10589.536213
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)                  9189.261642
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)              579980.648266
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                    5511.356029
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)           10703.533550
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)        585562.165552
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)              7166.602983
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)    584743.715335
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)          2968.943068
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)     -268390.606332
#
#                                                        pvalue-hs  reject-hs
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                   0.923217      False
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               0.923217      False
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)             0.000002       True
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 0.771748      False
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)         0.923217      False
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)       0.000002       True
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           0.923217      False
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)   0.000002       True
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)       0.777912      False
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)     0.000002       True

# %% [markdown]
# #### ANOVA Korrelation Unfallursachen Cluster und Damage

# %%
cause = anova("INFRASTRUCTURE_DMG","ACCCAUSE_LVL2")

# %%
cause[0]
# Out:
#                      sum_sq      df         F    PR(>F)       EtaSq
# ACCCAUSE_LVL2  7.087262e+11     6.0  5.905225  0.000004  0.00445765
# Residual       1.582822e+14  7913.0       NaN       NaN         NaN

# %%
cause[1]
# Out:
#                                                                           coef  \
# Human Factors-Environmental Conditions                            16013.704360
# Loading-Environmental Conditions                                  45062.002381
# Mechanical and Electrical Failures-Environmental Conditions       40600.687175
# Miscellaneous Causes-Environmental Conditions                     10245.371636
# Signal and Communication-Environmental Conditions                  1372.699402
# Track, Roadbed and Structures-Environmental Conditions            38566.354735
# Loading-Human Factors                                             29048.298021
# Mechanical and Electrical Failures-Human Factors                  24586.982815
# Miscellaneous Causes-Human Factors                                -5768.332724
# Signal and Communication-Human Factors                           -14641.004959
# Track, Roadbed and Structures-Human Factors                       22552.650374
# Mechanical and Electrical Failures-Loading                        -4461.315206
# Miscellaneous Causes-Loading                                     -34816.630745
# Signal and Communication-Loading                                 -43689.302979
# Track, Roadbed and Structures-Loading                             -6495.647646
# Miscellaneous Causes-Mechanical and Electrical Failures          -30355.315539
# Signal and Communication-Mechanical and Electrical Failures      -39227.987774
# Track, Roadbed and Structures-Mechanical and Electrical Failures  -2034.332441
# Signal and Communication-Miscellaneous Causes                     -8872.672235
# Track, Roadbed and Structures-Miscellaneous Causes                28320.983098
# Track, Roadbed and Structures-Signal and Communication            37193.655333
#
#                                                                        std err  \
# Human Factors-Environmental Conditions                            17006.816945
# Loading-Environmental Conditions                                  22888.487383
# Mechanical and Electrical Failures-Environmental Conditions       18508.928128
# Miscellaneous Causes-Environmental Conditions                     17743.396559
# Signal and Communication-Environmental Conditions                 19760.591728
# Track, Roadbed and Structures-Environmental Conditions            17643.714019
# Loading-Human Factors                                             15543.683879
# Mechanical and Electrical Failures-Human Factors                   7765.544046
# Miscellaneous Causes-Human Factors                                 5705.381258
# Signal and Communication-Human Factors                            10402.126672
# Track, Roadbed and Structures-Human Factors                        5387.383248
# Mechanical and Electrical Failures-Loading                        17174.245439
# Miscellaneous Causes-Loading                                      16346.327030
# Signal and Communication-Loading                                  18516.351460
# Track, Roadbed and Structures-Loading                             16238.070401
# Miscellaneous Causes-Mechanical and Electrical Failures            9268.223841
# Signal and Communication-Mechanical and Electrical Failures       12710.343708
# Track, Roadbed and Structures-Mechanical and Electrical Failures   9075.929491
# Signal and Communication-Miscellaneous Causes                     11567.218255
# Track, Roadbed and Structures-Miscellaneous Causes                 7390.547822
# Track, Roadbed and Structures-Signal and Communication            11413.722491
#
#                                                                          t  \
# Human Factors-Environmental Conditions                            0.941605
# Loading-Environmental Conditions                                  1.968763
# Mechanical and Electrical Failures-Environmental Conditions       2.193573
# Miscellaneous Causes-Environmental Conditions                     0.577419
# Signal and Communication-Environmental Conditions                 0.069467
# Track, Roadbed and Structures-Environmental Conditions            2.185841
# Loading-Human Factors                                             1.868817
# Mechanical and Electrical Failures-Human Factors                  3.166164
# Miscellaneous Causes-Human Factors                               -1.011034
# Signal and Communication-Human Factors                           -1.407501
# Track, Roadbed and Structures-Human Factors                       4.186198
# Mechanical and Electrical Failures-Loading                       -0.259768
# Miscellaneous Causes-Loading                                     -2.129936
# Signal and Communication-Loading                                 -2.359498
# Track, Roadbed and Structures-Loading                            -0.400026
# Miscellaneous Causes-Mechanical and Electrical Failures          -3.275203
# Signal and Communication-Mechanical and Electrical Failures      -3.086304
# Track, Roadbed and Structures-Mechanical and Electrical Failures -0.224146
# Signal and Communication-Miscellaneous Causes                    -0.767053
# Track, Roadbed and Structures-Miscellaneous Causes                3.832055
# Track, Roadbed and Structures-Signal and Communication            3.258679
#
#                                                                      P>|t|  \
# Human Factors-Environmental Conditions                            0.346424
# Loading-Environmental Conditions                                  0.049015
# Mechanical and Electrical Failures-Environmental Conditions       0.028295
# Miscellaneous Causes-Environmental Conditions                     0.563673
# Signal and Communication-Environmental Conditions                 0.944620
# Track, Roadbed and Structures-Environmental Conditions            0.028856
# Loading-Human Factors                                             0.061685
# Mechanical and Electrical Failures-Human Factors                  0.001551
# Miscellaneous Causes-Human Factors                                0.312031
# Signal and Communication-Human Factors                            0.159318
# Track, Roadbed and Structures-Human Factors                       0.000029
# Mechanical and Electrical Failures-Loading                        0.795050
# Miscellaneous Causes-Loading                                      0.033208
# Signal and Communication-Loading                                  0.018324
# Track, Roadbed and Structures-Loading                             0.689148
# Miscellaneous Causes-Mechanical and Electrical Failures           0.001060
# Signal and Communication-Mechanical and Electrical Failures       0.002034
# Track, Roadbed and Structures-Mechanical and Electrical Failures  0.822650
# Signal and Communication-Miscellaneous Causes                     0.443073
# Track, Roadbed and Structures-Miscellaneous Causes                0.000128
# Track, Roadbed and Structures-Signal and Communication            0.001124
#
#                                                                   Conf. Int. Low  \
# Human Factors-Environmental Conditions                             -17324.143654
# Loading-Environmental Conditions                                      194.528583
# Mechanical and Electrical Failures-Environmental Conditions          4318.304948
# Miscellaneous Causes-Environmental Conditions                      -24536.366749
# Signal and Communication-Environmental Conditions                  -37363.273699
# Track, Roadbed and Structures-Environmental Conditions               3980.020425
# Loading-Human Factors                                               -1421.423176
# Mechanical and Electrical Failures-Human Factors                     9364.467750
# Miscellaneous Causes-Human Factors                                 -16952.385206
# Signal and Communication-Human Factors                             -35031.917565
# Track, Roadbed and Structures-Human Factors                         11991.957888
# Mechanical and Electrical Failures-Loading                         -38127.367241
# Miscellaneous Causes-Loading                                       -66859.744274
# Signal and Communication-Loading                                   -79986.236894
# Track, Roadbed and Structures-Loading                              -38326.549621
# Miscellaneous Causes-Mechanical and Electrical Failures            -48523.479445
# Signal and Communication-Mechanical and Electrical Failures        -64143.614732
# Track, Roadbed and Structures-Mechanical and Electrical Failures   -19825.548690
# Signal and Communication-Miscellaneous Causes                      -31547.471721
# Track, Roadbed and Structures-Miscellaneous Causes                  13833.559565
# Track, Roadbed and Structures-Signal and Communication              14819.748038
#
#                                                                   Conf. Int. Upp.  \
# Human Factors-Environmental Conditions                               49351.552375
# Loading-Environmental Conditions                                     89929.476179
# Mechanical and Electrical Failures-Environmental Conditions          76883.069402
# Miscellaneous Causes-Environmental Conditions                        45027.110021
# Signal and Communication-Environmental Conditions                    40108.672503
# Track, Roadbed and Structures-Environmental Conditions               73152.689044
# Loading-Human Factors                                                59518.019217
# Mechanical and Electrical Failures-Human Factors                     39809.497880
# Miscellaneous Causes-Human Factors                                    5415.719758
# Signal and Communication-Human Factors                                5749.907648
# Track, Roadbed and Structures-Human Factors                          33113.342861
# Mechanical and Electrical Failures-Loading                           29204.736829
# Miscellaneous Causes-Loading                                         -2773.517216
# Signal and Communication-Loading                                     -7392.369064
# Track, Roadbed and Structures-Loading                                25335.254328
# Miscellaneous Causes-Mechanical and Electrical Failures             -12187.151633
# Signal and Communication-Mechanical and Electrical Failures         -14312.360815
# Track, Roadbed and Structures-Mechanical and Electrical Failures     15756.883808
# Signal and Communication-Miscellaneous Causes                        13802.127252
# Track, Roadbed and Structures-Miscellaneous Causes                   42808.406631
# Track, Roadbed and Structures-Signal and Communication               59567.562627
#
#                                                                   pvalue-hs  \
# Human Factors-Environmental Conditions                             0.949818
# Loading-Environmental Conditions                                   0.424680
# Mechanical and Electrical Failures-Environmental Conditions        0.330915
# Miscellaneous Causes-Environmental Conditions                      0.984185
# Signal and Communication-Environmental Conditions                  0.991391
# Track, Roadbed and Structures-Environmental Conditions             0.330915
# Loading-Human Factors                                              0.470964
# Mechanical and Electrical Failures-Human Factors                   0.026034
# Miscellaneous Causes-Human Factors                                 0.949818
# Signal and Communication-Human Factors                             0.790258
# Track, Roadbed and Structures-Human Factors                        0.000602
# Mechanical and Electrical Failures-Loading                         0.991391
# Miscellaneous Causes-Loading                                       0.333196
# Signal and Communication-Loading                                   0.242254
# Track, Roadbed and Structures-Loading                              0.990663
# Miscellaneous Causes-Mechanical and Electrical Failures            0.019957
# Signal and Communication-Mechanical and Electrical Failures        0.032046
# Track, Roadbed and Structures-Mechanical and Electrical Failures   0.991391
# Signal and Communication-Miscellaneous Causes                      0.970161
# Track, Roadbed and Structures-Miscellaneous Causes                 0.002558
# Track, Roadbed and Structures-Signal and Communication             0.020041
#
#                                                                   reject-hs
# Human Factors-Environmental Conditions                                False
# Loading-Environmental Conditions                                      False
# Mechanical and Electrical Failures-Environmental Conditions           False
# Miscellaneous Causes-Environmental Conditions                         False
# Signal and Communication-Environmental Conditions                     False
# Track, Roadbed and Structures-Environmental Conditions                False
# Loading-Human Factors                                                 False
# Mechanical and Electrical Failures-Human Factors                       True
# Miscellaneous Causes-Human Factors                                    False
# Signal and Communication-Human Factors                                False
# Track, Roadbed and Structures-Human Factors                            True
# Mechanical and Electrical Failures-Loading                            False
# Miscellaneous Causes-Loading                                          False
# Signal and Communication-Loading                                      False
# Track, Roadbed and Structures-Loading                                 False
# Miscellaneous Causes-Mechanical and Electrical Failures                True
# Signal and Communication-Mechanical and Electrical Failures            True
# Track, Roadbed and Structures-Mechanical and Electrical Failures      False
# Signal and Communication-Miscellaneous Causes                         False
# Track, Roadbed and Structures-Miscellaneous Causes                     True
# Track, Roadbed and Structures-Signal and Communication                 True

# %% [markdown]
# #### ANOVA Korrelation Unfallart und Damage

# %%
accidenttype = anova("INFRASTRUCTURE_DMG","ACCIDENT_TYPE")

# %%
accidenttype[0]
# Out:
#                      sum_sq      df         F    PR(>F)       EtaSq
# ACCIDENT_TYPE  2.474742e+11     3.0  4.113569  0.006329  0.00155653
# Residual       1.587434e+14  7916.0       NaN       NaN         NaN

# %%
accidenttype[1]
# Out:
#                                                                   coef  \
# Crossing-Collision                                        26448.332300
# Derailment-Collision                                      11699.776768
# Fire / Violent Rupture / Explosive Detonation-Collision  -29078.334366
# Derailment-Crossing                                      -14748.555532
# Fire / Violent Rupture / Explosive Detonation-Crossing   -55526.666667
# Fire / Violent Rupture / Explosive Detonation-Derailment -40778.111134
#
#                                                                std err  \
# Crossing-Collision                                        25924.987546
# Derailment-Collision                                       3465.188747
# Fire / Violent Rupture / Explosive Detonation-Collision   81781.117948
# Derailment-Crossing                                       26015.413234
# Fire / Violent Rupture / Explosive Detonation-Crossing    85749.317464
# Fire / Violent Rupture / Explosive Detonation-Derailment  81809.828256
#
#                                                                  t     P>|t|  \
# Crossing-Collision                                        1.020187  0.307671
# Derailment-Collision                                      3.376375  0.000738
# Fire / Violent Rupture / Explosive Detonation-Collision  -0.355563  0.722177
# Derailment-Crossing                                      -0.566916  0.570787
# Fire / Violent Rupture / Explosive Detonation-Crossing   -0.647546  0.517297
# Fire / Violent Rupture / Explosive Detonation-Derailment -0.498450  0.618181
#
#                                                           Conf. Int. Low  \
# Crossing-Collision                                         -24371.479971
# Derailment-Collision                                         4907.093018
# Fire / Violent Rupture / Explosive Detonation-Collision   -189390.892054
# Derailment-Crossing                                        -65745.625999
# Fire / Violent Rupture / Explosive Detonation-Crossing    -223617.941859
# Fire / Violent Rupture / Explosive Detonation-Derailment  -201146.948597
#
#                                                           Conf. Int. Upp.  \
# Crossing-Collision                                           77268.144572
# Derailment-Collision                                         18492.460518
# Fire / Violent Rupture / Explosive Detonation-Collision     131234.223321
# Derailment-Crossing                                          36248.514934
# Fire / Violent Rupture / Explosive Detonation-Crossing      112564.608526
# Fire / Violent Rupture / Explosive Detonation-Derailment    119590.726329
#
#                                                           pvalue-hs  reject-hs
# Crossing-Collision                                         0.840939      False
# Derailment-Collision                                       0.004420       True
# Fire / Violent Rupture / Explosive Detonation-Collision    0.945710      False
# Derailment-Crossing                                        0.945710      False
# Fire / Violent Rupture / Explosive Detonation-Crossing     0.945710      False
# Fire / Violent Rupture / Explosive Detonation-Derailment   0.945710      False

# %% [markdown]
# #### ANOVA Korrelation Zugart und Damage

# %%
eqtype = anova("INFRASTRUCTURE_DMG","EQUIPMENT_TYPE")

# %%
eqtype[0]
# Out:
#                       sum_sq      df          F         PR(>F)     EtaSq
# EQUIPMENT_TYPE  1.830637e+13    90.0  11.319302  3.423024e-146  0.115141
# Residual        1.406845e+14  7829.0        NaN            NaN       NaN

# %%
eqtype[1]
# Out:
#                                                                                         coef  \
# Commuter Train, Locomotive, NaN-Commuter Train, Commuter Train                 178197.000000
# Commuter Train, NaN-Commuter Train, Commuter Train                             -53351.333333
# Commuter Train, Yard/Switching-Commuter Train, Commuter Train                  -61679.000000
# Cut of Cars, Cut of Cars-Commuter Train, Commuter Train                        -73449.945946
# Cut of Cars, Cut of Cars, Cut of Cars-Commuter Train, Commuter Train           -79436.666667
# ...                                                                                      ...
# Yard/Switching, Yard/Switching-Work Train, Yard/Switching                      -16733.728934
# Yard/Switching, Yard/Switching, Yard/Switching-Work Train, Yard/Switching       -6479.416667
# Yard/Switching, Yard/Switching-Yard/Switching, NaN                              -3935.412268
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, NaN               6318.900000
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, Yard/Switching   10254.312268
#
#                                                                                      std err  \
# Commuter Train, Locomotive, NaN-Commuter Train, Commuter Train                 189576.717478
# Commuter Train, NaN-Commuter Train, Commuter Train                             154788.741644
# Commuter Train, Yard/Switching-Commuter Train, Commuter Train                  189576.717478
# Cut of Cars, Cut of Cars-Commuter Train, Commuter Train                        134503.095006
# Cut of Cars, Cut of Cars, Cut of Cars-Commuter Train, Commuter Train           154788.741644
# ...                                                                                      ...
# Yard/Switching, Yard/Switching-Work Train, Yard/Switching                       38869.428927
# Yard/Switching, Yard/Switching, Yard/Switching-Work Train, Yard/Switching      102383.129036
# Yard/Switching, Yard/Switching-Yard/Switching, NaN                              42547.936929
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, NaN             103835.444540
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, Yard/Switching   94858.807176
#
#                                                                                       t  \
# Commuter Train, Locomotive, NaN-Commuter Train, Commuter Train                 0.939973
# Commuter Train, NaN-Commuter Train, Commuter Train                            -0.344672
# Commuter Train, Yard/Switching-Commuter Train, Commuter Train                 -0.325351
# Cut of Cars, Cut of Cars-Commuter Train, Commuter Train                       -0.546084
# Cut of Cars, Cut of Cars, Cut of Cars-Commuter Train, Commuter Train          -0.513194
# ...                                                                                 ...
# Yard/Switching, Yard/Switching-Work Train, Yard/Switching                     -0.430511
# Yard/Switching, Yard/Switching, Yard/Switching-Work Train, Yard/Switching     -0.063286
# Yard/Switching, Yard/Switching-Yard/Switching, NaN                            -0.092494
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, NaN             0.060855
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, Yard/Switching  0.108101
#
#                                                                                   P>|t|  \
# Commuter Train, Locomotive, NaN-Commuter Train, Commuter Train                 0.347260
# Commuter Train, NaN-Commuter Train, Commuter Train                             0.730350
# Commuter Train, Yard/Switching-Commuter Train, Commuter Train                  0.744924
# Cut of Cars, Cut of Cars-Commuter Train, Commuter Train                        0.585024
# Cut of Cars, Cut of Cars, Cut of Cars-Commuter Train, Commuter Train           0.607830
# ...                                                                                 ...
# Yard/Switching, Yard/Switching-Work Train, Yard/Switching                      0.666836
# Yard/Switching, Yard/Switching, Yard/Switching-Work Train, Yard/Switching      0.949540
# Yard/Switching, Yard/Switching-Yard/Switching, NaN                             0.926308
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, NaN             0.951476
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, Yard/Switching  0.913919
#
#                                                                                Conf. Int. Low  \
# Commuter Train, Locomotive, NaN-Commuter Train, Commuter Train                 -193423.991079
# Commuter Train, NaN-Commuter Train, Commuter Train                             -356778.601950
# Commuter Train, Yard/Switching-Commuter Train, Commuter Train                  -433299.991079
# Cut of Cars, Cut of Cars-Commuter Train, Commuter Train                        -337111.930047
# Cut of Cars, Cut of Cars, Cut of Cars-Commuter Train, Commuter Train           -382863.935284
# ...                                                                                       ...
# Yard/Switching, Yard/Switching-Work Train, Yard/Switching                       -92928.189377
# Yard/Switching, Yard/Switching, Yard/Switching-Work Train, Yard/Switching      -207177.690106
# Yard/Switching, Yard/Switching-Yard/Switching, NaN                              -87340.730706
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, NaN             -197226.299656
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, Yard/Switching  -175694.281021
#
#                                                                                Conf. Int. Upp.  \
# Commuter Train, Locomotive, NaN-Commuter Train, Commuter Train                   549817.991079
# Commuter Train, NaN-Commuter Train, Commuter Train                               250075.935284
# Commuter Train, Yard/Switching-Commuter Train, Commuter Train                    309941.991079
# Cut of Cars, Cut of Cars-Commuter Train, Commuter Train                          190212.038155
# Cut of Cars, Cut of Cars, Cut of Cars-Commuter Train, Commuter Train             223990.601950
# ...                                                                                        ...
# Yard/Switching, Yard/Switching-Work Train, Yard/Switching                         59460.731508
# Yard/Switching, Yard/Switching, Yard/Switching-Work Train, Yard/Switching        194218.856772
# Yard/Switching, Yard/Switching-Yard/Switching, NaN                                79469.906171
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, NaN               209864.099656
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, Yard/Switching    196202.905556
#
#                                                                                pvalue-hs  \
# Commuter Train, Locomotive, NaN-Commuter Train, Commuter Train                       1.0
# Commuter Train, NaN-Commuter Train, Commuter Train                                   1.0
# Commuter Train, Yard/Switching-Commuter Train, Commuter Train                        1.0
# Cut of Cars, Cut of Cars-Commuter Train, Commuter Train                              1.0
# Cut of Cars, Cut of Cars, Cut of Cars-Commuter Train, Commuter Train                 1.0
# ...                                                                                  ...
# Yard/Switching, Yard/Switching-Work Train, Yard/Switching                            1.0
# Yard/Switching, Yard/Switching, Yard/Switching-Work Train, Yard/Switching            1.0
# Yard/Switching, Yard/Switching-Yard/Switching, NaN                                   1.0
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, NaN                   1.0
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, Yard/Switching        1.0
#
#                                                                                reject-hs
# Commuter Train, Locomotive, NaN-Commuter Train, Commuter Train                     False
# Commuter Train, NaN-Commuter Train, Commuter Train                                 False
# Commuter Train, Yard/Switching-Commuter Train, Commuter Train                      False
# Cut of Cars, Cut of Cars-Commuter Train, Commuter Train                            False
# Cut of Cars, Cut of Cars, Cut of Cars-Commuter Train, Commuter Train               False
# ...                                                                                  ...
# Yard/Switching, Yard/Switching-Work Train, Yard/Switching                          False
# Yard/Switching, Yard/Switching, Yard/Switching-Work Train, Yard/Switching          False
# Yard/Switching, Yard/Switching-Yard/Switching, NaN                                 False
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, NaN                 False
# Yard/Switching, Yard/Switching, Yard/Switching-Yard/Switching, Yard/Switching      False
#
# [4095 rows x 8 columns]

# %% [markdown]
# #### ANOVA Korrelation Sichtbarkeit und Damage

# %%
vis = anova("INFRASTRUCTURE_DMG","VISIBLTY")

# %%
vis[0]
# Out:
#                 sum_sq      df         F    PR(>F)        EtaSq
# VISIBLTY  4.335354e+10     3.0  0.719706  0.540077  0.000272679
# Residual  1.589475e+14  7916.0       NaN       NaN          NaN

# %%
vis[1]
# Out:
#                   coef       std err         t     P>|t|  Conf. Int. Low  \
# Dawn-Dark  4905.783131   8289.655981  0.591796  0.554004   -11344.128658
# Day-Dark  -3733.248410   3338.542663 -1.118227  0.263504   -10277.672437
# Dusk-Dark -4951.484403   7502.083907 -0.660015  0.509264   -19657.547236
# Day-Dawn  -8639.031541   8289.282797 -1.042193  0.297354   -24888.211790
# Dusk-Dawn -9857.267534  10669.939321 -0.923835  0.355600   -30773.162375
# Dusk-Day  -1218.235993   7501.671544 -0.162395  0.870999   -15923.490486
#
#            Conf. Int. Upp.  pvalue-hs  reject-hs
# Dawn-Dark     21155.694919   0.881820      False
# Day-Dark       2811.175616   0.840404      False
# Dusk-Dark      9754.578430   0.881820      False
# Day-Dawn       7610.148709   0.840404      False
# Dusk-Dawn     11058.627307   0.840404      False
# Dusk-Day      13487.018500   0.881820      False

# %% [markdown]
# #### ANOVA Korrelation Wetter und Damage

# %%
weather = anova("INFRASTRUCTURE_DMG","WEATHER")

# %%
weather[0]
# Out:
#                 sum_sq      df         F   PR(>F)       EtaSq
# WEATHER   4.079837e+11     5.0  4.072044  0.00108  0.00256608
# Residual  1.585829e+14  7914.0       NaN      NaN         NaN

# %%
weather[1]
# Out:
#                       coef       std err         t     P>|t|  Conf. Int. Low  \
# Cloudy-Clear  -4821.631722   3789.497159 -1.272367  0.203280   -12250.045770
# Fog-Clear     51432.788591  12667.782018  4.060126  0.000050    26600.594253
# Rain-Clear    -6853.248355   6068.546543 -1.129306  0.258803   -18749.200377
# Sleet-Clear   -3153.887880  34389.615748 -0.091710  0.926930   -70566.606242
# Snow-Clear    -4802.783352  12168.974090 -0.394674  0.693094   -28657.182572
# Fog-Cloudy    56254.420313  12922.291373  4.353285  0.000014    30923.320503
# Rain-Cloudy   -2031.616633   6583.325164 -0.308600  0.757634   -14936.670544
# Sleet-Cloudy   1667.743842  34484.178755  0.048363  0.961429   -65930.342957
# Snow-Cloudy      18.848370  12433.697901  0.001516  0.998791   -24354.479349
# Rain-Fog     -58286.036946  13764.177518 -4.234618  0.000023   -85267.455678
# Sleet-Fog    -54586.676471  36541.360086 -1.493833  0.135259  -126217.381334
# Snow-Fog     -56235.571942  17340.970446 -3.242931  0.001188   -90228.448321
# Sleet-Rain     3699.360475  34808.412099  0.106278  0.915365   -64534.309206
# Snow-Rain      2050.465003  13306.532678  0.154095  0.877539   -24033.849121
# Snow-Sleet    -1648.895472  36371.447951 -0.045335  0.963842   -72946.527732
#
#               Conf. Int. Upp.  pvalue-hs  reject-hs
# Cloudy-Clear      2606.782326   0.896948      False
# Fog-Clear        76264.982928   0.000644       True
# Rain-Clear        5042.703667   0.932484      False
# Sleet-Clear      64258.830483   0.999997      False
# Snow-Clear       19051.615869   0.999921      False
# Fog-Cloudy       81585.520122   0.000204       True
# Rain-Cloudy      10873.437277   0.999951      False
# Sleet-Cloudy     69265.830641   0.999997      False
# Snow-Cloudy      24392.176089   0.999997      False
# Rain-Fog        -31304.618214   0.000324       True
# Sleet-Fog        17044.028393   0.797817      False
# Snow-Fog        -22242.695564   0.014163       True
# Sleet-Rain       71933.030156   0.999997      False
# Snow-Rain        28134.779128   0.999997      False
# Snow-Sleet       69648.736788   0.999997      False

# %% [markdown]
# #### ANOVA Korrelation zu hoher Geschwindigkeit und Damage

# %%
spd = anova("INFRASTRUCTURE_DMG","SPD_TOO_HIGH")

# %%
spd[0]
# Out:
#                     sum_sq      df          F        PR(>F)       EtaSq
# SPD_TOO_HIGH  7.993239e+11     1.0  40.008753  2.665525e-10  0.00502748
# Residual      1.581916e+14  7918.0        NaN           NaN         NaN

# %%
spd[1]
# Out:
#                    coef      std err         t         P>|t|  Conf. Int. Low  \
# True-False  55461.13581  8768.216259  6.325247  2.665525e-10    38273.120338
#
#             Conf. Int. Upp.     pvalue-hs  reject-hs
# True-False     72649.151282  2.665524e-10       True

# %% [markdown]
# #### ANOVA Korrelation Streckenart und Damage

# %%
typtrk = anova("INFRASTRUCTURE_DMG","TYPTRK")

# %%
typtrk[0]
# Out:
#                 sum_sq      df           F         PR(>F)      EtaSq
# TYPTRK    1.211488e+13     3.0  217.647143  1.129833e-135  0.0761986
# Residual  1.468760e+14  7916.0         NaN            NaN        NaN

# %%
typtrk[1]
# Out:
#                           coef       std err          t          P>|t|  \
# Main-Industry     99259.430825   7491.208637  13.250122   1.188584e-39
# Siding-Industry   45099.689732  11146.644294   4.046033   5.258825e-05
# Yard-Industry     -7156.208152   6671.994614  -1.072574   2.834950e-01
# Siding-Main      -54159.741093   9875.935391  -5.484011   4.286067e-08
# Yard-Main       -106415.638977   4219.233694 -25.221556  4.494983e-135
# Yard-Siding      -52255.897884   9269.919370  -5.637147   1.788313e-08
#
#                  Conf. Int. Low  Conf. Int. Upp.     pvalue-hs  reject-hs
# Main-Industry      84574.686389    113944.175261  0.000000e+00       True
# Siding-Industry    23249.327434     66950.052031  1.051737e-04       True
# Yard-Industry     -20235.077067      5922.660763  2.834950e-01      False
# Siding-Main       -73519.178843    -34800.303342  1.285820e-07       True
# Yard-Main        -114686.449671    -98144.828283  0.000000e+00       True
# Yard-Siding       -70427.384421    -34084.411347  7.153252e-08       True

# %% [markdown]
# #### ANOVA Korrelation Signifikanzlevel und Damage

# %%
acctype = anova("INFRASTRUCTURE_DMG","ACCTYPE")

# %%
acctype[0]
# Out:
#                 sum_sq      df            F  PR(>F)     EtaSq
# ACCTYPE   4.234453e+13     1.0  2874.363145     0.0  0.266333
# Residual  1.166464e+14  7918.0          NaN     NaN       NaN

# %%
acctype[1]
# Out:
#                                       coef      std err          t  P>|t|  \
# Significant-Not Significant  214500.118137  4000.890983  53.613087    0.0
#
#                              Conf. Int. Low  Conf. Int. Upp.  pvalue-hs  \
# Significant-Not Significant   206657.317037    222342.919237        0.0
#
#                              reject-hs
# Significant-Not Significant       True

# %% [markdown]
# #### ANOVA Korrelation Jahreszeit und Damage

# %%
jahreszeit = anova("INFRASTRUCTURE_DMG","Jahreszeit")

# %%
jahreszeit[0]
# Out:
#                   sum_sq      df         F    PR(>F)        EtaSq
# Jahreszeit  8.949657e+10     3.0  1.486152  0.216114  0.000562904
# Residual    1.589014e+14  7916.0       NaN       NaN          NaN

# %%
jahreszeit[1]
# Out:
#                         coef      std err         t     P>|t|  Conf. Int. Low  \
# Herbst-Frühling -5568.640082  4540.579412 -1.226416  0.220079   -14469.373125
# Sommer-Frühling -1042.766931  4462.333505 -0.233682  0.815238    -9790.117363
# Winter-Frühling -8350.055348  4573.958641 -1.825564  0.067954   -17316.220485
# Sommer-Herbst    4525.873151  4437.950058  1.019812  0.307849    -4173.679295
# Winter-Herbst   -2781.415267  4550.173410 -0.611277  0.541034   -11700.955077
# Winter-Sommer   -7307.288417  4472.095367 -1.633974  0.102304   -16073.774674
#
#                  Conf. Int. Upp.  pvalue-hs  reject-hs
# Herbst-Frühling      3332.092962   0.629999      False
# Sommer-Frühling      7704.583501   0.815238      False
# Winter-Frühling       616.109788   0.344421      False
# Sommer-Herbst       13225.425596   0.668409      False
# Winter-Herbst        6138.124543   0.789350      False
# Winter-Sommer        1459.197839   0.417030      False

# %%
temp_cluster_eqpdmg = anova("EQPDMG","TEMP_CLUSTER")
cause_eqpdmg = anova("EQPDMG","ACCCAUSE_LVL2")
accidenttype_eqpdmg = anova("EQPDMG","ACCIDENT_TYPE")
eqtype_eqpdmg = anova("EQPDMG","EQUIPMENT_TYPE")
vis_eqpdmg = anova("EQPDMG","VISIBLTY")
weather_eqpdmg = anova("EQPDMG","WEATHER")
spd_eqpdmg = anova("EQPDMG","SPD_TOO_HIGH")
typtrk_eqpdmg = anova("EQPDMG","TYPTRK")
acctype_eqpdmg = anova("EQPDMG","ACCTYPE")
jahreszeit_eqpdmg = anova("EQPDMG","Jahreszeit")

# %%
temp_cluster_trkdmg = anova("TRKDMG","TEMP_CLUSTER")
cause_trkdmg = anova("TRKDMG","ACCCAUSE_LVL2")
accidenttype_trkdmg = anova("TRKDMG","ACCIDENT_TYPE")
eqtype_trkdmg = anova("TRKDMG","EQUIPMENT_TYPE")
vis_trkdmg = anova("TRKDMG","VISIBLTY")
weather_trkdmg = anova("TRKDMG","WEATHER")
spd_trkdmg = anova("TRKDMG","SPD_TOO_HIGH")
typtrk_trkdmg = anova("TRKDMG","TYPTRK")
acctype_trkdmg = anova("TRKDMG","ACCTYPE")
jahreszeit_trkdmg = anova("TRKDMG","Jahreszeit")

# %%
compare_anova = [
                                [
                                    temp_cluster[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis[0]["EtaSq"]["VISIBLTY"],
                                    weather[0]["EtaSq"]["WEATHER"],
                                    spd[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk[0]["EtaSq"]["TYPTRK"],
                                    acctype[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit[0]["EtaSq"]["Jahreszeit"]
                                ],
                                [
                                    temp_cluster_eqpdmg[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause_eqpdmg[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype_eqpdmg[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype_eqpdmg[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis_eqpdmg[0]["EtaSq"]["VISIBLTY"],
                                    weather_eqpdmg[0]["EtaSq"]["WEATHER"],
                                    spd_eqpdmg[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk_eqpdmg[0]["EtaSq"]["TYPTRK"],
                                    acctype_eqpdmg[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit_eqpdmg[0]["EtaSq"]["Jahreszeit"]
                                ],
                                [
                                    temp_cluster_trkdmg[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause_trkdmg[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype_trkdmg[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype_trkdmg[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis_trkdmg[0]["EtaSq"]["VISIBLTY"],
                                    weather_trkdmg[0]["EtaSq"]["WEATHER"],
                                    spd_trkdmg[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk_trkdmg[0]["EtaSq"]["TYPTRK"],
                                    acctype_trkdmg[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit_trkdmg[0]["EtaSq"]["Jahreszeit"]
                                ]
                            ]
pd.DataFrame(compare_anova,columns=["Temperatur", "Ursache","Unfallart", "Zugart", "Sichtbarkeit", "Wetter", "Zug zu schnell?", "Streckenart", "Siginifikanz des Unfalls", "Jahreszeit"], index=["Infrastrukturschaden", "Materialschaden", "Streckenschaden"]).style.format("{:.1g}")
# Out:
# <style  type="text/css" >
# </style><table id="T_ac36101a_d199_11ea_8a46_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Temperatur</th>        <th class="col_heading level0 col1" >Ursache</th>        <th class="col_heading level0 col2" >Unfallart</th>        <th class="col_heading level0 col3" >Zugart</th>        <th class="col_heading level0 col4" >Sichtbarkeit</th>        <th class="col_heading level0 col5" >Wetter</th>        <th class="col_heading level0 col6" >Zug zu schnell?</th>        <th class="col_heading level0 col7" >Streckenart</th>        <th class="col_heading level0 col8" >Siginifikanz des Unfalls</th>        <th class="col_heading level0 col9" >Jahreszeit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ac36101a_d199_11ea_8a46_acde48001122level0_row0" class="row_heading level0 row0" >Infrastrukturschaden</th>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row0_col0" class="data row0 col0" >0.004</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row0_col1" class="data row0 col1" >0.004</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row0_col2" class="data row0 col2" >0.002</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row0_col3" class="data row0 col3" >0.1</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row0_col4" class="data row0 col4" >0.0003</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row0_col5" class="data row0 col5" >0.003</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row0_col6" class="data row0 col6" >0.005</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row0_col7" class="data row0 col7" >0.08</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row0_col8" class="data row0 col8" >0.3</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row0_col9" class="data row0 col9" >0.0006</td>
#             </tr>
#             <tr>
#                         <th id="T_ac36101a_d199_11ea_8a46_acde48001122level0_row1" class="row_heading level0 row1" >Materialschaden</th>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row1_col0" class="data row1 col0" >0.003</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row1_col1" class="data row1 col1" >0.002</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row1_col2" class="data row1 col2" >0.0002</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row1_col3" class="data row1 col3" >0.1</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row1_col4" class="data row1 col4" >0.0003</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row1_col5" class="data row1 col5" >0.003</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row1_col6" class="data row1 col6" >0.005</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row1_col7" class="data row1 col7" >0.07</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row1_col8" class="data row1 col8" >0.2</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row1_col9" class="data row1 col9" >0.0004</td>
#             </tr>
#             <tr>
#                         <th id="T_ac36101a_d199_11ea_8a46_acde48001122level0_row2" class="row_heading level0 row2" >Streckenschaden</th>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row2_col0" class="data row2 col0" >0.002</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row2_col1" class="data row2 col1" >0.03</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row2_col2" class="data row2 col2" >0.03</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row2_col3" class="data row2 col3" >0.06</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row2_col4" class="data row2 col4" >0.0006</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row2_col5" class="data row2 col5" >0.0003</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row2_col6" class="data row2 col6" >0.002</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row2_col7" class="data row2 col7" >0.02</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row2_col8" class="data row2 col8" >0.1</td>
#                         <td id="T_ac36101a_d199_11ea_8a46_acde48001122row2_col9" class="data row2 col9" >0.0004</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### ANOVA Heatmap <a class="anchor" id="ANOVA_HEATMAP"></a>
#
# **Interpretation:** Nach Cohen (1988) bei .01 (kleiner Effekt), .06 (mittlerer Effekt) und .14 (großer Effekt)
#
# [Cohen, J. (1988)](http://www.utstat.toronto.edu/~brunner/oldclass/378f16/readings/CohenPower.pdf). Statistical Power Analysis for the Behavioral Sciences.

# %%
colormap = plt.cm.Blues
ax=plt.figure(figsize=(20,15)).gca()
x_axis_labels = ["Temperatur", "Ursache","Unfallart", "Zugart", "Sichtbarkeit", "Wetter", "Zug zu schnell?", "Streckenart", "Siginifikanz des Unfalls", "Jahreszeit"] # labels for x-axis
y_axis_labels = ["Infrastrukturschaden", "Materialschaden", "Streckenschaden"] # labels for y-axis
ax=sns.heatmap(compare_anova,ax=ax,linewidths=0.1, 
            square=True, cmap=colormap, linecolor='white', annot=True, xticklabels=x_axis_labels, yticklabels=y_axis_labels, vmin=0, vmax=0.5);
bottom, top = ax.get_ylim()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, horizontalalignment='right', verticalalignment='top')
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.savefig("Images/Multi_Train/ANOVA_Heatmap.png")
