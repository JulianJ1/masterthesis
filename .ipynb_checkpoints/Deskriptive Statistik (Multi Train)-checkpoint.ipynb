# %% [markdown]
# # Masterthesis
# ## Deskriptive Statistik
# #### Julian Jetz

# %% [markdown]
# ## Inhalt:
#
# * [Boxenplots und Histogramme der Schäden (mit Ausreißern)](#ausreißer)
#
#
# * [Entfernung der Ausreißer](#ausreißer-delete)
#
#
# * [Häufigkeitsverteilungen](#frequencies)
#     * [Zugart](#freq-zugart)
#     * [Unfallart](#freq-unfallart)
#     * [Streckenart](#freq-streckenart)
#     * [Unfallursache Lvl 2](#freq-cause)
#         * [Unfallursache Lvl 1 (nach Unfallart aufgeteilt)](#freq-cause_lvl1_lvl2_unfallart)
#     * [Unfallsignifikanz](#freq-acctype)
#         * [Unfallsignifikanz (nach Unfallursache Lvl 2)](#freq-acctype_cause)
#     * [Wetter](#freq-wetter)
#     * [Jahreszeit](#freq-jahreszeit)
#     * [Jahr](#freq-jahr)
#         * [Jahr nach Unfallart](#freq-jahr_unfallart)
#     * [Temperatur](#freq-temp)
#         * [Unfallursachen nach Temperatur](#freq-temp_cause)
#     * [Sichtbarkeit](#freq-vis)
#     * [Geschwindigkeitsüberschreitung](#freq-speed)
#
#
# * [Verteilungstabellen](#tables)
#     * [Zugart nach Unfallart](#tables_eqtype_type)
#     * [Unfallart nach Zugart](#tables_type_eqtype)
#     * [Unfallursache nach Zugart](#tables_zugart_cause)
#     * [Unfallursache nach Wetter](#tables_weather_cause)
#     * [Unfallursache nach Jahreszeit](#tables_jahreszeit_cause)
#     * [Unfallursache nach Temperatur](#tables_cause_temp)
#     * [Unfallursache nach Sichtbarkeit](#tables_vis_cause)
#     * [Sichtbarkeit nach Unfallursache](#tables_cause_vis)
#     * [Geschwindigkeitsüberschreitung nach Unfallart](#tables_speed_acctype)
#     * [Geschwindigkeitsüberschreitung nach Streckenart](#tables_speed_typtrk)
#     * [Geschwindigkeitsüberschreitung nach Zugart](#tables_speed_eqtype)
#
#
# * [Boxenplots und Histogramme](#boxenplots)
#     * [Infrastrukturschaden](#infrastrukturdmg)
#     * [Materialschaden](#EQPDMG)
#     * [Streckenschaden](#TRKDMG)
#     * [Zuggeschwindigkeit](#zuggeschwindigkeit)
#     * [Zuggewicht](#tons)
#     * [Zugart](#zugart)
#     * [Unfallart](#unfallart)
#     * [Streckenart](#typtrk)
#     * [Unfallursache Lvl 2](#cause)
#     * [Unfallsignifikanz](#unfallsignifikanz)
#     * [Wetter](#wetter)
#     * [Jahreszeit](#Jahreszeit)
#     * [Jahr](#jahr)
#     * [Temperatur](#temp)
#     * [Sichrbarkeit](#vis)
#     * [Geschwindigkeitsüberschreitung](#speed)
#
#
# * [Statistik](#common_statistics)
#
#
# * [Korrelationen](#correlations)
#
#
# * [Anova Varianz](#ANOVA)
#     * [Anova Heatmap](#ANOVA_HEATMAP)

# %%
import glob
import pandas as pd
import numpy as np
from scipy import stats
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from pandas.plotting import scatter_matrix
from currency_converter import CurrencyConverter
from datetime import date
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
na_values = ['nan', 'N/A', 'NaN', 'NaT']

# %%
df = pd.read_csv('resources/accident_data.csv', sep=";", na_values=na_values, index_col=False, dtype = {"STATE" : "str", "TYPE" : "str", "TYPEQ" : "str", "TYPTRK" : "str", "WEATHER" : "str", "VISIBLTY" : "str", "TONS" : "float64"})
df.shape[0]
# Out:
# /Users/julianjetz/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 66389

# %%
pd.set_option('display.max_colwidth', 500)

# %%
a4_dims = (16, 10)
sns.set(style="whitegrid")

# %% [markdown]
# ### Boxenplots und Histogramme der Schäden (mit Ausreißern) <a class="anchor" id="ausreißer"></a>

# %% [markdown]
# #### Boxenplot Infrastrukturschaden

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
#plt.yscale("log")
ax.set_ylabels("Infrastrukturschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Boxplot_Infrastrukturschaden.png')

# %% [markdown]
# #### Histogramm Infrastrukturschaden (ohne Ausreißer)¶

# %%
df['INFRASTRUCTURE_DMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Infrastrukturschaden.png')

# %% [markdown]
# #### Boxenplot Materialschaden

# %%
ax = sns.catplot(y='EQPDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Boxplot_Materialschaden.png')

# %% [markdown]
# #### Histogramm Materialschaden

# %%
df['EQPDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Materialschaden.png')

# %% [markdown]
# #### Boxenplot Streckenschaden

# %%
ax = sns.catplot(y='TRKDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Streckenschaden in Dollar")
ax.set_xlabels("Alle Unfälle")
plt.savefig('Images/Boxplot_Streckenschaden.png')

# %% [markdown]
# #### Histogramm Materialschaden

# %%
df['TRKDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Streckenschaden.png')

# %% [markdown]
# #### Entfernung der Ausreißer <a class="anchor" id="ausreißer-delete"></a>

# %%
df.shape[0]
# Out:
# 66389

# %%
std_dev = 3.5
df = df[(np.abs(stats.zscore(df[['LOCOMOTIVES1','LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2','LOADF2', 'EMPTYF2', 'INFRASTRUCTURE_DMG']])) < float(std_dev)).all(axis=1)]

# %%
df.shape[0]
# Out:
# 59908

# %% [markdown]
# ### Häufigkeiten <a class="anchor" id="frequencies"></a>

# %%
def bar_values(ax):
    for p in ax.patches:
        ax.annotate(format(p.get_height(), ',d').replace(",","."), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
    sns.despine()
    return ax

# %% [markdown]
# #### Häufigkeiten Zugart <a class="anchor" id="freq-zugart"></a>

# %%
#fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.countplot(x="EQUIPMENT_TYPE", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Zugart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90, horizontalalignment='right')
plt.savefig('Images/Count_Zugart.png')

# %% [markdown]
# #### Häufigkeiten Unfallart <a class="anchor" id="freq-unfallart"></a>

# %%
ax = sns.countplot(x="ACCIDENT_TYPE", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=25, horizontalalignment='right')
plt.savefig('Images/Count_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Streckenart <a class="anchor" id="freq-streckenart"></a>

# %%
ax = sns.countplot(x="TYPTRK", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Streckenart")
ax.set_xticklabels(ax.get_xticklabels(),rotation=25, horizontalalignment='right')
plt.savefig('Images/Count_Streckenart.png')

# %% [markdown]
# #### Häufigkeiten Unfallursache <a class="anchor" id="freq-cause"></a>

# %%
#fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.countplot(x="ACCCAUSE_LVL2", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallursache")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')
plt.savefig('Images/Count_Unfallursache.png')

# %% [markdown]
# #### Häufigkeiten Unfallursache Lvl 1 (eingefärbt nach Unfallursache Lvl2 und gruppiert nach Unfallart) <a class="anchor" id="freq-cause_lvl1_lvl2_unfallart"></a>

# %%
bp = sns.catplot(y="ACCCAUSE_LVL1", hue="ACCCAUSE_LVL2", data=df, kind="count", col="ACCIDENT_TYPE", col_wrap=2, height=14, aspect=0.7, legend=False, legend_out=False)
bp.set_xlabels('Anzahl', fontsize=12)
bp.set_ylabels('Unfallursache', fontsize=12)
for ax in bp.axes:
    ax.legend(bbox_to_anchor=(0, 1.08), loc='upper left', ncol=3, frameon=False, fontsize=10)
    ax.grid(axis='y')
    #plt.setp(ax.get_xticklabels(), visible=True)
    #ax.set_xticks([0,1,2,3,4,5], ax.get_xticklabels())
plt.subplots_adjust(wspace=0.1, hspace=0.15)
plt.savefig('Images/Count_Unfallursache_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Unfallschwere <a class="anchor" id="freq-acctype"></a>

# %%
ax = sns.countplot(x="ACCTYPE", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Unfallschwere")
plt.savefig('Images/Count_Unfallschwere.png')

# %% [markdown]
# #### Häufigkeiten Unfallschwere (nach Zugart)  <a class="anchor" id="freq-acctype_cause"></a>

# %%
cp = sns.catplot(x="ACCTYPE", data=df, col="EQUIPMENT_TYPE", palette="colorblind", kind="count", col_wrap=4, height=3, aspect=1)
cp.set_xlabels('Unfallschwere', fontsize=12)
cp.set_ylabels('Anzahl', fontsize=12)

# %% [markdown]
# #### Häufigkeiten Wetter <a class="anchor" id="freq-wetter"></a>

# %%
ax = sns.countplot(x="WEATHER", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Wetter")
plt.savefig('Images/Count_Wetter.png')

# %% [markdown]
# #### Häufigkeiten Jahreszeit <a class="anchor" id="freq-jahreszeit"></a>

# %%
ax = sns.countplot(x="Jahreszeit", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Jahreszeit")
plt.savefig('Images/Count_Jahreszeit.png')

# %% [markdown]
# #### Häufigkeiten Jahr <a class="anchor" id="freq-jahr"></a>

# %%
bp = sns.catplot(x="YEAR4", data=df, kind="count", height=10, aspect=1.5, palette="colorblind")
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Anzahl', fontsize=12)
plt.savefig('Images/Count_Jahr.png')

# %% [markdown]
# #### Häufigkeiten Jahr (nach Unfallart) <a class="anchor" id="freq-jahr_unfallart"></a>

# %%
bp = sns.catplot(x="YEAR4", data=df, kind="count", col="ACCIDENT_TYPE", col_wrap=2, height=5, aspect=1.5, palette="colorblind")
bp.set_ylabels('Jahr', fontsize=12)
bp.set_xlabels('Anzahl', fontsize=12)
for x in bp.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
plt.savefig('Images/Count_Jahr_Unfallart.png')

# %% [markdown]
# #### Häufigkeiten Temperatur <a class="anchor" id="freq-temp"></a>

# %%
temp_order = ["Sehr Kalt (-45° - 30,01° C)", "Kalt (-30° - 0,01° C)", "Moderat (0° bis 19,99° C)", "Warm (20° bis 31,99° C)", "Heiß (>= 32° C)"]
ax = sns.countplot(x="TEMP_CLUSTER", data=df, palette="colorblind", order=temp_order)
ax = bar_values(ax)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')
ax.set_xlabel("Temperatur")
plt.savefig('Images/Count_Temperatur.png')

# %% [markdown]
# #### Häufigkeiten Temperatur (nach Unfallursache) <a class="anchor" id="freq-temp_cause"></a>

# %%
ax = sns.catplot(x="TEMP_CLUSTER", hue="ACCCAUSE_LVL2", kind="count", data=df, palette='colorblind', order=temp_order, legend=False, height=15, aspect=1.5)
for x in ax.axes.flat:
    x.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=3, frameon=False, fontsize=20)
    for label in x.get_xticklabels():
        label.set_rotation(-90)   
ax.set_xlabels("Temperatur")
plt.savefig('Images/Count_Temperatur_Unfallursache.png')

# %% [markdown]
# #### Häufigkeiten Sichtbarkeit <a class="anchor" id="freq-vis"></a>

# %%
vis_order = ["Dawn", "Day", "Dusk", "Dark"]
ax = sns.countplot(x="VISIBLTY", data=df, palette="colorblind", order=vis_order)
ax = bar_values(ax)
ax.set_xlabel("Sichtbarkeit")
plt.savefig('Images/Count_Sichtbarkeit.png')

# %% [markdown]
# #### Häufigkeiten zu hohe Zuggeschwindigkeit <a class="anchor" id="freq-speed"></a>

# %%
ax = sns.countplot(x="SPD_TOO_HIGH", data=df, palette="colorblind")
ax = bar_values(ax)
ax.set_xlabel("Zuggeschwindigkeit zu hoch")
plt.savefig('Images/Count_Zug_zu_schnell.png')

# %% [markdown]
# ### Verteilungstabellen <a class="anchor" id="tables"></a>

# %% [markdown]
# #### Verteilungstabelle Zugart nach Unfallart <a class="anchor" id="tables_eqtype_type"></a>

# %%
format_dict = {'Commuter Train':'{:.2f}%', 'Cut of Cars': '{:.2f}%', 'Freight Train': '{:.2f}%', 
               'Locomotive': '{:.2f}%', 'Passenger Train': '{:.2f}%', 'Single Car': '{:.2f}%', 'Work Train': '{:.2f}%',
               'Yard/Switching': '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["ACCIDENT_TYPE"],  columns=df["EQUIPMENT_TYPE"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f4e909c6_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >EQUIPMENT_TYPE</th>        <th class="col_heading level0 col0" >Commuter Train</th>        <th class="col_heading level0 col1" >Cut of Cars</th>        <th class="col_heading level0 col2" >Freight Train</th>        <th class="col_heading level0 col3" >Locomotive</th>        <th class="col_heading level0 col4" >Passenger Train</th>        <th class="col_heading level0 col5" >Single Car</th>        <th class="col_heading level0 col6" >Work Train</th>        <th class="col_heading level0 col7" >Yard/Switching</th>        <th class="col_heading level0 col8" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f4e909c6_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Collision</th>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >18.79%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >9.53%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >3.55%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row0_col3" class="data row0 col3" >8.09%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row0_col4" class="data row0 col4" >27.71%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row0_col5" class="data row0 col5" >15.51%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row0_col6" class="data row0 col6" >15.07%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row0_col7" class="data row0 col7" >4.08%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row0_col8" class="data row0 col8" >4.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4e909c6_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Crossing</th>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >57.23%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >0.82%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >10.76%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row1_col3" class="data row1 col3" >7.72%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row1_col4" class="data row1 col4" >45.86%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row1_col5" class="data row1 col5" >9.85%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row1_col6" class="data row1 col6" >12.67%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row1_col7" class="data row1 col7" >0.62%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row1_col8" class="data row1 col8" >8.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4e909c6_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Derailment</th>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >17.05%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >85.75%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >84.32%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row2_col3" class="data row2 col3" >81.76%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row2_col4" class="data row2 col4" >18.21%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row2_col5" class="data row2 col5" >53.67%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row2_col6" class="data row2 col6" >68.66%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row2_col7" class="data row2 col7" >95.18%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row2_col8" class="data row2 col8" >84.78%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4e909c6_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Fire / Violent Rupture / Explosive Detonation</th>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >6.94%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >3.90%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >1.37%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row3_col3" class="data row3 col3" >2.43%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row3_col4" class="data row3 col4" >8.22%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row3_col5" class="data row3 col5" >20.96%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row3_col6" class="data row3 col6" >3.60%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row3_col7" class="data row3 col7" >0.12%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row3_col8" class="data row3 col8" >1.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4e909c6_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#                         <td id="T_f4e909c6_d12a_11ea_88f6_acde48001122row4_col8" class="data row4 col8" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallart nach Zugart <a class="anchor" id="tables_type_eqtype"></a>

# %%
format_dict = {'Collision':'{:.2f}%', 'Crossing': '{:.2f}%', 'Derailment': '{:.2f}%', 
               'Fire / Violent RuptureViolent rupture / Explosive Detonation': '{:.2f}%', 'All': '{:.2f}%'}
freq_tab_eqtype_type = pd.crosstab(index=df["EQUIPMENT_TYPE"],  columns=df["ACCIDENT_TYPE"], margins=True)
(freq_tab_eqtype_type/freq_tab_eqtype_type.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f4f3f656_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="col_heading level0 col0" >Collision</th>        <th class="col_heading level0 col1" >Crossing</th>        <th class="col_heading level0 col2" >Derailment</th>        <th class="col_heading level0 col3" >Fire / Violent Rupture / Explosive Detonation</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="index_name level0" >EQUIPMENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f4f3f656_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Commuter Train</th>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >2.21%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >3.75%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >0.12%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row0_col3" class="data row0 col3" >2.68757</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row0_col4" class="data row0 col4" >0.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4f3f656_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Cut of Cars</th>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >3.57%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >0.17%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >1.86%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row1_col3" class="data row1 col3" >4.81523</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row1_col4" class="data row1 col4" >1.84%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4f3f656_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Freight Train</th>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >44.39%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >74.82%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >61.03%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row2_col3" class="data row2 col3" >56.439</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row2_col4" class="data row2 col4" >61.36%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4f3f656_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Locomotive</th>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >5.10%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >2.71%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >2.98%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row3_col3" class="data row3 col3" >5.03919</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row3_col4" class="data row3 col4" >3.09%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4f3f656_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >Passenger Train</th>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >15.47%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >14.25%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >0.59%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row4_col3" class="data row4 col3" >15.1176</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row4_col4" class="data row4 col4" >2.74%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4f3f656_d12a_11ea_88f6_acde48001122level0_row5" class="row_heading level0 row5" >Single Car</th>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row5_col0" class="data row5 col0" >2.52%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row5_col1" class="data row5 col1" >0.89%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row5_col2" class="data row5 col2" >0.50%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row5_col3" class="data row5 col3" >11.1982</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row5_col4" class="data row5 col4" >0.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4f3f656_d12a_11ea_88f6_acde48001122level0_row6" class="row_heading level0 row6" >Work Train</th>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row6_col0" class="data row6 col0" >2.99%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row6_col1" class="data row6 col1" >1.40%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row6_col2" class="data row6 col2" >0.79%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row6_col3" class="data row6 col3" >2.35162</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row6_col4" class="data row6 col4" >0.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4f3f656_d12a_11ea_88f6_acde48001122level0_row7" class="row_heading level0 row7" >Yard/Switching</th>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row7_col0" class="data row7 col0" >23.76%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row7_col1" class="data row7 col1" >2.02%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row7_col2" class="data row7 col2" >32.13%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row7_col3" class="data row7 col3" >2.35162</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row7_col4" class="data row7 col4" >28.62%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4f3f656_d12a_11ea_88f6_acde48001122level0_row8" class="row_heading level0 row8" >All</th>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row8_col0" class="data row8 col0" >100.00%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row8_col1" class="data row8 col1" >100.00%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row8_col2" class="data row8 col2" >100.00%</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row8_col3" class="data row8 col3" >100</td>
#                         <td id="T_f4f3f656_d12a_11ea_88f6_acde48001122row8_col4" class="data row8 col4" >100.00%</td>
#             </tr>
#     </tbody></table>

# %%
format_dict = {'Environmental Conditions':'{:.2f}%', 'Human Factors': '{:.2f}%', 'Loading': '{:.2f}%', 
               'Mechanical and Electrical Failures': '{:.2f}%', 'Miscellaneous Causes': '{:.2f}%', 
               'Signal and Communication': '{:.2f}%', 'Track, Roadbed and Structures': '{:.2f}%',
               'All': '{:.2f}%'}

# %% [markdown]
# #### Verteilungstabelle Unfallart  nach Unfallursache <a class="anchor" id="tables_zugart_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["ACCIDENT_TYPE"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f50071d8_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f50071d8_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Collision</th>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >8.01%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >9.57%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >1.53%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row0_col3" class="data row0 col3" >2.56%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row0_col4" class="data row0 col4" >17.29%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row0_col5" class="data row0 col5" >6.46%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row0_col6" class="data row0 col6" >0.40%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row0_col7" class="data row0 col7" >4.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_f50071d8_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Crossing</th>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >0.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >0.23%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >85.08%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row1_col3" class="data row1 col3" >0.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row1_col4" class="data row1 col4" >0.49%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row1_col5" class="data row1 col5" >0.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row1_col6" class="data row1 col6" >0.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row1_col7" class="data row1 col7" >8.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_f50071d8_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Derailment</th>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >91.65%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >90.11%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >13.33%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row2_col3" class="data row2 col3" >91.12%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row2_col4" class="data row2 col4" >76.14%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row2_col5" class="data row2 col5" >93.54%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row2_col6" class="data row2 col6" >99.56%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row2_col7" class="data row2 col7" >84.78%</td>
#             </tr>
#             <tr>
#                         <th id="T_f50071d8_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Fire / Violent Rupture / Explosive Detonation</th>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >0.34%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >0.09%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >0.07%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row3_col3" class="data row3 col3" >6.32%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row3_col4" class="data row3 col4" >6.08%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row3_col5" class="data row3 col5" >0.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row3_col6" class="data row3 col6" >0.04%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row3_col7" class="data row3 col7" >1.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_f50071d8_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_f50071d8_d12a_11ea_88f6_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Zugart  <a class="anchor" id="tables_zugart_typtrk"></a>

# %%
freq_tab = pd.crosstab(index=df["TYPTRK"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f50bee14_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >TYPTRK</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f50bee14_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Industry</th>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >20.59%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >9.50%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >2.54%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row0_col3" class="data row0 col3" >2.96%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row0_col4" class="data row0 col4" >9.35%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row0_col5" class="data row0 col5" >2.32%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row0_col6" class="data row0 col6" >14.13%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row0_col7" class="data row0 col7" >9.76%</td>
#             </tr>
#             <tr>
#                         <th id="T_f50bee14_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Main</th>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >44.74%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >21.00%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >90.89%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row1_col3" class="data row1 col3" >67.46%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row1_col4" class="data row1 col4" >40.47%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row1_col5" class="data row1 col5" >11.42%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row1_col6" class="data row1 col6" >31.41%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row1_col7" class="data row1 col7" >40.66%</td>
#             </tr>
#             <tr>
#                         <th id="T_f50bee14_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Siding</th>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >5.15%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >4.08%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >0.86%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row2_col3" class="data row2 col3" >3.19%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row2_col4" class="data row2 col4" >3.32%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row2_col5" class="data row2 col5" >1.66%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row2_col6" class="data row2 col6" >4.89%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row2_col7" class="data row2 col7" >3.86%</td>
#             </tr>
#             <tr>
#                         <th id="T_f50bee14_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Yard</th>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >29.52%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >65.43%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >5.70%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row3_col3" class="data row3 col3" >26.38%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row3_col4" class="data row3 col4" >46.86%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row3_col5" class="data row3 col5" >84.60%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row3_col6" class="data row3 col6" >49.56%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row3_col7" class="data row3 col7" >45.72%</td>
#             </tr>
#             <tr>
#                         <th id="T_f50bee14_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_f50bee14_d12a_11ea_88f6_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach State <a class="anchor" id="tables_state_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["STATE"],  columns=df["ACCCAUSE_LVL2"], margins=True)
((freq_tab/freq_tab.loc["All"]*100).sort_values(by=['All'], ascending=False)).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f5182f62_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >STATE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5182f62_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >All</th>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >100.00%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >100.00%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >100.00%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row0_col3" class="data row0 col3" >100.00%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row0_col4" class="data row0 col4" >100.00%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row0_col5" class="data row0 col5" >100.00%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row0_col6" class="data row0 col6" >100.00%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row0_col7" class="data row0 col7" >100.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5182f62_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Texas</th>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >6.18%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >11.30%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >15.35%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row1_col3" class="data row1 col3" >10.35%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row1_col4" class="data row1 col4" >10.37%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row1_col5" class="data row1 col5" >11.26%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row1_col6" class="data row1 col6" >12.47%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row1_col7" class="data row1 col7" >11.87%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5182f62_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Illinois</th>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >6.98%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >11.18%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >5.51%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row2_col3" class="data row2 col3" >7.24%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row2_col4" class="data row2 col4" >8.77%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row2_col5" class="data row2 col5" >10.10%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row2_col6" class="data row2 col6" >8.16%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row2_col7" class="data row2 col7" >8.59%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5182f62_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Kalifornien</th>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >4.23%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >6.63%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >8.52%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row3_col3" class="data row3 col3" >4.77%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row3_col4" class="data row3 col4" >9.37%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row3_col5" class="data row3 col5" >7.45%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row3_col6" class="data row3 col6" >5.10%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row3_col7" class="data row3 col7" >6.21%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5182f62_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >Ohio</th>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >3.78%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >3.45%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >2.62%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row4_col3" class="data row4 col3" >3.00%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row4_col4" class="data row4 col4" >2.99%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row4_col5" class="data row4 col5" >5.30%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row4_col6" class="data row4 col6" >3.47%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row4_col7" class="data row4 col7" >3.29%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5182f62_d12a_11ea_88f6_acde48001122level0_row5" class="row_heading level0 row5" >Kansas</th>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row5_col0" class="data row5 col0" >4.46%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row5_col1" class="data row5 col1" >3.04%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row5_col2" class="data row5 col2" >2.74%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row5_col3" class="data row5 col3" >3.22%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row5_col4" class="data row5 col4" >2.30%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row5_col5" class="data row5 col5" >2.81%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row5_col6" class="data row5 col6" >3.55%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row5_col7" class="data row5 col7" >3.18%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5182f62_d12a_11ea_88f6_acde48001122level0_row6" class="row_heading level0 row6" >Louisiana</th>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row6_col0" class="data row6 col0" >0.92%</td>
#                         <td id="T_f5182f62_d12a_11ea_88f6_acde48001122row6_col1" class="data row6 col

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Wetter <a class="anchor" id="tables_weather_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["WEATHER"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f5258f9a_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >WEATHER</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5258f9a_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Clear</th>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >39.24%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >67.45%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >71.00%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row0_col3" class="data row0 col3" >65.80%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row0_col4" class="data row0 col4" >66.99%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row0_col5" class="data row0 col5" >62.58%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row0_col6" class="data row0 col6" >64.51%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row0_col7" class="data row0 col7" >65.94%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5258f9a_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Cloudy</th>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >22.31%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >22.71%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >20.23%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row1_col3" class="data row1 col3" >24.57%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row1_col4" class="data row1 col4" >23.23%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row1_col5" class="data row1 col5" >25.99%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row1_col6" class="data row1 col6" >25.39%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row1_col7" class="data row1 col7" >23.83%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5258f9a_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Fog</th>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >1.26%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >1.24%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >1.78%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row2_col3" class="data row2 col3" >1.39%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row2_col4" class="data row2 col4" >1.39%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row2_col5" class="data row2 col5" >0.66%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row2_col6" class="data row2 col6" >0.93%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row2_col7" class="data row2 col7" >1.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5258f9a_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Rain</th>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >23.34%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >6.43%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >5.13%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row3_col3" class="data row3 col3" >5.21%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row3_col4" class="data row3 col4" >6.58%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row3_col5" class="data row3 col5" >7.78%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row3_col6" class="data row3 col6" >6.98%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row3_col7" class="data row3 col7" >6.62%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5258f9a_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >Sleet</th>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >0.57%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >0.18%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >0.23%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row4_col3" class="data row4 col3" >0.16%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row4_col4" class="data row4 col4" >0.12%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row4_col5" class="data row4 col5" >0.17%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row4_col6" class="data row4 col6" >0.23%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row4_col7" class="data row4 col7" >0.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5258f9a_d12a_11ea_88f6_acde48001122level0_row5" class="row_heading level0 row5" >Snow</th>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row5_col0" class="data row5 col0" >13.27%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row5_col1" class="data row5 col1" >1.99%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row5_col2" class="data row5 col2" >1.63%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row5_col3" class="data row5 col3" >2.87%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row5_col4" class="data row5 col4" >1.69%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row5_col5" class="data row5 col5" >2.81%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row5_col6" class="data row5 col6" >1.97%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row5_col7" class="data row5 col7" >2.21%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5258f9a_d12a_11ea_88f6_acde48001122level0_row6" class="row_heading level0 row6" >All</th>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row6_col0" class="data row6 col0" >100.00%</td>
#                         <td id="T_f5258f9a_d12a_11ea_88f6_acde48001122row6_col1" class="data row6 col1" >100.00%</td>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Jahreszeit <a class="anchor" id="tables_jahreszeit_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["Jahreszeit"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f5313700_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >Jahreszeit</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5313700_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Frühling</th>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >19.45%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >25.45%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >23.84%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row0_col3" class="data row0 col3" >25.88%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row0_col4" class="data row0 col4" >26.23%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row0_col5" class="data row0 col5" >24.50%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row0_col6" class="data row0 col6" >24.66%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row0_col7" class="data row0 col7" >25.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5313700_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Herbst</th>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >15.90%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >23.69%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >25.19%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row1_col3" class="data row1 col3" >21.81%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row1_col4" class="data row1 col4" >21.72%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row1_col5" class="data row1 col5" >22.52%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row1_col6" class="data row1 col6" >23.56%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row1_col7" class="data row1 col7" >23.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5313700_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Sommer</th>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >19.34%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >27.04%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >27.53%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row2_col3" class="data row2 col3" >25.69%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row2_col4" class="data row2 col4" >27.78%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row2_col5" class="data row2 col5" >25.66%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row2_col6" class="data row2 col6" >26.47%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row2_col7" class="data row2 col7" >26.63%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5313700_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Winter</th>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >45.31%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >23.82%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >23.44%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row3_col3" class="data row3 col3" >26.62%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row3_col4" class="data row3 col4" >24.27%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row3_col5" class="data row3 col5" >27.32%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row3_col6" class="data row3 col6" >25.31%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row3_col7" class="data row3 col7" >25.13%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5313700_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_f5313700_d12a_11ea_88f6_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Temperatur <a class="anchor" id="tables_cause_temp"></a>

# %%
freq_tab = pd.crosstab(index=df["TEMP_CLUSTER"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f53d40a4_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >TEMP_CLUSTER</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f53d40a4_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Heiß (>= 32° C)</th>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >3.55%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >5.33%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >9.16%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row0_col3" class="data row0 col3" >5.69%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row0_col4" class="data row0 col4" >6.11%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row0_col5" class="data row0 col5" >4.47%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row0_col6" class="data row0 col6" >8.42%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row0_col7" class="data row0 col7" >7.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_f53d40a4_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Kalt (-30° - 0,01° C)</th>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >36.38%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >11.78%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >9.07%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row1_col3" class="data row1 col3" >16.44%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row1_col4" class="data row1 col4" >10.51%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row1_col5" class="data row1 col5" >12.25%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row1_col6" class="data row1 col6" >13.28%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row1_col7" class="data row1 col7" >12.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_f53d40a4_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Moderat (0° bis 19,99° C)</th>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >36.38%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >49.13%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >42.13%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row2_col3" class="data row2 col3" >47.34%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row2_col4" class="data row2 col4" >49.02%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row2_col5" class="data row2 col5" >49.34%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row2_col6" class="data row2 col6" >46.90%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row2_col7" class="data row2 col7" >47.11%</td>
#             </tr>
#             <tr>
#                         <th id="T_f53d40a4_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Sehr Kalt (-45° - 30,01° C)</th>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >0.57%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >0.05%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >0.00%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row3_col3" class="data row3 col3" >0.09%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row3_col4" class="data row3 col4" >0.02%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row3_col5" class="data row3 col5" >0.00%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row3_col6" class="data row3 col6" >0.03%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row3_col7" class="data row3 col7" >0.05%</td>
#             </tr>
#             <tr>
#                         <th id="T_f53d40a4_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >Warm (20° bis 31,99° C)</th>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >23.11%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >33.70%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >39.64%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row4_col3" class="data row4 col3" >30.44%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row4_col4" class="data row4 col4" >34.33%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row4_col5" class="data row4 col5" >33.94%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row4_col6" class="data row4 col6" >31.36%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row4_col7" class="data row4 col7" >32.87%</td>
#             </tr>
#             <tr>
#                         <th id="T_f53d40a4_d12a_11ea_88f6_acde48001122level0_row5" class="row_heading level0 row5" >All</th>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row5_col0" class="data row5 col0" >100.00%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row5_col1" class="data row5 col1" >100.00%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row5_col2" class="data row5 col2" >100.00%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row5_col3" class="data row5 col3" >100.00%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row5_col4" class="data row5 col4" >100.00%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row5_col5" class="data row5 col5" >100.00%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row5_col6" class="data row5 col6" >100.00%</td>
#                         <td id="T_f53d40a4_d12a_11ea_88f6_acde48001122row5_col7" class="data row5 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Unfallursache nach Sichtbarkeit <a class="anchor" id="tables_vis_cause"></a>

# %%
freq_tab = pd.crosstab(index=df["VISIBLTY"],  columns=df["ACCCAUSE_LVL2"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f54904f2_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="col_heading level0 col0" >Environmental Conditions</th>        <th class="col_heading level0 col1" >Human Factors</th>        <th class="col_heading level0 col2" >Loading</th>        <th class="col_heading level0 col3" >Mechanical and Electrical Failures</th>        <th class="col_heading level0 col4" >Miscellaneous Causes</th>        <th class="col_heading level0 col5" >Signal and Communication</th>        <th class="col_heading level0 col6" >Track, Roadbed and Structures</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >VISIBLTY</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f54904f2_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Dark</th>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >46.00%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >45.38%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >21.20%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row0_col3" class="data row0 col3" >42.05%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row0_col4" class="data row0 col4" >42.45%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row0_col5" class="data row0 col5" >42.22%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row0_col6" class="data row0 col6" >37.83%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row0_col7" class="data row0 col7" >39.22%</td>
#             </tr>
#             <tr>
#                         <th id="T_f54904f2_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Dawn</th>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >3.55%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >4.93%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >4.61%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row1_col3" class="data row1 col3" >5.28%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row1_col4" class="data row1 col4" >4.87%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row1_col5" class="data row1 col5" >5.30%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row1_col6" class="data row1 col6" >4.27%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row1_col7" class="data row1 col7" >4.67%</td>
#             </tr>
#             <tr>
#                         <th id="T_f54904f2_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Day</th>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >43.59%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >44.22%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >70.38%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row2_col3" class="data row2 col3" >47.73%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row2_col4" class="data row2 col4" >46.60%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row2_col5" class="data row2 col5" >45.53%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row2_col6" class="data row2 col6" >53.10%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row2_col7" class="data row2 col7" >51.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_f54904f2_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Dusk</th>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >6.86%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >5.47%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >3.81%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row3_col3" class="data row3 col3" >4.94%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row3_col4" class="data row3 col4" >6.08%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row3_col5" class="data row3 col5" >6.95%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row3_col6" class="data row3 col6" >4.79%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row3_col7" class="data row3 col7" >5.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_f54904f2_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row4_col4" class="data row4 col4" >100.00%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row4_col5" class="data row4 col5" >100.00%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row4_col6" class="data row4 col6" >100.00%</td>
#                         <td id="T_f54904f2_d12a_11ea_88f6_acde48001122row4_col7" class="data row4 col7" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Sichtbarkeit nach Unfallursache  <a class="anchor" id="tables_cause_vis"></a>

# %%
format_dict = {'Dark':'{:.2f}%', 'Dawn': '{:.2f}%', 'Day': '{:.2f}%', 
               'Dusk': '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["ACCCAUSE_LVL2"],  columns=df["VISIBLTY"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f554da70_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >VISIBLTY</th>        <th class="col_heading level0 col0" >Dark</th>        <th class="col_heading level0 col1" >Dawn</th>        <th class="col_heading level0 col2" >Day</th>        <th class="col_heading level0 col3" >Dusk</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCCAUSE_LVL2</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f554da70_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Environmental Conditions</th>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >1.71%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >1.11%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >1.25%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row0_col3" class="data row0 col3" >1.98%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row0_col4" class="data row0 col4" >1.46%</td>
#             </tr>
#             <tr>
#                         <th id="T_f554da70_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Human Factors</th>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >29.29%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >26.74%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >21.93%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row1_col3" class="data row1 col3" >27.36%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row1_col4" class="data row1 col4" >25.31%</td>
#             </tr>
#             <tr>
#                         <th id="T_f554da70_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Loading</th>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >5.54%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >10.12%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >14.12%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row2_col3" class="data row2 col3" >7.72%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row2_col4" class="data row2 col4" >10.25%</td>
#             </tr>
#             <tr>
#                         <th id="T_f554da70_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Mechanical and Electrical Failures</th>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >14.68%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >15.48%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >12.80%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row3_col3" class="data row3 col3" >13.37%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row3_col4" class="data row3 col4" >13.69%</td>
#             </tr>
#             <tr>
#                         <th id="T_f554da70_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >Miscellaneous Causes</th>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >10.28%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >9.90%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >8.67%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row4_col3" class="data row4 col3" >11.42%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row4_col4" class="data row4 col4" >9.50%</td>
#             </tr>
#             <tr>
#                         <th id="T_f554da70_d12a_11ea_88f6_acde48001122level0_row5" class="row_heading level0 row5" >Signal and Communication</th>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row5_col0" class="data row5 col0" >1.09%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row5_col1" class="data row5 col1" >1.14%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row5_col2" class="data row5 col2" >0.90%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row5_col3" class="data row5 col3" >1.39%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row5_col4" class="data row5 col4" >1.01%</td>
#             </tr>
#             <tr>
#                         <th id="T_f554da70_d12a_11ea_88f6_acde48001122level0_row6" class="row_heading level0 row6" >Track, Roadbed and Structures</th>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row6_col0" class="data row6 col0" >37.41%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row6_col1" class="data row6 col1" >35.50%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row6_col2" class="data row6 col2" >40.34%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row6_col3" class="data row6 col3" >36.77%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row6_col4" class="data row6 col4" >38.78%</td>
#             </tr>
#             <tr>
#                         <th id="T_f554da70_d12a_11ea_88f6_acde48001122level0_row7" class="row_heading level0 row7" >All</th>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row7_col0" class="data row7 col0" >100.00%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row7_col1" class="data row7 col1" >100.00%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row7_col2" class="data row7 col2" >100.00%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row7_col3" class="data row7 col3" >100.00%</td>
#                         <td id="T_f554da70_d12a_11ea_88f6_acde48001122row7_col4" class="data row7 col4" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Geschwindigkeitsüberschreitung nach Unfallart  <a class="anchor" id="tables_speed_acctype"></a>

# %%
format_dict = {False:'{:.2f}%', True: '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["ACCIDENT_TYPE"],  columns=df["SPD_TOO_HIGH"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f55f118e_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >SPD_TOO_HIGH</th>        <th class="col_heading level0 col0" >False</th>        <th class="col_heading level0 col1" >True</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >ACCIDENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f55f118e_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Collision</th>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >4.87%</td>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >6.14%</td>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >4.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_f55f118e_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Crossing</th>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >8.90%</td>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >6.65%</td>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >8.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_f55f118e_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Derailment</th>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >84.72%</td>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >86.56%</td>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >84.78%</td>
#             </tr>
#             <tr>
#                         <th id="T_f55f118e_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Fire / Violent Rupture / Explosive Detonation</th>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >1.52%</td>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >0.65%</td>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >1.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_f55f118e_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_f55f118e_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Geschwindigkeitsüberschreitung nach Streckenart  <a class="anchor" id="tables_speed_typtrk"></a>

# %%
format_dict = {False:'{:.2f}%', True: '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["TYPTRK"],  columns=df["SPD_TOO_HIGH"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f5685802_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >SPD_TOO_HIGH</th>        <th class="col_heading level0 col0" >False</th>        <th class="col_heading level0 col1" >True</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >TYPTRK</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5685802_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Industry</th>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >9.87%</td>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >6.75%</td>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >9.76%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5685802_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Main</th>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >39.95%</td>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >61.33%</td>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >40.66%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5685802_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Siding</th>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >3.84%</td>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >4.63%</td>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >3.86%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5685802_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Yard</th>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >46.35%</td>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >27.29%</td>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >45.72%</td>
#             </tr>
#             <tr>
#                         <th id="T_f5685802_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >All</th>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_f5685802_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Verteilungstabelle Geschwindigkeitsüberschreitung nach Zugart  <a class="anchor" id="tables_speed_eqtype"></a>

# %%
format_dict = {False:'{:.2f}%', True: '{:.2f}%', 'All': '{:.2f}%'}
freq_tab = pd.crosstab(index=df["EQUIPMENT_TYPE"],  columns=df["SPD_TOO_HIGH"], margins=True)
(freq_tab/freq_tab.loc["All"]*100).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f571bc94_d12a_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="index_name level0" >SPD_TOO_HIGH</th>        <th class="col_heading level0 col0" >False</th>        <th class="col_heading level0 col1" >True</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >EQUIPMENT_TYPE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f571bc94_d12a_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Commuter Train</th>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >0.59%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >0.25%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >0.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_f571bc94_d12a_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Cut of Cars</th>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >1.77%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >3.73%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >1.84%</td>
#             </tr>
#             <tr>
#                         <th id="T_f571bc94_d12a_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Freight Train</th>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >60.85%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >76.28%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >61.36%</td>
#             </tr>
#             <tr>
#                         <th id="T_f571bc94_d12a_11ea_88f6_acde48001122level0_row3" class="row_heading level0 row3" >Locomotive</th>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row3_col0" class="data row3 col0" >3.12%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row3_col1" class="data row3 col1" >2.37%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row3_col2" class="data row3 col2" >3.09%</td>
#             </tr>
#             <tr>
#                         <th id="T_f571bc94_d12a_11ea_88f6_acde48001122level0_row4" class="row_heading level0 row4" >Passenger Train</th>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row4_col0" class="data row4 col0" >2.76%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row4_col1" class="data row4 col1" >2.11%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row4_col2" class="data row4 col2" >2.74%</td>
#             </tr>
#             <tr>
#                         <th id="T_f571bc94_d12a_11ea_88f6_acde48001122level0_row5" class="row_heading level0 row5" >Single Car</th>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row5_col0" class="data row5 col0" >0.76%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row5_col1" class="data row5 col1" >1.76%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row5_col2" class="data row5 col2" >0.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_f571bc94_d12a_11ea_88f6_acde48001122level0_row6" class="row_heading level0 row6" >Work Train</th>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row6_col0" class="data row6 col0" >0.98%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row6_col1" class="data row6 col1" >0.81%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row6_col2" class="data row6 col2" >0.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_f571bc94_d12a_11ea_88f6_acde48001122level0_row7" class="row_heading level0 row7" >Yard/Switching</th>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row7_col0" class="data row7 col0" >29.16%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row7_col1" class="data row7 col1" >12.69%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row7_col2" class="data row7 col2" >28.62%</td>
#             </tr>
#             <tr>
#                         <th id="T_f571bc94_d12a_11ea_88f6_acde48001122level0_row8" class="row_heading level0 row8" >All</th>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row8_col0" class="data row8 col0" >100.00%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row8_col1" class="data row8 col1" >100.00%</td>
#                         <td id="T_f571bc94_d12a_11ea_88f6_acde48001122row8_col2" class="data row8 col2" >100.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Boxenplots und Histogramme <a class="anchor" id="boxenplots"></a>
#
# [Hadley Wickham: Letter-value plots: Boxplots for large data](https://doi.org/10.1080/10618600.2017.1305277)

# %% [markdown]
# #### Boxenplot Infrastrukturschaden (ohne Ausreißer) <a class="anchor" id="infrastrukturdmg"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
plt.yscale("log")
ax.set_ylabels("Infrastrukturschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Infrastrukturschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Infrastrukturschaden (ohne Ausreißer)¶

# %%
df['INFRASTRUCTURE_DMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Infrastrukturschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Materialschaden (ohne Ausreißer) <a class="anchor" id="EQPDMG"></a>

# %%
ax = sns.catplot(y='EQPDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
plt.yscale("log")
ax.set_ylabels("Materialschaden in Dollar (Log-Skalierung)")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Materialschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Materialschaden (ohne Ausreißer)¶

# %%
df['EQPDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Materialschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Streckenchaden (ohne Ausreißer) <a class="anchor" id="TRKDMG"></a>

# %%
ax = sns.catplot(y='TRKDMG', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Streckenschaden in Dollar")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Streckenschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Histogramm Materialschaden (ohne Ausreißer)¶

# %%
df['TRKDMG'].hist(bins=30)
plt.savefig('Images/Histogramm_Streckenschaden_ohne_Ausreißer.png')

# %% [markdown]
# #### Boxenplot Zuggeschwindigkeit <a class="anchor" id="zuggeschwindigkeit"></a>

# %%
ax = sns.catplot(y='SPEED', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Geschwindigkeit des Zuges")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Zuggeschwindigkeit.png')

# %% [markdown]
# #### Histogramm Zuggeschwindigkeit

# %%
df['SPEED'].hist(bins=50)
plt.savefig('Images/Histogramm_Zuggeschwindigkeit.png')

# %% [markdown]
# #### Boxenplot Zuggewicht <a class="anchor" id="tons"></a>

# %%
ax = sns.catplot(y='TONS', data=df, kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Gewicht des Zuges")
ax.set_xlabels("Alle Unfälle (ohne Ausreißer)")
plt.savefig('Images/Boxplot_Zuggewicht.png')

# %% [markdown]
# #### Histogramm Zuggewicht

# %%
df['TONS'].hist(bins=50)
plt.savefig('Images/Histogramm_Zuggewicht.png')

# %% [markdown]
# #### Boxenplot Zugart und Geschwindigkeit <a class="anchor" id="zugart"></a>

# %%
ax = sns.catplot(y='SPEED', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Geschwindigkeit des Zuges")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Geschwindigkeit_Zugart.png')

# %% [markdown]
# #### Boxenplot Zugart und Gewicht

# %%
ax = sns.catplot(y='TONS', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Gewicht in t(ohne Lokomotiven)")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Gewicht_Zugart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Zugart

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Infrastruktur_Zugart.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Zugart

# %%
ax = sns.catplot(y='EQPDMG', x='EQUIPMENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Zugart")
plt.savefig('Images/Boxplot_Material_Zugart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallart <a class="anchor" id="unfallart"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCIDENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallart")
plt.savefig('Images/Boxplot_Infrastruktur_Unfallart.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallart

# %%
ax = sns.catplot(y='EQPDMG', x='ACCIDENT_TYPE', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallart")
plt.savefig('Images/Boxplot_Material_Unfallart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Streckenart <a class="anchor" id="typtrk"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='TYPTRK', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Streckenart")
plt.savefig('Images/Boxplot_Infrastruktur_Streckenart.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Streckenart

# %%
ax = sns.catplot(y='EQPDMG', x='TYPTRK', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Streckenart")
plt.savefig('Images/Boxplot_Material_Streckenart.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallursache <a class="anchor" id="cause"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCCAUSE_LVL2', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallursache")
plt.savefig('Images/Boxplot_Infrastruktur_Unfallursache.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallursache

# %%
ax = sns.catplot(y='EQPDMG', x='ACCCAUSE_LVL2', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
for x in ax.axes.flat:
    for label in x.get_xticklabels():
        label.set_rotation(-90)
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallursache")
plt.savefig('Images/Boxplot_Material_Unfallursache.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Unfallschwere <a class="anchor" id="unfallsignifikanz"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='ACCTYPE', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Unfallschwere")
plt.savefig('Images/Boxplot_Infrastruktur_Unfallschwere.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Unfallschwere

# %%
ax = sns.catplot(y='EQPDMG', x='ACCTYPE', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Unfallschwere")
plt.savefig('Images/Boxplot_Material_Unfallschwere.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Wetter <a class="anchor" id="wetter"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='WEATHER', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Wetter")
plt.savefig('Images/Boxplot_Infrastruktur_Wetter.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Wetter

# %%
ax = sns.catplot(y='EQPDMG', x='WEATHER', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Wetter")
plt.savefig('Images/Boxplot_Material_Wetter.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Temperatur <a class="anchor" id="temp"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='TEMP_CLUSTER', data=df, palette="colorblind", order=temp_order, kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Temperatur")
plt.savefig('Images/Boxplot_Infrastruktur_Temperatur.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Temperatur

# %%
ax = sns.catplot(y='EQPDMG', x='TEMP_CLUSTER', data=df, palette="colorblind", order=temp_order, kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Temperatur")
plt.savefig('Images/Boxplot_Material_Temperatur.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Sichtbarkeit <a class="anchor" id="vis"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='VISIBLTY', data=df, palette="colorblind", kind='boxen', order=vis_order, height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Sichtbarkeit")
plt.savefig('Images/Boxplot_Infrastruktur_Sichtbarkeit.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Temperatur

# %%
ax = sns.catplot(y='EQPDMG', x='VISIBLTY', data=df, palette="colorblind", order=vis_order, kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Sichtbarkeit")
plt.savefig('Images/Boxplot_Material_Sichtbarkeit.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahreszeit <a class="anchor" id="jahreszeit"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='Jahreszeit', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Infrastruktur_Jahreszeit.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahreszeit (nach Unfallursache)

# %%
bp = sns.catplot(y='INFRASTRUCTURE_DMG', x='Jahreszeit', data=df, palette="colorblind", hue='ACCCAUSE_LVL2', kind="boxen", legend=False, height=10, aspect=1.5)
plt.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=3, frameon=False)
bp.set_ylabels("Infrastrukturschaden in Dollar")
bp.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Infrastruktur_Ursache_Sommer.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahreszeit

# %%
ax = sns.catplot(y='EQPDMG', x='Jahreszeit', data=df, palette="colorblind", kind='boxen', height=10, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Material_Jahreszeit.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahreszeit (nach Unfallursache)

# %%
bp = sns.catplot(y='EQPDMG', x='Jahreszeit', data=df, palette="colorblind", hue='ACCCAUSE_LVL2', kind="boxen", legend=False, height=10, aspect=1.5)
plt.legend(bbox_to_anchor=(0, 1.06), loc='upper left', ncol=3, frameon=False)
bp.set_ylabels("Materialschaden in Dollar")
bp.set_xlabels("Jahreszeit")
plt.savefig('Images/Boxplot_Material_Ursache_Sommer.png')
plt.show()

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Jahr <a class="anchor" id="jahr"></a>

# %%
bp = sns.catplot(x="YEAR4", y="INFRASTRUCTURE_DMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Infrastrukturschaden in Dollar', fontsize=12)
plt.savefig('Images/Boxplot_Infrastruktur_Jahr.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Jahr

# %%
bp = sns.catplot(x="YEAR4", y="EQPDMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Materialschaden in Dollar', fontsize=12)
plt.savefig('Images/Boxplot_Material_Jahr.png')

# %% [markdown]
# #### Boxenplot Streckenschaden und Jahr

# %%
bp = sns.catplot(x="YEAR4", y="TRKDMG", data=df, kind="boxen", height=10, aspect=1.5)
bp.set_xlabels('Jahr', fontsize=12)
bp.set_ylabels('Streckenschaden in Dollar', fontsize=12)
plt.savefig('Images/Boxplot_Strecke_Jahr.png')

# %% [markdown]
# #### Boxenplot Infrastrukturschaden und Zug zu schnell? <a class="anchor" id="speed"></a>

# %%
ax = sns.catplot(y='INFRASTRUCTURE_DMG', x='SPD_TOO_HIGH', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Infrastrukturschaden in Dollar")
ax.set_xlabels("Zug zu schnell?")
plt.savefig('Images/Boxplot_Infrastruktur_Zug_zu_schnell.png')

# %% [markdown]
# #### Boxenplot Materialschaden und Zug zu schnell?

# %%
ax = sns.catplot(y='EQPDMG', x='SPD_TOO_HIGH', data=df, palette="colorblind", kind='boxen', height=5, aspect=1.5)
sns.despine()
ax.set_ylabels("Materialschaden in Dollar")
ax.set_xlabels("Zug zu schnell?")
plt.savefig('Images/Boxplot_Material_Zug_zu_schnell.png')

# %% [markdown]
# ### Common Statistics <a class="anchor" id="common_statistics"></a>

# %%
x_data = df[['YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'TEMP_CLUSTER', 'SPEED', 'ACCCAUSE_LVL1', 'ACCIDENT_TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']]
y = df['INFRASTRUCTURE_DMG']

# %%
x_data.describe(include=np.number, percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
#               YEAR4         MONTH  LOCOMOTIVES1        LOADF1        LOADP1  \
# count  59908.000000  59908.000000  59908.000000  59908.000000  59908.000000
# mean    2001.468852      6.442195      2.412316     36.506376      0.131235
# std        9.798176      3.433446      1.262726     34.675575      0.811104
# min     1985.000000      1.000000      0.000000      0.000000      0.000000
# 10%     1988.000000      2.000000      1.000000      0.000000      0.000000
# 20%     1991.000000      3.000000      1.000000      4.000000      0.000000
# 30%     1995.000000      4.000000      2.000000     11.000000      0.000000
# 40%     1999.000000      5.000000      2.000000     18.000000      0.000000
# 50%     2002.000000      6.000000      2.000000     27.000000      0.000000
# 60%     2004.000000      8.000000      2.000000     37.000000      0.000000
# 70%     2007.000000      9.000000      3.000000     50.000000      0.000000
# 80%     2011.000000     10.000000      3.000000     65.000000      0.000000
# 90%     2015.000000     11.000000      4.000000     90.000000      0.000000
# max     2020.000000     12.000000      7.000000    161.000000      7.000000
#
#             EMPTYF1       EMPTYP1  LOCOMOTIVES2        LOADF2       EMPTYF2  \
# count  59908.000000  59908.000000  59908.000000  59908.000000  59908.000000
# mean      16.927990      0.013471      0.133321      2.771316      1.052931
# std       24.674988      0.176778      0.424243      3.487071      2.064766
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 10%        0.000000      0.000000      0.000000      0.000000      0.000000
# 20%        0.000000      0.000000      0.000000      0.000000      0.000000
# 30%        0.000000      0.000000      0.000000      0.000000      0.000000
# 40%        1.000000      0.000000      0.000000      1.000000      0.000000
# 50%        4.000000      0.000000      0.000000      2.000000      0.000000
# 60%       11.000000      0.000000      0.000000      3.000000      0.000000
# 70%       20.000000      0.000000      0.000000      4.000000      1.000000
# 80%       32.000000      0.000000      0.000000      5.000000      2.000000
# 90%       53.000000      0.000000      1.000000      7.000000      4.000000
# max      116.000000      3.000000      2.000000     20.000000     12.000000
#
#                TONS         SPEED
# count  59908.000000  59908.000000
# mean    4770.274312     13.964014
# std     4588.040689     15.701533
# min        0.000000      0.000000
# 10%      220.000000      3.000000
# 20%      955.183367      4.000000
# 30%     1800.000000      5.000000
# 40%     2668.000000      6.000000
# 50%     3566.500000      7.000000
# 60%     4711.307145      9.000000
# 70%     6048.000000     10.000000
# 80%     7860.523601     23.000000
# 90%    10977.300000     40.000000
# max    96140.000000    135.000000

# %%
x_data.describe(include=np.object, percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
#                      TEMP_CLUSTER   ACCCAUSE_LVL1 ACCIDENT_TYPE  \
# count                       59908           59908         59908
# unique                          5              31             4
# top     Moderat (0° bis 19,99° C)  Track Geometry    Derailment
# freq                        28223            9598         50788
#
#        EQUIPMENT_TYPE TYPTRK VISIBLTY WEATHER  STATE          ACCTYPE  \
# count           59908  59908    59907   59881  59908            59908
# unique              8      4        4       6     50                2
# top     Freight Train   Yard      Day   Clear  Texas  Not Significant
# freq            36760  27387    30586   39487   7114            51037
#
#        Jahreszeit
# count       59908
# unique          4
# top        Sommer
# freq        15952

# %%
y.describe(include='all', percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9])
# Out:
# count    5.990800e+04
# mean     7.121136e+04
# std      1.423473e+05
# min      3.300000e+01
# 10%      8.605700e+03
# 20%      1.110000e+04
# 30%      1.414610e+04
# 40%      1.815480e+04
# 50%      2.389400e+04
# 60%      3.250000e+04
# 70%      4.800000e+04
# 80%      7.881140e+04
# 90%      1.642105e+05
# max      1.476346e+06
# Name: INFRASTRUCTURE_DMG, dtype: float64

# %%
ax = sns.jointplot(x='SPEED', y='INFRASTRUCTURE_DMG', data=df, kind='hex', gridsize=20)

# %%
ax = sns.jointplot(x='TONS', y='INFRASTRUCTURE_DMG', data=df, kind='hex', gridsize=20)

# %% [markdown]
# ### Scattermatrix und Korrelationen der Daten <a class="anchor" id="correlations"></a>
# Jahr, Monat, Anzahl der beladenen Frachtwagons und Personenwagons, Gewicht, Temperatur, Geschwindigkeit und Unfallkosten

# %%
scattermatrix = scatter_matrix(df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'SPEED']], diagonal='kde', figsize=(18, 18))
n = len(df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'SPEED']].columns)
for x in range(n):
    for y in range(n):
        # to get the axis of subplots
        ax = scattermatrix[x, y]
        # to make x axis name vertical  
        ax.xaxis.label.set_rotation(-90)
        # to make y axis name horizontal 
        ax.yaxis.label.set_rotation(0)
        # to make sure y axis names are outside the plot area
        ax.yaxis.labelpad = 50
plt.savefig(r"Images/scatterALL.png")

# %%
colormap = plt.cm.RdBu
corr = df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'YEAR4', 'MONTH', 'LOCOMOTIVES1', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1','LOCOMOTIVES2', 'LOADF2', 'EMPTYF2', 'TONS', 'TEMP_CLUSTER', 'SPEED', 'ACCCAUSE_LVL1', 'TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']].corr()
corr
# Out:
#                     INFRASTRUCTURE_DMG    EQPDMG    TRKDMG     YEAR4  \
# INFRASTRUCTURE_DMG            1.000000  0.851381  0.702941  0.123241
# EQPDMG                        0.851381  1.000000  0.287686  0.083740
# TRKDMG                        0.702941  0.287686  1.000000  0.113750
# YEAR4                         0.123241  0.083740  0.113750  1.000000
# MONTH                        -0.006309 -0.002232 -0.010046 -0.015179
# LOCOMOTIVES1                  0.140232  0.107034  0.120946 -0.072810
# LOADF1                        0.253516  0.201673  0.208657 -0.024008
# LOADP1                       -0.002506  0.024660 -0.047153  0.041911
# EMPTYF1                      -0.009256 -0.013184 -0.000138 -0.008779
# EMPTYP1                      -0.000713  0.007407 -0.013294  0.011407
# LOCOMOTIVES2                  0.021271  0.031052 -0.003768  0.079842
# LOADF2                        0.431434  0.446267  0.232447 -0.120397
# EMPTYF2                       0.082647  0.099678  0.028223 -0.030943
# TONS                          0.247856  0.195086  0.205712  0.009707
# SPEED                         0.229728  0.219571  0.143025 -0.018940
# SPD_TOO_HIGH                  0.030822  0.035325  0.003660 -0.088451
#
#                        MONTH  LOCOMOTIVES1    LOADF1    LOADP1   EMPTYF1  \
# INFRASTRUCTURE_DMG -0.006309      0.140232  0.253516 -0.002506 -0.009256
# EQPDMG             -0.002232      0.107034  0.201673  0.024660 -0.013184
# TRKDMG             -0.010046      0.120946  0.208657 -0.047153 -0.000138
# YEAR4              -0.015179     -0.072810 -0.024008  0.041911 -0.008779
# MONTH               1.000000      0.005519  0.006408 -0.000615  0.007667
# LOCOMOTIVES1        0.005519      1.000000  0.405096 -0.146367  0.171022
# LOADF1              0.006408      0.405096  1.000000 -0.170023 -0.109244
# LOADP1             -0.000615     -0.146367 -0.170023  1.000000 -0.110912
# EMPTYF1             0.007667      0.171022 -0.109244 -0.110912  1.000000
# EMPTYP1             0.007292     -0.074536 -0.076211  0.058103 -0.050666
# LOCOMOTIVES2       -0.005246      0.033772 -0.118487 -0.009565 -0.073347
# LOADF2             -0.013546      0.192771  0.431974 -0.128270 -0.172876
# EMPTYF2             0.003560      0.060660 -0.134520 -0.082341  0.441611
# TONS                0.002802      0.384448  0.855539 -0.160781  0.067745
# SPEED              -0.002444      0.110166  0.092157  0.380377  0.042518
# SPD_TOO_HIGH        0.005942      0.020242  0.007782 -0.013177 -0.008683
#
#                      EMPTYP1  LOCOMOTIVES2    LOADF2   EMPTYF2      TONS  \
# INFRASTRUCTURE_DMG -0.000713      0.021271  0.431434  0.082647  0.247856
# EQPDMG              0.007407      0.031052  0.446267  0.099678  0.195086
# TRKDMG             -0.013294     -0.003768  0.232447  0.028223  0.205712
# YEAR4               0.011407      0.079842 -0.120397 -0.030943  0.009707
# MONTH               0.007292     -0.005246 -0.013546  0.003560  0.002802
# LOCOMOTIVES1       -0.074536      0.033772  0.192771  0.060660  0.384448
# LOADF1             -0.076211     -0.118487  0.431974 -0.134520  0.855539
# LOADP1              0.058103     -0.009565 -0.128270 -0.082341 -0.160781
# EMPTYF1            -0.050666     -0.073347 -0.172876  0.441611  0.067745
# EMPTYP1             1.000000      0.035258 -0.057393 -0.035978 -0.074645
# LOCOMOTIVES2        0.035258      1.000000 -0.122828 -0.076354 -0.111813
# LOADF2             -0.057393     -0.122828  1.000000 -0.111909  0.364102
# EMPTYF2            -0.035978     -0.076354 -0.111909  1.000000 -0.045665
# TONS               -0.074645     -0.111813  0.364102 -0.045665  1.000000
# SPEED               0.007776     -0.056120 -0.024883 -0.047708  0.066414
# SPD_TOO_HIGH        0.002768      0.001807  0.044791  0.007220 -0.001423
#
#                        SPEED  SPD_TOO_HIGH
# INFRASTRUCTURE_DMG  0.229728      0.030822
# EQPDMG              0.219571      0.035325
# TRKDMG              0.143025      0.003660
# YEAR4              -0.018940     -0.088451
# MONTH              -0.002444      0.005942
# LOCOMOTIVES1        0.110166      0.020242
# LOADF1              0.092157      0.007782
# LOADP1              0.380377     -0.013177
# EMPTYF1             0.042518     -0.008683
# EMPTYP1             0.007776      0.002768
# LOCOMOTIVES2       -0.056120      0.001807
# LOADF2             -0.024883      0.044791
# EMPTYF2            -0.047708      0.007220
# TONS                0.066414     -0.001423
# SPEED               1.000000      0.104719
# SPD_TOO_HIGH        0.104719      1.000000

# %%
ax=plt.figure(figsize=(20,15)).gca()
ax=sns.heatmap(corr,ax=ax,linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True);
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.savefig(r"Images/corrALL.png")

# %%
corr = df[df['TONS']!=0][['TONS', 'LOADF1', 'LOADP1', 'EMPTYF1', 'EMPTYP1', 'LOADF2', 'EMPTYF2']].corr()
corr
# Out:
#              TONS    LOADF1    LOADP1   EMPTYF1   EMPTYP1    LOADF2   EMPTYF2
# TONS     1.000000  0.849464 -0.170500  0.042732 -0.079086  0.344518 -0.066884
# LOADF1   0.849464  1.000000 -0.180111 -0.139909 -0.080764  0.414429 -0.158337
# LOADP1  -0.170500 -0.180111  1.000000 -0.116071  0.057713 -0.134655 -0.085838
# EMPTYF1  0.042732 -0.139909 -0.116071  1.000000 -0.053008 -0.196953  0.434630
# EMPTYP1 -0.079086 -0.080764  0.057713 -0.053008  1.000000 -0.060277 -0.037556
# LOADF2   0.344518  0.414429 -0.134655 -0.196953 -0.060277  1.000000 -0.128982
# EMPTYF2 -0.066884 -0.158337 -0.085838  0.434630 -0.037556 -0.128982  1.000000

# %% [markdown]
# ### ANOVA <a class="anchor" id="ANOVA"></a>

# %%
anova_df =df[['INFRASTRUCTURE_DMG', 'EQPDMG', 'TRKDMG', 'TEMP_CLUSTER', 'ACCCAUSE_LVL1', 'ACCCAUSE_LVL2', 'ACCIDENT_TYPE', 'EQUIPMENT_TYPE', 'TYPTRK', 'VISIBLTY', 'WEATHER', 'STATE', 'SPD_TOO_HIGH', 'ACCTYPE', 'Jahreszeit']]

# %%
anova = anova_df.copy()
anova = anova.dropna

# %%
def anova(dmg, cat):
    #print ("ANOVA für INFRASTRUCUTURE_DMG ~ %s :" % (cat))
    mod= ols(dmg + ' ~ ' + cat , data=anova_df).fit()
    anova_table = sm.stats.anova_lm(mod, typ=2)
    esq_sm = anova_table['sum_sq'][0]/(anova_table['sum_sq'][0]+anova_table['sum_sq'][1])
    anova_table['EtaSq'] = [esq_sm, 'NaN']
    anova_table
    pair_t = mod.t_test_pairwise(cat)
    anova_table
    pair_t.result_frame
    return [anova_table, pair_t.result_frame]

# %% [markdown]
# #### ANOVA Korrelation Temperatur Cluster und Damage

# %%
temp_cluster = anova("INFRASTRUCTURE_DMG","TEMP_CLUSTER")

# %%
temp_cluster[0]
# Out:
#                     sum_sq       df          F        PR(>F)      EtaSq
# TEMP_CLUSTER  3.154268e+12      4.0  39.015878  1.127180e-32  0.0025985
# Residual      1.210726e+15  59903.0        NaN           NaN        NaN

# %%
temp_cluster[1]
# Out:
#                                                                coef  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                  -3931.484475
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)             -19817.370042
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)            -7172.112381
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)               -21437.697387
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)       -15885.885567
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      -3240.627906
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)         -17506.212911
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  12645.257661
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)      -1620.327345
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)   -14265.585006
#
#                                                             std err         t  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                   2722.890502 -1.443864
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               2351.251066 -8.428436
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)            26956.435800 -0.266063
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 2416.357291 -8.871907
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)         1821.542887 -8.721115
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      26915.405774 -0.120400
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           1904.841062 -9.190380
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  26880.351874  0.470428
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)       1320.101648 -1.227426
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)    26886.125006 -0.530593
#
#                                                               P>|t|  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                  1.487824e-01
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)              3.579755e-17
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)            7.901915e-01
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                7.383365e-19
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)        2.823785e-18
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)      9.041663e-01
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)          4.035581e-20
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)  6.380513e-01
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)      2.196673e-01
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)    5.957029e-01
#
#                                                        Conf. Int. Low  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                    -9268.359628
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               -24425.830567
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)             -60006.823248
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 -26173.766345
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)         -19456.116160
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)       -55994.919774
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           -21239.708226
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)   -40040.328437
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)        -4207.731310
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)     -66962.486464
#
#                                                        Conf. Int. Upp.  \
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                      1405.390677
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)                -15208.909517
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)               45662.598486
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                  -16701.628428
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)          -12315.654973
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)         49513.663962
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)            -13772.717597
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)     65330.843759
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)           967.076620
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)       38431.316452
#
#                                                        pvalue-hs  reject-hs
# Kalt (-30° - 0,01° C)-Heiß (>= 32° C)                   0.619597      False
# Moderat (0° bis 19,99° C)-Heiß (>= 32° C)               0.000000       True
# Sehr Kalt (-45° - 30,01° C)-Heiß (>= 32° C)             0.973282      False
# Warm (20° bis 31,99° C)-Heiß (>= 32° C)                 0.000000       True
# Moderat (0° bis 19,99° C)-Kalt (-30° - 0,01° C)         0.000000       True
# Sehr Kalt (-45° - 30,01° C)-Kalt (-30° - 0,01° C)       0.973282      False
# Warm (20° bis 31,99° C)-Kalt (-30° - 0,01° C)           0.000000       True
# Sehr Kalt (-45° - 30,01° C)-Moderat (0° bis 19,99° C)   0.973282      False
# Warm (20° bis 31,99° C)-Moderat (0° bis 19,99° C)       0.710666      False
# Warm (20° bis 31,99° C)-Sehr Kalt (-45° - 30,01° C)     0.973282      False

# %% [markdown]
# #### ANOVA Korrelation Unfallursachen Cluster und Damage

# %%
cause = anova("INFRASTRUCTURE_DMG","ACCCAUSE_LVL2")

# %%
cause[0]
# Out:
#                      sum_sq       df           F         PR(>F)      EtaSq
# ACCCAUSE_LVL2  2.496399e+13      6.0  209.626227  9.745272e-266  0.0205654
# Residual       1.188916e+15  59901.0         NaN            NaN        NaN

# %%
cause[1]
# Out:
#                                                                           coef  \
# Human Factors-Environmental Conditions                           -91037.771388
# Loading-Environmental Conditions                                 -86655.316802
# Mechanical and Electrical Failures-Environmental Conditions      -34573.171680
# Miscellaneous Causes-Environmental Conditions                    -76709.731640
# Signal and Communication-Environmental Conditions                -96448.713300
# Track, Roadbed and Structures-Environmental Conditions           -62402.277567
# Loading-Human Factors                                              4382.454586
# Mechanical and Electrical Failures-Human Factors                  56464.599708
# Miscellaneous Causes-Human Factors                                14328.039747
# Signal and Communication-Human Factors                            -5410.941912
# Track, Roadbed and Structures-Human Factors                       28635.493821
# Mechanical and Electrical Failures-Loading                        52082.145122
# Miscellaneous Causes-Loading                                       9945.585162
# Signal and Communication-Loading                                  -9793.396498
# Track, Roadbed and Structures-Loading                             24253.039235
# Miscellaneous Causes-Mechanical and Electrical Failures          -42136.559960
# Signal and Communication-Mechanical and Electrical Failures      -61875.541620
# Track, Roadbed and Structures-Mechanical and Electrical Failures -27829.105887
# Signal and Communication-Miscellaneous Causes                    -19738.981659
# Track, Roadbed and Structures-Miscellaneous Causes                14307.454074
# Track, Roadbed and Structures-Signal and Communication            34046.435733
#
#                                                                       std err  \
# Human Factors-Environmental Conditions                            4900.846414
# Loading-Environmental Conditions                                  5093.430534
# Mechanical and Electrical Failures-Environmental Conditions       5012.913803
# Miscellaneous Causes-Environmental Conditions                     5118.302481
# Signal and Communication-Environmental Conditions                 7454.553287
# Track, Roadbed and Structures-Environmental Conditions            4854.238785
# Loading-Human Factors                                             2131.318980
# Mechanical and Electrical Failures-Human Factors                  1931.007711
# Miscellaneous Causes-Human Factors                                2190.092755
# Signal and Communication-Human Factors                            5845.498328
# Track, Roadbed and Structures-Human Factors                       1470.754965
# Mechanical and Electrical Failures-Loading                        2377.715250
# Miscellaneous Causes-Loading                                      2592.536462
# Signal and Communication-Loading                                  6007.877306
# Track, Roadbed and Structures-Loading                             2021.845493
# Miscellaneous Causes-Mechanical and Electrical Failures           2430.538108
# Signal and Communication-Mechanical and Electrical Failures       5939.769349
# Track, Roadbed and Structures-Mechanical and Electrical Failures  1809.455549
# Signal and Communication-Miscellaneous Causes                     6028.977974
# Track, Roadbed and Structures-Miscellaneous Causes                2083.709405
# Track, Roadbed and Structures-Signal and Communication            5806.478219
#
#                                                                           t  \
# Human Factors-Environmental Conditions                           -18.575928
# Loading-Environmental Conditions                                 -17.013154
# Mechanical and Electrical Failures-Environmental Conditions       -6.896821
# Miscellaneous Causes-Environmental Conditions                    -14.987338
# Signal and Communication-Environmental Conditions                -12.938228
# Track, Roadbed and Structures-Environmental Conditions           -12.855214
# Loading-Human Factors                                              2.056217
# Mechanical and Electrical Failures-Human Factors                  29.241002
# Miscellaneous Causes-Human Factors                                 6.542207
# Signal and Communication-Human Factors                            -0.925660
# Track, Roadbed and Structures-Human Factors                       19.469928
# Mechanical and Electrical Failures-Loading                        21.904282
# Miscellaneous Causes-Loading                                       3.836237
# Signal and Communication-Loading                                  -1.630093
# Track, Roadbed and Structures-Loading                             11.995496
# Miscellaneous Causes-Mechanical and Electrical Failures          -17.336309
# Signal and Communication-Mechanical and Electrical Failures      -10.417162
# Track, Roadbed and Structures-Mechanical and Electrical Failures -15.379823
# Signal and Communication-Miscellaneous Causes                     -3.274018
# Track, Roadbed and Structures-Miscellaneous Causes                 6.866338
# Track, Roadbed and Structures-Signal and Communication             5.863526
#
#                                                                           P>|t|  \
# Human Factors-Environmental Conditions                             8.280257e-77
# Loading-Environmental Conditions                                   9.319140e-65
# Mechanical and Electrical Failures-Environmental Conditions        5.370432e-12
# Miscellaneous Causes-Environmental Conditions                      1.098135e-50
# Signal and Communication-Environmental Conditions                  3.082116e-38
# Track, Roadbed and Structures-Environmental Conditions             9.021512e-38
# Loading-Human Factors                                              3.976591e-02
# Mechanical and Electrical Failures-Human Factors                  1.208998e-186
# Miscellaneous Causes-Human Factors                                 6.110420e-11
# Signal and Communication-Human Factors                             3.546266e-01
# Track, Roadbed and Structures-Human Factors                        3.600891e-84
# Mechanical and Electrical Failures-Loading                        6.174024e-106
# Miscellaneous Causes-Loading                                       1.250617e-04
# Signal and Communication-Loading                                   1.030872e-01
# Track, Roadbed and Structures-Loading                              4.094574e-33
# Miscellaneous Causes-Mechanical and Electrical Failures            3.653678e-67
# Signal and Communication-Mechanical and Electrical Failures        2.176511e-25
# Track, Roadbed and Structures-Mechanical and Electrical Failures   2.827432e-53
# Signal and Communication-Miscellaneous Causes                      1.060900e-03
# Track, Roadbed and Structures-Miscellaneous Causes                 6.651020e-12
# Track, Roadbed and Structures-Signal and Communication             4.555093e-09
#
#                                                                   Conf. Int. Low  \
# Human Factors-Environmental Conditions                            -100643.447946
# Loading-Environmental Conditions                                   -96638.458927
# Mechanical and Electrical Failures-Environmental Conditions        -44398.500722
# Miscellaneous Causes-Environmental Conditions                      -86741.622871
# Signal and Communication-Environmental Conditions                 -111059.664493
# Track, Roadbed and Structures-Environmental Conditions             -71916.603005
# Loading-Human Factors                                                 205.061737
# Mechanical and Electrical Failures-Human Factors                    52679.817665
# Miscellaneous Causes-Human Factors                                  10035.450088
# Signal and Communication-Human Factors                             -16868.139611
# Track, Roadbed and Structures-Human Factors                         25752.808812
# Mechanical and Electrical Failures-Loading                          47421.814699
# Miscellaneous Causes-Loading                                         4864.204392
# Signal and Communication-Loading                                   -21568.857578
# Track, Roadbed and Structures-Loading                               20290.214813
# Miscellaneous Causes-Mechanical and Electrical Failures            -46900.423374
# Signal and Communication-Mechanical and Electrical Failures        -73517.510858
# Track, Roadbed and Structures-Mechanical and Electrical Failures   -31375.645257
# Signal and Communication-Miscellaneous Causes                      -31555.800124
# Track, Roadbed and Structures-Miscellaneous Causes                  10223.376163
# Track, Roadbed and Structures-Signal and Communication              22665.717588
#
#                                                                   Conf. Int. Upp.  \
# Human Factors-Environmental Conditions                              -81432.094829
# Loading-Environmental Conditions                                    -76672.174677
# Mechanical and Electrical Failures-Environmental Conditions         -24747.842638
# Miscellaneous Causes-Environmental Conditions                       -66677.840410
# Signal and Communication-Environmental Conditions                   -81837.762106
# Track, Roadbed and Structures-Environmental Conditions              -52887.952129
# Loading-Human Factors                                                 8559.847434
# Mechanical and Electrical Failures-Human Factors                     60249.381750
# Miscellaneous Causes-Human Factors                                   18620.629407
# Signal and Communication-Human Factors                                6046.255787
# Track, Roadbed and Structures-Human Factors                          31518.178830
# Mechanical and Electrical Failures-Loading                           56742.475545
# Miscellaneous Causes-Loading                                         15026.965931
# Signal and Communication-Loading                                      1982.064583
# Track, Roadbed and Structures-Loading                                28215.863658
# Miscellaneous Causes-Mechanical and Electrical Failures             -37372.696546
# Signal and Communication-Mechanical and Electrical Failures         -50233.572381
# Track, Roadbed and Structures-Mechanical and Electrical Failures    -24282.566517
# Signal and Communication-Miscellaneous Causes                        -7922.163195
# Track, Roadbed and Structures-Miscellaneous Causes                   18391.531984
# Track, Roadbed and Structures-Signal and Communication               45427.153878
#
#                                                                      pvalue-hs  \
# Human Factors-Environmental Conditions                            0.000000e+00
# Loading-Environmental Conditions                                  0.000000e+00
# Mechanical and Electrical Failures-Environmental Conditions       4.833434e-11
# Miscellaneous Causes-Environmental Conditions                     0.000000e+00
# Signal and Communication-Environmental Conditions                 0.000000e+00
# Track, Roadbed and Structures-Environmental Conditions            0.000000e+00
# Loading-Human Factors                                             1.146166e-01
# Mechanical and Electrical Failures-Human Factors                  0.000000e+00
# Miscellaneous Causes-Human Factors                                4.277296e-10
# Signal and Communication-Human Factors                            3.546266e-01
# Track, Roadbed and Structures-Human Factors                       0.000000e+00
# Mechanical and Electrical Failures-Loading                        0.000000e+00
# Miscellaneous Causes-Loading                                      6.251520e-04
# Signal and Communication-Loading                                  1.955474e-01
# Track, Roadbed and Structures-Loading                             0.000000e+00
# Miscellaneous Causes-Mechanical and Electrical Failures           0.000000e+00
# Signal and Communication-Mechanical and Electrical Failures       0.000000e+00
# Track, Roadbed and Structures-Mechanical and Electrical Failures  0.000000e+00
# Signal and Communication-Miscellaneous Causes                     4.236852e-03
# Track, Roadbed and Structures-Miscellaneous Causes                5.320810e-11
# Track, Roadbed and Structures-Signal and Communication            2.733056e-08
#
#                                                                   reject-hs
# Human Factors-Environmental Conditions                                 True
# Loading-Environmental Conditions                                       True
# Mechanical and Electrical Failures-Environmental Conditions            True
# Miscellaneous Causes-Environmental Conditions                          True
# Signal and Communication-Environmental Conditions                      True
# Track, Roadbed and Structures-Environmental Conditions                 True
# Loading-Human Factors                                                 False
# Mechanical and Electrical Failures-Human Factors                       True
# Miscellaneous Causes-Human Factors                                     True
# Signal and Communication-Human Factors                                False
# Track, Roadbed and Structures-Human Factors                            True
# Mechanical and Electrical Failures-Loading                             True
# Miscellaneous Causes-Loading                                           True
# Signal and Communication-Loading                                      False
# Track, Roadbed and Structures-Loading                                  True
# Miscellaneous Causes-Mechanical and Electrical Failures                True
# Signal and Communication-Mechanical and Electrical Failures            True
# Track, Roadbed and Structures-Mechanical and Electrical Failures       True
# Signal and Communication-Miscellaneous Causes                          True
# Track, Roadbed and Structures-Miscellaneous Causes                     True
# Track, Roadbed and Structures-Signal and Communication                 True

# %% [markdown]
# #### ANOVA Korrelation Unfallart und Damage

# %%
accidenttype = anova("INFRASTRUCTURE_DMG","ACCIDENT_TYPE")

# %%
accidenttype[0]
# Out:
#                      sum_sq       df         F        PR(>F)       EtaSq
# ACCIDENT_TYPE  3.679691e+12      3.0  60.71397  3.485384e-39  0.00303135
# Residual       1.210201e+15  59904.0       NaN           NaN         NaN

# %%
accidenttype[1]
# Out:
#                                                                   coef  \
# Crossing-Collision                                        -9945.963263
# Derailment-Collision                                      15661.921592
# Fire / Violent Rupture / Explosive Detonation-Collision   20126.885631
# Derailment-Crossing                                       25607.884855
# Fire / Violent Rupture / Explosive Detonation-Crossing    30072.848895
# Fire / Violent Rupture / Explosive Detonation-Derailment   4464.964039
#
#                                                               std err  \
# Crossing-Collision                                        3269.472415
# Derailment-Collision                                      2695.301106
# Fire / Violent Rupture / Explosive Detonation-Collision   5430.457003
# Derailment-Crossing                                       2054.350792
# Fire / Violent Rupture / Explosive Detonation-Crossing    5142.525876
# Fire / Violent Rupture / Explosive Detonation-Derailment  4797.996516
#
#                                                                   t  \
# Crossing-Collision                                        -3.042070
# Derailment-Collision                                       5.810824
# Fire / Violent Rupture / Explosive Detonation-Collision    3.706297
# Derailment-Crossing                                       12.465196
# Fire / Violent Rupture / Explosive Detonation-Crossing     5.847875
# Fire / Violent Rupture / Explosive Detonation-Derailment   0.930589
#
#                                                                  P>|t|  \
# Crossing-Collision                                        2.350590e-03
# Derailment-Collision                                      6.247970e-09
# Fire / Violent Rupture / Explosive Detonation-Collision   2.105010e-04
# Derailment-Crossing                                       1.279838e-35
# Fire / Violent Rupture / Explosive Detonation-Crossing    5.004684e-09
# Fire / Violent Rupture / Explosive Detonation-Derailment  3.520698e-01
#
#                                                           Conf. Int. Low  \
# Crossing-Collision                                         -16354.140924
# Derailment-Collision                                        10379.121757
# Fire / Violent Rupture / Explosive Detonation-Collision      9483.170429
# Derailment-Crossing                                         21581.349936
# Fire / Violent Rupture / Explosive Detonation-Crossing      19993.479734
# Fire / Violent Rupture / Explosive Detonation-Derailment    -4939.126339
#
#                                                           Conf. Int. Upp.  \
# Crossing-Collision                                           -3537.785603
# Derailment-Collision                                         20944.721427
# Fire / Violent Rupture / Explosive Detonation-Collision      30770.600834
# Derailment-Crossing                                          29634.419775
# Fire / Violent Rupture / Explosive Detonation-Crossing       40152.218055
# Fire / Violent Rupture / Explosive Detonation-Derailment     13869.054418
#
#                                                              pvalue-hs  \
# Crossing-Collision                                        4.695656e-03
# Derailment-Collision                                      2.502342e-08
# Fire / Violent Rupture / Explosive Detonation-Collision   6.313702e-04
# Derailment-Crossing                                       0.000000e+00
# Fire / Violent Rupture / Explosive Detonation-Crossing    2.502342e-08
# Fire / Violent Rupture / Explosive Detonation-Derailment  3.520698e-01
#
#                                                           reject-hs
# Crossing-Collision                                             True
# Derailment-Collision                                           True
# Fire / Violent Rupture / Explosive Detonation-Collision        True
# Derailment-Crossing                                            True
# Fire / Violent Rupture / Explosive Detonation-Crossing         True
# Fire / Violent Rupture / Explosive Detonation-Derailment      False

# %% [markdown]
# #### ANOVA Korrelation Zugart und Damage

# %%
eqtype = anova("INFRASTRUCTURE_DMG","EQUIPMENT_TYPE")

# %%
eqtype[0]
# Out:
#                       sum_sq       df           F  PR(>F)      EtaSq
# EQUIPMENT_TYPE  3.916194e+13      7.0  285.272042     0.0  0.0322618
# Residual        1.174718e+15  59900.0         NaN     NaN        NaN

# %%
eqtype[1]
# Out:
#                                         coef      std err          t  \
# Cut of Cars-Commuter Train     -33004.953794  8629.962099  -3.824461
# Freight Train-Commuter Train    22442.219662  7563.968707   2.966990
# Locomotive-Commuter Train      -35109.904546  8201.443733  -4.280942
# Passenger Train-Commuter Train  -1761.864274  8283.941405  -0.212684
# Single Car-Commuter Train      -40116.359296  9889.085523  -4.056630
# Work Train-Commuter Train       -1946.861282  9500.587353  -0.204920
# Yard/Switching-Commuter Train  -31334.225935  7604.212250  -4.120641
# Freight Train-Cut of Cars       55447.173456  4281.310057  12.950983
# Locomotive-Cut of Cars          -2104.950752  5327.257504  -0.395128
# Passenger Train-Cut of Cars     31243.089519  5453.409797   5.729093
# Single Car-Cut of Cars          -7111.405502  7675.285382  -0.926533
# Work Train-Cut of Cars          31058.092512  7167.785799   4.333011
# Yard/Switching-Cut of Cars       1670.727859  4352.015296   0.383898
# Locomotive-Freight Train       -57552.124208  3334.223941 -17.261025
# Passenger Train-Freight Train  -24204.083936  3532.287529  -6.852241
# Single Car-Freight Train       -62558.578958  6453.478323  -9.693777
# Work Train-Freight Train       -24389.080943  5840.764508  -4.175666
# Yard/Switching-Freight Train   -53776.445597  1295.150151 -41.521399
# Passenger Train-Locomotive      33348.040272  4746.273474   7.026152
# Single Car-Locomotive           -5006.454750  7190.093127  -0.696299
# Work Train-Locomotive           33163.043265  6645.644193   4.990192
# Yard/Switching-Locomotive        3775.678611  3424.539476   1.102536
# Single Car-Passenger Train     -38354.495022  7284.054164  -5.265542
# Work Train-Passenger Train       -184.997007  6747.191463  -0.027418
# Yard/Switching-Passenger Train -29572.361660  3617.661747  -8.174441
# Work Train-Single Car           38169.498015  8642.622282   4.416426
# Yard/Switching-Single Car        8782.133362  6500.600264   1.350973
# Yard/Switching-Work Train      -29387.364653  5892.788081  -4.987005
#
#                                        P>|t|  Conf. Int. Low  Conf. Int. Upp.  \
# Cut of Cars-Commuter Train      1.311912e-04   -49919.710482    -16090.197105
# Freight Train-Commuter Train    3.008495e-03     7616.813847     37267.625477
# Locomotive-Commuter Train       1.863929e-05   -51184.763700    -19035.045392
# Passenger Train-Commuter Train  8.315739e-01   -17998.419162     14474.690613
# Single Car-Commuter Train       4.984889e-05   -59499.002416    -20733.716177
# Work Train-Commuter Train       8.376352e-01   -20568.046593     16674.324030
# Yard/Switching-Commuter Train   3.783277e-05   -46238.509237    -16429.942633
# Freight Train-Cut of Cars       2.611712e-38    47055.790377     63838.556535
# Locomotive-Cut of Cars          6.927495e-01   -12546.394580      8336.493076
# Passenger Train-Cut of Cars     1.014516e-08    20554.386745     41931.792294
# Single Car-Cut of Cars          3.541728e-01   -22154.992398      7932.181393
# Work Train-Cut of Cars          1.473231e-05    17009.206620     45106.978404
# Yard/Switching-Cut of Cars      7.010558e-01    -6859.237741     10200.693459
# Locomotive-Freight Train        1.340833e-66   -64087.215100    -51017.033316
# Passenger Train-Freight Train   7.340232e-12   -31127.380171    -17280.787702
# Single Car-Freight Train        3.327311e-22   -75207.419634    -49909.738282
# Work Train-Freight Train        2.975353e-05   -35837.000342    -12941.161545
# Yard/Switching-Freight Train    0.000000e+00   -56314.944541    -51237.946652
# Passenger Train-Locomotive      2.145636e-12    24045.327227     42650.753317
# Single Car-Locomotive           4.862443e-01   -19099.063085      9086.153585
# Work Train-Locomotive           6.048783e-07    20137.556794     46188.529735
# Yard/Switching-Locomotive       2.702331e-01    -2936.431052     10487.788275
# Single Car-Passenger Train      1.402572e-07   -52631.267328    -24077.722716
# Work Train-Passenger Train      9.781261e-01   -13409.516491     13039.522477
# Yard/Switching-Passenger Train  3.029961e-16   -36662.991669    -22481.731652
# Work Train-Single Car           1.005219e-05    21229.927321     55109.068708
# Yard/Switching-Single Car       1.767093e-01    -3959.066488     21523.333211
# Yard/Switching-Work Train       6.149346e-07   -40937.250442    -17837.478865
#
#                                    pvalue-hs  reject-hs
# Cut of Cars-Commuter Train      1.442157e-03       True
# Freight Train-Commuter Train    2.968090e-02       True
# Locomotive-Commuter Train       2.795528e-04       True
# Passenger Train-Commuter Train  9.972618e-01      False
# Single Car-Commuter Train       5.980227e-04       True
# Work Train-Commuter Train       9.972618e-01      False
# Yard/Switching-Commuter Train   4.917144e-04       True
# Freight Train-Cut of Cars       0.000000e+00       True
# Locomotive-Cut of Cars          9.972618e-01      False
# Passenger Train-Cut of Cars     2.130483e-07       True
# Single Car-Cut of Cars          9.531387e-01      False
# Work Train-Cut of Cars          2.356910e-04       True
# Yard/Switching-Cut of Cars      9.972618e-01      False
# Locomotive-Freight Train        0.000000e+00       True
# Passenger Train-Freight Train   1.614853e-10       True
# Single Car-Freight Train        0.000000e+00       True
# Work Train-Freight Train        4.164689e-04       True
# Yard/Switching-Freight Train    0.000000e+00       True
# Passenger Train-Locomotive      4.934919e-11       True
# Single Car-Locomotive           9.816118e-01      False
# Work Train-Locomotive           1.149262e-05       True
# Yard/Switching-Locomotive       9.195598e-01      False
# Single Car-Passenger Train      2.805140e-06       True
# Work Train-Passenger Train      9.972618e-01      False
# Yard/Switching-Passenger Train  7.993606e-15       True
# Work Train-Single Car           1.708735e-04       True
# Yard/Switching-Single Car       8.262283e-01      False
# Yard/Switching-Work Train       1.149262e-05       True

# %% [markdown]
# #### ANOVA Korrelation Sichtbarkeit und Damage

# %%
vis = anova("INFRASTRUCTURE_DMG","VISIBLTY")

# %%
vis[0]
# Out:
#                 sum_sq       df         F        PR(>F)       EtaSq
# VISIBLTY  1.319469e+12      3.0  21.72821  4.659404e-14  0.00108699
# Residual  1.212558e+15  59903.0       NaN           NaN         NaN

# %%
vis[1]
# Out:
#                    coef      std err         t         P>|t|  Conf. Int. Low  \
# Dawn-Dark  15990.209900  2845.809540  5.618862  1.930710e-08    10412.412993
# Day-Dark   -4593.616768  1234.256750 -3.721768  1.980139e-04    -7012.764425
# Dusk-Dark  -8147.531319  2746.291969 -2.966739  3.010952e-03   -13530.273430
# Day-Dawn  -20583.826668  2810.490358 -7.323927  2.438330e-13   -26092.397852
# Dusk-Dawn -24137.741220  3730.628085 -6.470155  9.865502e-11   -31449.785649
# Dusk-Day   -3553.914551  2709.675939 -1.311564  1.896722e-01    -8864.889112
#
#            Conf. Int. Upp.     pvalue-hs  reject-hs
# Dawn-Dark     21568.006807  7.722839e-08       True
# Day-Dark      -2174.469111  5.939241e-04       True
# Dusk-Dark     -2764.789208  6.012838e-03       True
# Day-Dawn     -15075.255485  1.462830e-12       True
# Dusk-Dawn    -16825.696790  4.932749e-10       True
# Dusk-Day       1757.060009  1.896722e-01      False

# %% [markdown]
# #### ANOVA Korrelation Wetter und Damage

# %%
weather = anova("INFRASTRUCTURE_DMG","WEATHER")

# %%
weather[0]
# Out:
#                 sum_sq       df         F    PR(>F)        EtaSq
# WEATHER   2.914397e+11      5.0  2.875977  0.013376  0.000240107
# Residual  1.213498e+15  59875.0       NaN       NaN          NaN

# %%
weather[1]
# Out:
#                       coef       std err         t     P>|t|  Conf. Int. Low  \
# Cloudy-Clear   -566.172560   1390.620652 -0.407137  0.683909    -3291.794052
# Fog-Clear      8794.322015   5350.054611  1.643782  0.100227    -1691.804314
# Rain-Clear      414.515166   2372.478410  0.174718  0.861302    -4235.551073
# Sleet-Clear    3437.171559  12961.891548  0.265175  0.790875   -21968.182612
# Snow-Clear    13309.576673   3978.991278  3.344963  0.000823     5510.739421
# Fog-Cloudy     9360.494576   5434.186772  1.722520  0.084981    -1290.531092
# Rain-Cloudy     980.687726   2556.551455  0.383598  0.701278    -4030.162343
# Sleet-Cloudy   4003.344119  12996.843233  0.308024  0.758065   -21470.515481
# Snow-Cloudy   13875.749234   4091.414563  3.391431  0.000696     5856.561938
# Rain-Fog      -8379.806850   5764.131668 -1.453785  0.146011   -19677.525703
# Sleet-Fog     -5357.150457  13985.964128 -0.383038  0.701693   -32769.690576
# Snow-Fog       4515.254658   6590.063101  0.685161  0.493245    -8401.292781
# Sleet-Rain     3022.656393  13138.217613  0.230066  0.818041   -22728.297501
# Snow-Rain     12895.061508   4520.453642  2.852603  0.004338     4034.956069
# Snow-Sleet     9872.405115  13520.964456  0.730155  0.465298   -16628.733972
#
#               Conf. Int. Upp.  pvalue-hs  reject-hs
# Cloudy-Clear      2159.448932   0.999685      False
# Fog-Clear        19280.448344   0.687057      False
# Rain-Clear        5064.581404   0.999685      False
# Sleet-Clear      28842.525729   0.999685      False
# Snow-Clear       21108.413926   0.011467       True
# Fog-Cloudy       20011.520244   0.655520      False
# Rain-Cloudy       5991.537795   0.999685      False
# Sleet-Cloudy     29477.203719   0.999685      False
# Snow-Cloudy      21894.936529   0.010385       True
# Rain-Fog          2917.912004   0.793689      False
# Sleet-Fog        22055.389663   0.999685      False
# Snow-Fog         17431.802097   0.996427      False
# Sleet-Rain       28773.610287   0.999685      False
# Snow-Rain        21755.166946   0.054946      False
# Snow-Sleet       36373.544202   0.996427      False

# %% [markdown]
# #### ANOVA Korrelation zu hoher Geschwindigkeit und Damage

# %%
spd = anova("INFRASTRUCTURE_DMG","SPD_TOO_HIGH")

# %%
spd[0]
# Out:
#                     sum_sq       df          F        PR(>F)        EtaSq
# SPD_TOO_HIGH  1.153171e+12      1.0  56.964087  4.501032e-14  0.000949988
# Residual      1.212727e+15  59906.0        NaN           NaN          NaN

# %%
spd[1]
# Out:
#                     coef      std err         t         P>|t|  Conf. Int. Low  \
# True-False  24506.311871  3246.963346  7.547456  4.501032e-14    18142.252073
#
#             Conf. Int. Upp.     pvalue-hs  reject-hs
# True-False     30870.371669  4.496403e-14       True

# %% [markdown]
# #### ANOVA Korrelation Streckenart und Damage

# %%
typtrk = anova("INFRASTRUCTURE_DMG","TYPTRK")

# %%
typtrk[0]
# Out:
#                 sum_sq       df            F  PR(>F)      EtaSq
# TYPTRK    8.089549e+13      3.0  1425.721902     0.0  0.0666421
# Residual  1.132985e+15  59904.0          NaN     NaN        NaN

# %%
typtrk[1]
# Out:
#                          coef      std err          t         P>|t|  \
# Main-Industry    77509.531901  2002.517371  38.706047  0.000000e+00
# Siding-Industry  33180.837033  3377.431335   9.824282  9.208098e-23
# Yard-Industry     2010.595839  1980.958839   1.014961  3.101285e-01
# Siding-Main     -44328.694868  2991.640603 -14.817520  1.382134e-49
# Yard-Main       -75498.936062  1211.226237 -62.332646  0.000000e+00
# Yard-Siding     -31170.241194  2977.253029 -10.469463  1.255592e-25
#
#                  Conf. Int. Low  Conf. Int. Upp.  pvalue-hs  reject-hs
# Main-Industry      73584.590671     81434.473131   0.000000       True
# Siding-Industry    26561.059503     39800.614563   0.000000       True
# Yard-Industry      -1872.090590      5893.282268   0.310129      False
# Siding-Main       -50192.321181    -38465.068556   0.000000       True
# Yard-Main         -77872.943831    -73124.928293   0.000000       True
# Yard-Siding       -37005.667809    -25334.814579   0.000000       True

# %% [markdown]
# #### ANOVA Korrelation Signifikanzlevel und Damage

# %%
acctype = anova("INFRASTRUCTURE_DMG","ACCTYPE")

# %%
acctype[0]
# Out:
#                 sum_sq       df             F  PR(>F)     EtaSq
# ACCTYPE   4.439760e+14      1.0  34545.627063     0.0  0.365749
# Residual  7.699042e+14  59906.0           NaN     NaN       NaN

# %%
acctype[1]
# Out:
#                                       coef      std err          t  P>|t|  \
# Significant-Not Significant  242378.050836  1304.057522  185.86454    0.0
#
#                              Conf. Int. Low  Conf. Int. Upp.  pvalue-hs  \
# Significant-Not Significant   239822.093417    244934.008254        0.0
#
#                              reject-hs
# Significant-Not Significant       True

# %% [markdown]
# #### ANOVA Korrelation Jahreszeit und Damage

# %%
jahreszeit = anova("INFRASTRUCTURE_DMG","Jahreszeit")

# %%
jahreszeit[0]
# Out:
#                   sum_sq       df         F    PR(>F)        EtaSq
# Jahreszeit  2.244413e+11      3.0  3.692681  0.011316  0.000184896
# Residual    1.213656e+15  59904.0       NaN       NaN          NaN

# %%
jahreszeit[1]
# Out:
#                         coef      std err         t     P>|t|  Conf. Int. Low  \
# Herbst-Frühling -3554.435607  1675.740971 -2.121113  0.033916    -6838.893921
# Sommer-Frühling  1829.656768  1619.283939  1.129917  0.258516    -1344.145561
# Winter-Frühling -1077.447599  1642.429269 -0.656009  0.511821    -4296.614858
# Sommer-Herbst    5384.092374  1651.105462  3.260902  0.001111     2147.919746
# Winter-Herbst    2476.988007  1673.810825  1.479849  0.138919     -803.687212
# Winter-Sommer   -2907.104367  1617.286415 -1.797520  0.072258    -6076.991542
#
#                  Conf. Int. Upp.  pvalue-hs  reject-hs
# Herbst-Frühling      -269.977293   0.158462      False
# Sommer-Frühling      5003.459096   0.450201      False
# Winter-Frühling      2141.719659   0.511821      False
# Sommer-Herbst        8620.265002   0.006649       True
# Winter-Herbst        5757.663227   0.361542      False
# Winter-Sommer         262.782808   0.259187      False

# %%
temp_cluster_eqpdmg = anova("EQPDMG","TEMP_CLUSTER")
cause_eqpdmg = anova("EQPDMG","ACCCAUSE_LVL2")
accidenttype_eqpdmg = anova("EQPDMG","ACCIDENT_TYPE")
eqtype_eqpdmg = anova("EQPDMG","EQUIPMENT_TYPE")
vis_eqpdmg = anova("EQPDMG","VISIBLTY")
weather_eqpdmg = anova("EQPDMG","WEATHER")
spd_eqpdmg = anova("EQPDMG","SPD_TOO_HIGH")
typtrk_eqpdmg = anova("EQPDMG","TYPTRK")
acctype_eqpdmg = anova("EQPDMG","ACCTYPE")
jahreszeit_eqpdmg = anova("EQPDMG","Jahreszeit")

# %%
temp_cluster_trkdmg = anova("TRKDMG","TEMP_CLUSTER")
cause_trkdmg = anova("TRKDMG","ACCCAUSE_LVL2")
accidenttype_trkdmg = anova("TRKDMG","ACCIDENT_TYPE")
eqtype_trkdmg = anova("TRKDMG","EQUIPMENT_TYPE")
vis_trkdmg = anova("TRKDMG","VISIBLTY")
weather_trkdmg = anova("TRKDMG","WEATHER")
spd_trkdmg = anova("TRKDMG","SPD_TOO_HIGH")
typtrk_trkdmg = anova("TRKDMG","TYPTRK")
acctype_trkdmg = anova("TRKDMG","ACCTYPE")
jahreszeit_trkdmg = anova("TRKDMG","Jahreszeit")

# %%
compare_anova = [
                                [
                                    temp_cluster[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis[0]["EtaSq"]["VISIBLTY"],
                                    weather[0]["EtaSq"]["WEATHER"],
                                    spd[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk[0]["EtaSq"]["TYPTRK"],
                                    acctype[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit[0]["EtaSq"]["Jahreszeit"]
                                ],
                                [
                                    temp_cluster_eqpdmg[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause_eqpdmg[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype_eqpdmg[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype_eqpdmg[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis_eqpdmg[0]["EtaSq"]["VISIBLTY"],
                                    weather_eqpdmg[0]["EtaSq"]["WEATHER"],
                                    spd_eqpdmg[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk_eqpdmg[0]["EtaSq"]["TYPTRK"],
                                    acctype_eqpdmg[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit_eqpdmg[0]["EtaSq"]["Jahreszeit"]
                                ],
                                [
                                    temp_cluster_trkdmg[0]["EtaSq"]["TEMP_CLUSTER"],
                                    cause_trkdmg[0]["EtaSq"]["ACCCAUSE_LVL2"],
                                    accidenttype_trkdmg[0]["EtaSq"]["ACCIDENT_TYPE"],
                                    eqtype_trkdmg[0]["EtaSq"]["EQUIPMENT_TYPE"],
                                    vis_trkdmg[0]["EtaSq"]["VISIBLTY"],
                                    weather_trkdmg[0]["EtaSq"]["WEATHER"],
                                    spd_trkdmg[0]["EtaSq"]["SPD_TOO_HIGH"],
                                    typtrk_trkdmg[0]["EtaSq"]["TYPTRK"],
                                    acctype_trkdmg[0]["EtaSq"]["ACCTYPE"],
                                    jahreszeit_trkdmg[0]["EtaSq"]["Jahreszeit"]
                                ]
                            ]
pd.DataFrame(compare_anova,columns=["Temperatur", "Ursache","Unfallart", "Zugart", "Sichtbarkeit", "Wetter", "Zug zu schnell?", "Streckenart", "Siginifikanz des Unfalls", "Jahreszeit"], index=["Infrastrukturschaden", "Materialschaden", "Streckenschaden"]).style.format("{:.1g}")
# Out:
# <style  type="text/css" >
# </style><table id="T_abef4c20_d12b_11ea_88f6_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Temperatur</th>        <th class="col_heading level0 col1" >Ursache</th>        <th class="col_heading level0 col2" >Unfallart</th>        <th class="col_heading level0 col3" >Zugart</th>        <th class="col_heading level0 col4" >Sichtbarkeit</th>        <th class="col_heading level0 col5" >Wetter</th>        <th class="col_heading level0 col6" >Zug zu schnell?</th>        <th class="col_heading level0 col7" >Streckenart</th>        <th class="col_heading level0 col8" >Siginifikanz des Unfalls</th>        <th class="col_heading level0 col9" >Jahreszeit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_abef4c20_d12b_11ea_88f6_acde48001122level0_row0" class="row_heading level0 row0" >Infrastrukturschaden</th>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row0_col0" class="data row0 col0" >0.003</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row0_col1" class="data row0 col1" >0.02</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row0_col2" class="data row0 col2" >0.003</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row0_col3" class="data row0 col3" >0.03</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row0_col4" class="data row0 col4" >0.001</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row0_col5" class="data row0 col5" >0.0002</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row0_col6" class="data row0 col6" >0.0009</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row0_col7" class="data row0 col7" >0.07</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row0_col8" class="data row0 col8" >0.4</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row0_col9" class="data row0 col9" >0.0002</td>
#             </tr>
#             <tr>
#                         <th id="T_abef4c20_d12b_11ea_88f6_acde48001122level0_row1" class="row_heading level0 row1" >Materialschaden</th>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row1_col0" class="data row1 col0" >0.002</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row1_col1" class="data row1 col1" >0.01</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row1_col2" class="data row1 col2" >0.003</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row1_col3" class="data row1 col3" >0.02</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row1_col4" class="data row1 col4" >0.0005</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row1_col5" class="data row1 col5" >0.0003</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row1_col6" class="data row1 col6" >0.001</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row1_col7" class="data row1 col7" >0.05</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row1_col8" class="data row1 col8" >0.3</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row1_col9" class="data row1 col9" >1e-05</td>
#             </tr>
#             <tr>
#                         <th id="T_abef4c20_d12b_11ea_88f6_acde48001122level0_row2" class="row_heading level0 row2" >Streckenschaden</th>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row2_col0" class="data row2 col0" >0.001</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row2_col1" class="data row2 col1" >0.02</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row2_col2" class="data row2 col2" >0.008</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row2_col3" class="data row2 col3" >0.02</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row2_col4" class="data row2 col4" >0.001</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row2_col5" class="data row2 col5" >0.0004</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row2_col6" class="data row2 col6" >1e-05</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row2_col7" class="data row2 col7" >0.03</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row2_col8" class="data row2 col8" >0.2</td>
#                         <td id="T_abef4c20_d12b_11ea_88f6_acde48001122row2_col9" class="data row2 col9" >0.0006</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### ANOVA Heatmap <a class="anchor" id="ANOVA_HEATMAP"></a>
#
# **Interpretation:** Nach Cohen (1988) bei .01 (kleiner Effekt), .06 (mittlerer Effekt) und .14 (großer Effekt)
#
# [Cohen, J. (1988)](http://www.utstat.toronto.edu/~brunner/oldclass/378f16/readings/CohenPower.pdf). Statistical Power Analysis for the Behavioral Sciences.

# %%
colormap = plt.cm.Blues
ax=plt.figure(figsize=(20,15)).gca()
x_axis_labels = ["Temperatur", "Ursache","Unfallart", "Zugart", "Sichtbarkeit", "Wetter", "Zug zu schnell?", "Streckenart", "Siginifikanz des Unfalls", "Jahreszeit"] # labels for x-axis
y_axis_labels = ["Infrastrukturschaden", "Materialschaden", "Streckenschaden"] # labels for y-axis
ax=sns.heatmap(compare_anova,ax=ax,linewidths=0.1, 
            square=True, cmap=colormap, linecolor='white', annot=True, xticklabels=x_axis_labels, yticklabels=y_axis_labels, vmin=0, vmax=0.5);
bottom, top = ax.get_ylim()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, horizontalalignment='right', verticalalignment='top')
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.savefig("Images/ANOVA_Heatmap.png")
